# %% [markdown]
# ## Impact of Training Data Window and Shuffling on Model Performance
#
#
# The point of this notebook is just to look into the impact of the size of the training history on model performance. A related experiment is whether or not shuffling of the training history has any effect.

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import time
import gc

import numpy as np
from google.cloud import bigquery
from google.cloud import storage

import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)


from tensorflow import keras
from tensorflow.keras import layers
import seaborn as sns
from pandas.tseries.offsets import BDay

from tensorflow.keras.layers import Embedding
from tensorflow.keras import activations
from tensorflow.keras import backend as K
from tensorflow.keras import initializers
from tensorflow.keras.layers.experimental.preprocessing import Normalization
from sklearn import preprocessing
from datetime import datetime
import matplotlib.pyplot as plt
import pickle5 as pickle


from ficc.utils.nelson_siegel_model import *
from ficc.utils.diff_in_days import *
from ficc.utils.auxiliary_functions import sqltodf


from IPython.display import display, HTML
import os


from ficc.data.process_data import process_data
from ficc.utils.auxiliary_variables import PREDICTORS, NON_CAT_FEATURES, BINARY, CATEGORICAL_FEATURES, IDENTIFIERS, PURPOSE_CLASS_DICT, NUM_OF_DAYS_IN_YEAR
from ficc.utils.gcp_storage_functions import upload_data, download_data
from ficc.utils.auxiliary_variables import RELATED_TRADE_BINARY_FEATURES, RELATED_TRADE_NON_CAT_FEATURES, RELATED_TRADE_CATEGORICAL_FEATURES

pd.set_option('display.float_format', lambda x: '%.3f' % x)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 2023-04-26 03:38:51.550660: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-26 03:38:51.696013: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-26 03:38:51.697727: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# Initializing pandarallel with 8.0 cores
# INFO: Pandarallel will run on 8 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.

# %%
print(tf.__version__)
# Out:
# 2.7.0

# %%
tf.config.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="/home/jupyter/ficc/isaac_creds.json"
os.environ['TF_GPU_THREAD_MODE'] = 'gpu_private'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
pd.options.mode.chained_assignment = None

bq_client = bigquery.Client()
storage_client = storage.Client()

TRAIN_TEST_SPLIT = 0.85
LEARNING_RATE = 0.0001
BATCH_SIZE = 1000
NUM_EPOCHS = 35

DROPOUT = 0.01
SEQUENCE_LENGTH = 5
NUM_FEATURES = 7

# %% [markdown]
# #### Data Preparation
# We grab the data from a GCP bucket. The data is prepared using the ficc python package. More insight on how the data is prepared can be found [here](https://github.com/Ficc-ai/ficc/blob/ahmad_ml/ml_models/sequence_predictors/data_prep/data_preparation.ipynb)

# %%
# # %%time

# import gcsfs
# fs = gcsfs.GCSFileSystem(project='eng-reactor-287421')
# # with fs.open('ahmad_data/processed_data_2022-10-24-20:56.pkl') as f:
# # with fs.open('ahmad_data/processed_data_2022-10-24-20:56_c_spread.pkl') as f:
# # with fs.open('ahmad_data/processed_data_2022-12-02-17:52.pkl') as f:
# with fs.open('isaac_data/processed_file_FULL_2023-04-12-20:44.pkl') as f:
#     data = pd.read_pickle(f)

# %%
if os.path.isfile('processed_file_FULL_2023-04-12-20:44.pkl'):
    with open('processed_file_FULL_2023-04-12-20:44.pkl', 'rb') as f:
        data = pickle.load(f)
else:
    with open('processed_file_FULL_2023-04-12-20:44.pkl', 'wb') as f:
        import gcsfs
        fs = gcsfs.GCSFileSystem(project='eng-reactor-287421')
        with fs.open('isaac_data/processed_file_FULL_2023-04-12-20:44.pkl') as f:
            data = pd.read_pickle(f)
            pickle.dump(data, f)

# %%
data.trade_date.max(), data.trade_date.min()
# Out:
# (Timestamp('2023-02-28 00:00:00'), Timestamp('2022-09-01 00:00:00'))

# %%
data['new_ys'] = data['yield'] - data['new_ficc_ycl']
data['new_ys_realtime'] = data['yield'] - data['new_real_time_ficc_ycl']
data.dropna(subset=['new_ys', 'new_ys_realtime'], inplace=True)

# %%
auxiliary_features = ['dollar_price',
                      'last_calc_date',
                     'calc_date', 
                     'trade_date',
                      'last_trade_date',
                     'trade_datetime', 
                     'purpose_sub_class', 
                     'called_redemption_type', 
                     'calc_day_cat',
                     'yield',
                     'ficc_ycl',
                     #'same_ys',
                     #'trade_history_sum',
                     'new_ficc_ycl',
                      'new_real_time_ficc_ycl',
                     'days_to_refund',
                      'last_dollar_price',
                      'last_rtrs_control_number',
                     'is_called',
                     ]

# %%
if 'target_attention_features' not in PREDICTORS:
    PREDICTORS.append('target_attention_features')
    
if 'ficc_treasury_spread' not in PREDICTORS:
    PREDICTORS.append('ficc_treasury_spread')
    NON_CAT_FEATURES.append('ficc_treasury_spread')
    
for col in ['new_ficc_ycl', 'new_real_time_ficc_ycl']:     
    if col not in PREDICTORS:
        PREDICTORS.append(col)
        NON_CAT_FEATURES.append(col)

for col in ['extraordinary_make_whole_call', 'make_whole_call', 'has_unexpired_lines_of_credit']:     
    if col not in data.columns:
        try: 
            print(f'Removing {col} from PREDICTORS and BINARY')
            BINARY.remove(col)
            PREDICTORS.remove(col) 
        except:
            continue
# Out:
# Removing extraordinary_make_whole_call from PREDICTORS and BINARY
# Removing make_whole_call from PREDICTORS and BINARY
# Removing has_unexpired_lines_of_credit from PREDICTORS and BINARY

# %%
def process_data(data): 
    data['ted-rate'] = (data['t_rate_10'] - data['t_rate_2']) * 100
    
    # Here is a list of exclusions that we will be experimenting with. The model is trained with these exclusions. These exclusions were discussed with a team member.
    # Callable less than a year in the future
    # Maturity less than a year in the future and more than 30 years in the future
    
    data = data[(data.days_to_call == 0) | (data.days_to_call > np.log10(400))]
    data = data[(data.days_to_refund == 0) | (data.days_to_refund > np.log10(400))]
    data = data[(data.days_to_maturity == 0) | (data.days_to_maturity > np.log10(400))]
    data = data[data.days_to_maturity < np.log10(30000)]
    data['trade_history_sum'] = data.trade_history.parallel_apply(lambda x: np.sum(x))
    data.issue_amount = data.issue_amount.replace([np.inf, -np.inf], np.nan)
    data.dropna(inplace=True, subset=PREDICTORS+['trade_history_sum'])
    data.purpose_sub_class.fillna(0, inplace=True)
    
    # data['calc_date_duration'] = data[['last_calc_date','last_trade_date']].parallel_apply(get_calc_date_duration, axis=1)
    # data['new_ficc_ycl_fixed_shape'] = data[['trade_date', 'calc_date_duration']].parallel_apply(lambda x: calculate_ycl(x, new_yc_params), axis = 1)
    # data['new_ficc_ycl_prev_day'] = data[['last_calc_date', 'last_trade_date' ,'calc_date_duration','trade_date']].parallel_apply(get_yield_for_last_duration, axis=1)
    
    return data

# %%
# %%time

processed_data = process_data(data) 
# processed_data = processed_data[IDENTIFIERS + PREDICTORS + auxiliary_features]
# Out:
# CPU times: user 40.6 s, sys: 12.6 s, total: 53.2 s
# Wall time: 58.7 s

# %%
encoders = {}
fmax = {}
for f in CATEGORICAL_FEATURES:
    print(f)
    fprep = preprocessing.LabelEncoder().fit(processed_data[f].drop_duplicates()) #note that there are apparently no trades with CC 
    fmax[f] = np.max(fprep.transform(fprep.classes_))
    encoders[f] = fprep
    
with open('encoders.pkl','wb') as file:
    pickle.dump(encoders,file)
# Out:
# rating
# incorporated_state_code
# trade_type
# purpose_class

# %%
train_dataframe = processed_data[(processed_data.trade_date <
                                  '2023-02-01')].sort_values(by='trade_date', ascending=True).reset_index(drop=True)

test_dataframe = processed_data[(processed_data.trade_date >'2023-02-01')].sort_values(by='trade_date', ascending=True).reset_index(drop=True)

# %%
def create_input(df):
    global encoders
    datalist = []
    datalist.append(np.stack(df['trade_history'].to_numpy()))
    datalist.append(np.stack(df['target_attention_features'].to_numpy()))

    noncat_and_binary = []
    for f in NON_CAT_FEATURES + BINARY:
        noncat_and_binary.append(np.expand_dims(df[f].to_numpy().astype('float32'), axis=1))
    datalist.append(np.concatenate(noncat_and_binary, axis=-1))
    
    for f in CATEGORICAL_FEATURES:
        encoded = encoders[f].transform(df[f])
        datalist.append(encoded.astype('float32'))
    
    return datalist

# %%
# %%time
x_train = create_input(train_dataframe)
x_train[0] = x_train[0][:,:,[0,2,3,4,5,6]]
y_train = train_dataframe.new_ys

x_test = create_input(test_dataframe)
x_test[0] = x_test[0][:,:,[0,2,3,4,5,6]]
y_test = test_dataframe.new_ys
# Out:
# CPU times: user 18.2 s, sys: 874 ms, total: 19.1 s
# Wall time: 19.1 s

# %%
cutoffs = ['2022-09-01', '2022-11-01', '2022-12-01']

dates = train_dataframe[['trade_date']].reset_index().set_index('trade_date')

indices = [dates.loc[cutoff:]['index'].min() for cutoff in cutoffs]

# %% [markdown]
# ## Model Training and Testing

# %%
# Normalization layer for the trade history
trade_history_normalizer = Normalization(name='Trade_history_normalizer')
trade_history_normalizer.adapt(x_train[0],batch_size=BATCH_SIZE)

# Normalization layer for the non-categorical and binary features
noncat_binary_normalizer = Normalization(name='Numerical_binary_normalizer')
noncat_binary_normalizer.adapt(x_train[2], batch_size = BATCH_SIZE)

tf.keras.utils.set_random_seed(10)
# Out:
# 2023-04-26 03:41:53.819279: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-26 03:41:53.821524: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-26 03:41:53.825029: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-26 03:41:53.827699: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-26 03:42:01.240688: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-26 03:42:01.242591: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-26 03:42:01.244186: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-26 03:42:01.259046: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13594 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5

# %% [markdown]
# #### Implementation of the model

# %%
def generate_model(SEQUENCE_LENGTH = SEQUENCE_LENGTH ,NUM_FEATURES = NUM_FEATURES, trade_history_normalizer = trade_history_normalizer):
    inputs = []
    layer = []

    ############## INPUT BLOCK ###################
    trade_history_input = layers.Input(name="trade_history_input", 
                                       shape=(SEQUENCE_LENGTH,NUM_FEATURES), 
                                       dtype = tf.float32) 

    target_attention_input = layers.Input(name="target_attention_input", 
                                       shape=(SEQUENCE_LENGTH, 3), 
                                       dtype = tf.float32) 


    inputs.append(trade_history_input)
    inputs.append(target_attention_input)

    inputs.append(layers.Input(
        name="NON_CAT_AND_BINARY_FEATURES",
        shape=(len(NON_CAT_FEATURES + BINARY),)
    ))


    layer.append(noncat_binary_normalizer(inputs[2]))
    ####################################################


    ############## TRADE HISTORY MODEL #################

    lstm_layer = layers.LSTM(50, 
                             activation='tanh',
                             input_shape=(SEQUENCE_LENGTH,NUM_FEATURES),
                             return_sequences = True,
                             name='LSTM')

    lstm_attention_layer = CustomAttention(50)

    lstm_layer_2 = layers.LSTM(100, 
                               activation='tanh',
                               input_shape=(SEQUENCE_LENGTH,50),
                               return_sequences = False,
                               name='LSTM_2')


    features = lstm_layer(trade_history_normalizer(inputs[0]))
    features = lstm_attention_layer(features, features, inputs[1])
    features = layers.BatchNormalization()(features)
    # features = layers.Dropout(DROPOUT)(features)

    features = lstm_layer_2(features)
    features = layers.BatchNormalization()(features)
    # features = layers.Dropout(DROPOUT)(features)

    trade_history_output = layers.Dense(100, 
                                        activation='relu')(features)

    ####################################################

    ############## REFERENCE DATA MODEL ################
    global encoders
    for f in CATEGORICAL_FEATURES:
        fin = layers.Input(shape=(1,), name = f)
        inputs.append(fin)
        embedded = layers.Flatten(name = f + "_flat")( layers.Embedding(input_dim = fmax[f]+1,
                                                                        output_dim = max(30,int(np.sqrt(fmax[f]))),
                                                                        input_length= 1,
                                                                        name = f + "_embed")(fin))
        layer.append(embedded)


    reference_hidden = layers.Dense(400,
                                    activation='relu',
                                    name='reference_hidden_1')(layers.concatenate(layer, axis=-1))

    reference_hidden = layers.BatchNormalization()(reference_hidden)
    reference_hidden = layers.Dropout(DROPOUT)(reference_hidden)

    reference_hidden2 = layers.Dense(200,activation='relu',name='reference_hidden_2')(reference_hidden)
    reference_hidden2 = layers.BatchNormalization()(reference_hidden2)
    reference_hidden2 = layers.Dropout(DROPOUT)(reference_hidden2)

    reference_output = layers.Dense(100,activation='tanh',name='reference_hidden_3')(reference_hidden2)

    ####################################################

    feed_forward_input = layers.concatenate([reference_output, trade_history_output])

    hidden = layers.Dense(300,activation='relu')(feed_forward_input)
    hidden = layers.BatchNormalization()(hidden)
    hidden = layers.Dropout(DROPOUT)(hidden)

    hidden2 = layers.Dense(100,activation='tanh')(hidden)
    hidden2 = layers.BatchNormalization()(hidden2)
    hidden2 = layers.Dropout(DROPOUT)(hidden2)

    final = layers.Dense(1)(hidden2)

    model = keras.Model(inputs=inputs, outputs=final)
    
    return model

# %%
fit_callbacks = [
    #WandbCallback(save_model=False),
    keras.callbacks.EarlyStopping(
        monitor="val_loss",
        patience=10,
        verbose=0,
        mode="auto",
        restore_best_weights=True,
    ),
    time_callback
]

tb_callback = tf.keras.callbacks.TensorBoard(log_dir='logs', update_freq='epoch', profile_batch=0, write_steps_per_second=True)

# %%
def create_tf_data(x_train, y_train, shuffle=False, shuffle_buffer=1):

    train_size = int(0.8*len(x_train[0]))
                     
    X=()
    for x in x_train:
        X += (tf.data.Dataset.from_tensor_slices(x),)
        

    temp = tf.data.Dataset.zip((X))
    del X
    dataset = tf.data.Dataset.zip((temp,
                        tf.data.Dataset.from_tensor_slices(y_train)))
    del temp
    if shuffle:
        shuffle_buffer = int(len(x_train[0])*shuffle_buffer)
        dataset = dataset.shuffle(shuffle_buffer)
            
    train_ds = dataset.take(train_size)
    val_ds = dataset.skip(train_size)                 
    return train_ds, val_ds

# %%
def train_model(x_train, y_train, shuffle, shuffle_buffer=1):
    tf.keras.backend.clear_session()
    gc.collect()

    timestamp = datetime.now().strftime('%Y-%m-%d %H-%M')
    
    fit_callbacks = fit_callbacks = [
    keras.callbacks.EarlyStopping(
        monitor="val_loss",
        patience=10,
        verbose=0,
        mode="auto",
        restore_best_weights=True),
        # time_callback,
        CSVLoggerTimeHistory(timestamp+'_training_logs.csv', separator=",", append=False)]
    
    with tf.device('/cpu:0'):
        train_ds, val_ds = create_tf_data(x_train, y_train, shuffle, shuffle_buffer)
        train_ds = train_ds.batch(BATCH_SIZE).prefetch(2).cache()
        val_ds = val_ds.batch(BATCH_SIZE).prefetch(2).cache()

    model_new_ys = generate_model(5, 6, trade_history_normalizer)

    fit_callbacks = fit_callbacks = [
    keras.callbacks.EarlyStopping(
        monitor="val_loss",
        patience=10,
        verbose=0,
        mode="auto",
        restore_best_weights=True),
        # time_callback,
        CSVLoggerTimeHistory('_'.join([model_new_ys.name,timestamp,'training_logs.csv'])
                             , separator=",", 
                             append=False)
    ]
    
    
    model_new_ys.compile(optimizer=keras.optimizers.Adam(learning_rate=0.0001),
          loss=keras.losses.MeanAbsoluteError(),
          metrics=[keras.metrics.MeanAbsoluteError()])

    history_new_ys = model_new_ys.fit(train_ds,
                                      validation_data=val_ds,
                                        epochs=NUM_EPOCHS,     
                                        verbose=1, 
                                        callbacks=fit_callbacks,
                                        use_multiprocessing=True,
                                        workers=8)
    
    return history_new_ys, model_new_ys

# %% [markdown]
# <b>Testing 3 cutoffs: </b>
#
# ['2022-09-01': 5 months,
# '2022-11-01': 3 months,
# '2022-12-01': 2 months]
#
# Shuffled

# %%
experiment_models = {}

# %%
for i, cutoff in enumerate(cutoffs):
    print(f'Running model for cutoff on {cutoff} onwards')
    cutoff_idx = indices[i]
    new_x_train = [x[cutoff_idx:] for x in x_train]
    new_y_train = y_train[cutoff_idx:]
   
    # Normalization layer for the trade history
    trade_history_normalizer = Normalization(name='Trade_history_normalizer')
    trade_history_normalizer.adapt(new_x_train[0],batch_size=BATCH_SIZE)

    # Normalization layer for the non-categorical and binary features
    noncat_binary_normalizer = Normalization(name='Numerical_binary_normalizer')
    noncat_binary_normalizer.adapt(new_x_train[2], batch_size = BATCH_SIZE)
    
    temp_model = train_model(new_x_train, new_y_train, True)
    
    experiment_models[cutoff] = temp_model
    print('\n\n')
# Out:
# Running model for cutoff on 2022-09-01 onwards
# Epoch 1/35
# 2023-04-26 03:48:07.812549: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 723226 of 4425824
# 2023-04-26 03:48:17.812536: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 1648386 of 4425824
# 2023-04-26 03:48:27.812539: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 2732057 of 4425824
# 2023-04-26 03:48:37.812534: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 3803395 of 4425824
# 2023-04-26 03:48:43.618657: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:405] Shuffle buffer filled.
# 2023-04-26 03:48:47.734621: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8200
# 3541/3541 [==============================] - ETA: 0s - loss: 41.5114 - mean_absolute_error: 41.5114
# 2023-04-26 03:49:55.070959: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 1066397 of 4425824
# 2023-04-26 03:50:05.070976: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 1939527 of 4425824
# 2023-04-26 03:50:15.070969: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 2696209 of 4425824
# 2023-04-26 03:50:25.070968: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 3762029 of 4425824
# 2023-04-26 03:50:31.293418: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:405] Shuffle buffer filled.
# 3541/3541 [==============================] - 204s 42ms/step - loss: 41.5114 - mean_absolute_error: 41.5114 - val_loss: 24.7736 - val_mean_absolute_error: 24.7736
# Epoch 2/35
# 3541/3541 [==============================] - 48s 13ms/step - loss: 14.9009 - mean_absolute_error: 14.9009 - val_loss: 11.0377 - val_mean_absolute_error: 11.0377
# Epoch 3/35
# 3541/3541 [==============================] - 53s 15ms/step - loss: 10.9493 - mean_absolute_error: 10.9493 - val_loss: 10.4113 - val_mean_absolute_error: 10.4113
# Epoch 4/35
# 3541/3541 [==============================] - 51s 15ms/step - loss: 10.6393 - mean_absolute_error: 10.6393 - val_loss: 10.1517 - val_mean_absolute_error: 10.1517
# Epoch 5/35
# 3541/3541 [==============================] - 53s 15ms/step - loss: 10.4405 - mean_absolute_error: 10.4405 - val_loss: 10.0831 - val_mean_absolute_error: 10.0831
# Epoch 6/35
# 3541/3541 [==============================] - 51s 14ms/step - loss: 10.2988 - mean_absolute_error: 10.2988 - val_loss: 9.9589 - val_mean_absolute_error: 9.9589
# Epoch 7/35
# 3541/3541 [==============================] - 46s 13ms/step - loss: 10.1879 - mean_absolute_error: 10.1879 - val_loss: 9.8240 - val_mean_absolute_error: 9.8240
# Epoch 8/35
# 3541/3541 [==============================] - 53s 15ms/step - loss: 10.0913 - mean_absolute_error: 10.0913 - val_loss: 9.6851 - val_mean_absolute_error: 9.6851
# Epoch 9/35
# 3541/3541 [==============================] - 52s 15ms/step - loss: 10.0106 - mean_absolute_error: 10.0106 - val_loss: 9.6977 - val_mean_absolute_error: 9.6977
# Epoch 10/35
# 3541/3541 [==============================] - 53s 15ms/step - loss: 9.9421 - mean_absolute_error: 9.9421 - val_loss: 9.6718 - val_mean_absolute_error: 9.6718
# Epoch 11/35
# 3541/3541 [==============================] - 52s 15ms/step - loss: 9.8779 - mean_absolute_error: 9.8779 - val_loss: 9.5472 - val_mean_absolute_error: 9.5472
# Epoch 12/35
# 3541/3541 [==============================] - 53s 15ms/step - loss: 9.8246 - mean_absolute_error: 9.8246 - val_loss: 9.5166 - val_mean_absolute_error: 9.5166
# Epoch 13/35
# 3541/3541 [==============================] - 53s 15ms/step - loss: 9.7713 - mean_absolute_error: 9.7713 - val_loss: 9.4361 - val_mean_absolute_error: 9.4361
# Epoch 14/35
# 3541/3541 [==============================] - 49s 14ms/step - loss: 9.7249 - mean_absolute_error: 9.7249 - val_loss: 9.4237 - val_mean_absolute_error: 9.4237
# Epoch 15/35
# 3541/3541 [==============================] - 50s 14ms/step - loss: 9.6798 - mean_absolute_error: 9.6798 - val_loss: 9.3608 - val_mean_absolute_error: 9.3608
# Epoch 16/35
# 3541/3541 [==============================] - 51s 14ms/step - loss: 9.6384 - mean_absolute_error: 9.6384 - val_loss: 9.2970 - val_mean_absolute_error: 9.2970
# Epoch 17/35
# 3541/3541 [==============================] - 51s 14ms/step - loss: 9.6000 - mean_absolute_error: 9.6000 - val_loss: 9.2707 - val_mean_absolute_error: 9.2707
# Epoch 18/35
# 3541/3541 [==============================] - 51s 14ms/step - loss: 9.5627 - mean_absolute_error: 9.5627 - val_loss: 9.2623 - val_mean_absolute_error: 9.2623
# Epoch 19/35
# 3541/3541 [==============================] - 51s 15ms/step - loss: 9.5310 - mean_absolute_error: 9.5310 - val_loss: 9.2543 - val_mean_absolute_error: 9.2543
# Epoch 20/35
# 3541/3541 [==============================] - 52s 15ms/step - loss: 9.4960 - mean_absolute_error: 9.4960 - val_loss: 9.1930 - val_mean_absolute_error: 9.1930
# Epoch 21/35
# 3541/3541 [==============================] - 49s 14ms/step - loss: 9.4664 - mean_absolute_error: 9.4664 - val_loss: 9.2012 - val_mean_absolute_error: 9.2012
# Epoch 22/35
# 3541/3541 [==============================] - 53s 15ms/step - loss: 9.4366 - mean_absolute_error: 9.4366 - val_loss: 9.0995 - val_mean_absolute_error: 9.0995
# Epoch 23/35
# 3541/3541 [==============================] - 51s 14ms/step - loss: 9.4065 - mean_absolute_error: 9.4065 - val_loss: 9.1055 - val_mean_absolute_error: 9.1055
# Epoch 24/35
# 3541/3541 [==============================] - 51s 14ms/step - loss: 9.3807 - mean_absolute_error: 9.3807 - val_loss: 9.0683 - val_mean_absolute_error: 9.0683
# Epoch 25/35
# 3541/3541 [==============================] - 51s 14ms/step - loss: 9.3555 - mean_absolute_error: 9.3555 - val_loss: 9.0743 - val_mean_absolute_error: 9.0743
# Epoch 26/35
# 3541/3541 [==============================] - 48s 13ms/step - loss: 9.3303 - mean_absolute_error: 9.3303 - val_loss: 9.0550 - val_mean_absolute_error: 9.0550
# Epoch 27/35
# 3541/3541 [==============================] - 52s 15ms/step - loss: 9.3075 - mean_absolute_error: 9.3075 - val_loss: 8.9917 - val_mean_absolute_error: 8.9917
# Epoch 28/35
# 3541/3541 [==============================] - 51s 15ms/step - loss: 9.2823 - mean_absolute_error: 9.2823 - val_loss: 8.9587 - val_mean_absolute_error: 8.9587
# Epoch 29/35
# 3541/3541 [==============================] - 51s 14ms/step - loss: 9.2623 - mean_absolute_error: 9.2623 - val_loss: 9.0364 - val_mean_absolute_error: 9.0364
# Epoch 30/35
# 3541/3541 [==============================] - 51s 15ms/step - loss: 9.2391 - mean_absolute_error: 9.2391 - val_loss: 8.9425 - val_mean_absolute_error: 8.9425
# Epoch 31/35
# 3541/3541 [==============================] - 51s 14ms/step - loss: 9.2165 - mean_absolute_error: 9.2165 - val_loss: 8.9750 - val_mean_absolute_error: 8.9750
# Epoch 32/35
# 3541/3541 [==============================] - 49s 14ms/step - loss: 9.2000 - mean_absolute_error: 9.2000 - val_loss: 8.9198 - val_mean_absolute_error: 8.9198
# Epoch 33/35
# 3541/3541 [==============================] - 52s 15ms/step - loss: 9.1783 - mean_absolute_error: 9.1783 - val_loss: 8.9321 - val_mean_absolute_error: 8.9321
# Epoch 34/35
# 3541/3541 [==============================] - 52s 15ms/step - loss: 9.1622 - mean_absolute_error: 9.1622 - val_loss: 8.8826 - val_mean_absolute_error: 8.8826
# Epoch 35/35
# 3541/3541 [==============================] - 52s 15ms/step - loss: 9.1419 - mean_absolute_error: 9.1419 - val_loss: 8.8867 - val_mean_absolute_error: 8.8867
#
#
#
# Running model for cutoff on 2022-11-01 onwards
# Epoch 1/35
# 2023-04-26 04:22:40.993235: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 1060021 of 2731538
# 2023-04-26 04:22:50.993231: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 2123965 of 2731538
#    5/2186 [..............................] - ETA: 30s - loss: 56.7090 - mean_absolute_error: 56.7090
# 2023-04-26 04:22:56.682901: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:405] Shuffle buffer filled.
# 2186/2186 [==============================] - ETA: 0s - loss: 49.9708 - mean_absolute_error: 49.9708
# 2023-04-26 04:23:45.453985: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 1072046 of 2731538
# 2023-04-26 04:23:55.453995: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 2141768 of 2731538
# 2023-04-26 04:24:00.917463: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:405] Shuffle buffer filled.
# 2186/2186 [==============================] - 121s 42ms/step - loss: 49.9708 - mean_absolute_error: 49.9708 - val_loss: 42.2241 - val_mean_absolute_error: 42.2241
# Epoch 2/35
# 2186/2186 [==============================] - 28s 13ms/step - loss: 32.1388 - mean_absolute_error: 32.1388 - val_loss: 21.3001 - val_mean_absolute_error: 21.3001
# Epoch 3/35
# 2186/2186 [==============================] - 35s 16ms/step - loss: 13.9371 - mean_absolute_error: 13.9371 - val_loss: 11.1226 - val_mean_absolute_error: 11.1226
# Epoch 4/35
# 2186/2186 [==============================] - 30s 14ms/step - loss: 11.1842 - mean_absolute_error: 11.1842 - val_loss: 10.6391 - val_mean_absolute_error: 10.6391
# Epoch 5/35
# 2186/2186 [==============================] - 33s 15ms/step - loss: 10.8900 - mean_absolute_error: 10.8900 - val_loss: 10.3171 - val_mean_absolute_error: 10.3171
# Epoch 6/35
# 2186/2186 [==============================] - 34s 16ms/step - loss: 10.7048 - mean_absolute_error: 10.7048 - val_loss: 10.2474 - val_mean_absolute_error: 10.2474
# Epoch 7/35
# 2186/2186 [==============================] - 28s 13ms/step - loss: 10.5646 - mean_absolute_error: 10.5646 - val_loss: 10.1461 - val_mean_absolute_error: 10.1461
# Epoch 8/35
# 2186/2186 [==============================] - 34s 16ms/step - loss: 10.4554 - mean_absolute_error: 10.4554 - val_loss: 9.9697 - val_mean_absolute_error: 9.9697
# Epoch 9/35
# 2186/2186 [==============================] - 28s 13ms/step - loss: 10.3545 - mean_absolute_error: 10.3545 - val_loss: 9.9610 - val_mean_absolute_error: 9.9610
# Epoch 10/35
# 2186/2186 [==============================] - 35s 16ms/step - loss: 10.2748 - mean_absolute_error: 10.2748 - val_loss: 9.8330 - val_mean_absolute_error: 9.8330
# Epoch 11/35
# 2186/2186 [==============================] - 28s 13ms/step - loss: 10.2020 - mean_absolute_error: 10.2020 - val_loss: 9.7795 - val_mean_absolute_error: 9.7795
# Epoch 12/35
# 2186/2186 [==============================] - 35s 16ms/step - loss: 10.1341 - mean_absolute_error: 10.1341 - val_loss: 9.7451 - val_mean_absolute_error: 9.7451
# Epoch 13/35
# 2186/2186 [==============================] - 28s 13ms/step - loss: 10.0739 - mean_absolute_error: 10.0739 - val_loss: 9.6183 - val_mean_absolute_error: 9.6183
# Epoch 14/35
# 2186/2186 [==============================] - 34s 16ms/step - loss: 10.0214 - mean_absolute_error: 10.0214 - val_loss: 9.5736 - val_mean_absolute_error: 9.5736
# Epoch 15/35
# 2186/2186 [==============================] - 28s 13ms/step - loss: 9.9665 - mean_absolute_error: 9.9665 - val_loss: 9.5682 - val_mean_absolute_error: 9.5682
# Epoch 16/35
# 2186/2186 [==============================] - 34s 16ms/step - loss: 9.9184 - mean_absolute_error: 9.9184 - val_loss: 9.5163 - val_mean_absolute_error: 9.5163
# Epoch 17/35
# 2186/2186 [==============================] - 28s 13ms/step - loss: 9.8725 - mean_absolute_error: 9.8725 - val_loss: 9.4793 - val_mean_absolute_error: 9.4793
# Epoch 18/35
# 2186/2186 [==============================] - 35s 16ms/step - loss: 9.8293 - mean_absolute_error: 9.8293 - val_loss: 9.5064 - val_mean_absolute_error: 9.5064
# Epoch 19/35
# 2186/2186 [==============================] - 29s 13ms/step - loss: 9.7878 - mean_absolute_error: 9.7878 - val_loss: 9.4127 - val_mean_absolute_error: 9.4127
# Epoch 20/35
# 2186/2186 [==============================] - 33s 15ms/step - loss: 9.7496 - mean_absolute_error: 9.7496 - val_loss: 9.3570 - val_mean_absolute_error: 9.3570
# Epoch 21/35
# 2186/2186 [==============================] - 33s 15ms/step - loss: 9.7113 - mean_absolute_error: 9.7113 - val_loss: 9.3355 - val_mean_absolute_error: 9.3355
# Epoch 22/35
# 2186/2186 [==============================] - 28s 13ms/step - loss: 9.6811 - mean_absolute_error: 9.6811 - val_loss: 9.3655 - val_mean_absolute_error: 9.3655
# Epoch 23/35
# 2186/2186 [==============================] - 34s 16ms/step - loss: 9.6472 - mean_absolute_error: 9.6472 - val_loss: 9.2769 - val_mean_absolute_error: 9.2769
# Epoch 24/35
# 2186/2186 [==============================] - 28s 13ms/step - loss: 9.6130 - mean_absolute_error: 9.6130 - val_loss: 9.2876 - val_mean_absolute_error: 9.2876
# Epoch 25/35
# 2186/2186 [==============================] - 34s 16ms/step - loss: 9.5816 - mean_absolute_error: 9.5816 - val_loss: 9.2605 - val_mean_absolute_error: 9.2605
# Epoch 26/35
# 2186/2186 [==============================] - 28s 13ms/step - loss: 9.5566 - mean_absolute_error: 9.5566 - val_loss: 9.2897 - val_mean_absolute_error: 9.2897
# Epoch 27/35
# 2186/2186 [==============================] - 34s 16ms/step - loss: 9.5236 - mean_absolute_error: 9.5236 - val_loss: 9.2429 - val_mean_absolute_error: 9.2429
# Epoch 28/35
# 2186/2186 [==============================] - 28s 13ms/step - loss: 9.4980 - mean_absolute_error: 9.4980 - val_loss: 9.1428 - val_mean_absolute_error: 9.1428
# Epoch 29/35
# 2186/2186 [==============================] - 34s 16ms/step - loss: 9.4731 - mean_absolute_error: 9.4731 - val_loss: 9.1785 - val_mean_absolute_error: 9.1785
# Epoch 30/35
# 2186/2186 [==============================] - 28s 13ms/step - loss: 9.4439 - mean_absolute_error: 9.4439 - val_loss: 9.1677 - val_mean_absolute_error: 9.1677
# Epoch 31/35
# 2186/2186 [==============================] - 33s 15ms/step - loss: 9.4178 - mean_absolute_error: 9.4178 - val_loss: 9.1350 - val_mean_absolute_error: 9.1350
# Epoch 32/35
# 2186/2186 [==============================] - 27s 13ms/step - loss: 9.3952 - mean_absolute_error: 9.3952 - val_loss: 9.0484 - val_mean_absolute_error: 9.0484
# Epoch 33/35
# 2186/2186 [==============================] - 34s 16ms/step - loss: 9.3711 - mean_absolute_error: 9.3711 - val_loss: 9.0551 - val_mean_absolute_error: 9.0551
# Epoch 34/35
# 2186/2186 [==============================] - 28s 13ms/step - loss: 9.3491 - mean_absolute_error: 9.3491 - val_loss: 9.0066 - val_mean_absolute_error: 9.0066
# Epoch 35/35
# 2186/2186 [==============================] - 33s 15ms/step - loss: 9.3301 - mean_absolute_error: 9.3301 - val_loss: 9.0199 - val_mean_absolute_error: 9.0199
#
#
#
# Running model for cutoff on 2022-12-01 onwards
# Epoch 1/35
# 2023-04-26 04:42:50.732321: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 1092744 of 1707057
#    5/1366 [..............................] - ETA: 18s - loss: 60.9581 - mean_absolute_error: 60.9581
# 2023-04-26 04:42:56.297209: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:405] Shuffle buffer filled.
# 1366/1366 [==============================] - ETA: 0s - loss: 56.2933 - mean_absolute_error: 56.2933
# 2023-04-26 04:43:32.692823: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 1088807 of 1707057
# 2023-04-26 04:43:38.326357: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:405] Shuffle buffer filled.
# 1366/1366 [==============================] - 75s 40ms/step - loss: 56.2933 - mean_absolute_error: 56.2933 - val_loss: 51.8324 - val_mean_absolute_error: 51.8324
# Epoch 2/35
# 1366/1366 [==============================] - 23s 17ms/step - loss: 48.1055 - mean_absolute_error: 48.1055 - val_loss: 37.5204 - val_mean_absolute_error: 37.5204
# Epoch 3/35
# 1366/1366 [==============================] - 18s 13ms/step - loss: 34.4570 - mean_absolute_error: 34.4570 - val_loss: 27.0897 - val_mean_absolute_error: 27.0897
# Epoch 4/35
# 1366/1366 [==============================] - 18s 13ms/step - loss: 19.2562 - mean_absolute_error: 19.2562 - val_loss: 14.1794 - val_mean_absolute_error: 14.1794
# Epoch 5/35
# 1366/1366 [==============================] - 23s 17ms/step - loss: 12.0403 - mean_absolute_error: 12.0403 - val_loss: 11.0417 - val_mean_absolute_error: 11.0417
# Epoch 6/35
# 1366/1366 [==============================] - 18s 13ms/step - loss: 11.1396 - mean_absolute_error: 11.1396 - val_loss: 10.7175 - val_mean_absolute_error: 10.7175
# Epoch 7/35
# 1366/1366 [==============================] - 18s 13ms/step - loss: 10.9210 - mean_absolute_error: 10.9210 - val_loss: 10.4918 - val_mean_absolute_error: 10.4918
# Epoch 8/35
# 1366/1366 [==============================] - 23s 17ms/step - loss: 10.7470 - mean_absolute_error: 10.7470 - val_loss: 10.3257 - val_mean_absolute_error: 10.3257
# Epoch 9/35
# 1366/1366 [==============================] - 18s 13ms/step - loss: 10.6263 - mean_absolute_error: 10.6263 - val_loss: 10.1988 - val_mean_absolute_error: 10.1988
# Epoch 10/35
# 1366/1366 [==============================] - 18s 13ms/step - loss: 10.5174 - mean_absolute_error: 10.5174 - val_loss: 10.1867 - val_mean_absolute_error: 10.1867
# Epoch 11/35
# 1366/1366 [==============================] - 24s 17ms/step - loss: 10.4288 - mean_absolute_error: 10.4288 - val_loss: 10.1059 - val_mean_absolute_error: 10.1059
# Epoch 12/35
# 1366/1366 [==============================] - 18s 13ms/step - loss: 10.3497 - mean_absolute_error: 10.3497 - val_loss: 10.0412 - val_mean_absolute_error: 10.0412
# Epoch 13/35
# 1366/1366 [==============================] - 18s 13ms/step - loss: 10.2812 - mean_absolute_error: 10.2812 - val_loss: 10.0190 - val_mean_absolute_error: 10.0190
# Epoch 14/35
# 1366/1366 [==============================] - 23s 17ms/step - loss: 10.2175 - mean_absolute_error: 10.2175 - val_loss: 9.9180 - val_mean_absolute_error: 9.9180
# Epoch 15/35
# 1366/1366 [==============================] - 18s 13ms/step - loss: 10.1625 - mean_absolute_error: 10.1625 - val_loss: 9.7716 - val_mean_absolute_error: 9.7716
# Epoch 16/35
# 1366/1366 [==============================] - 18s 13ms/step - loss: 10.1105 - mean_absolute_error: 10.1105 - val_loss: 9.7392 - val_mean_absolute_error: 9.7392
# Epoch 17/35
# 1366/1366 [==============================] - 23s 17ms/step - loss: 10.0626 - mean_absolute_error: 10.0626 - val_loss: 9.7706 - val_mean_absolute_error: 9.7706
# Epoch 18/35
# 1366/1366 [==============================] - 18s 13ms/step - loss: 10.0194 - mean_absolute_error: 10.0194 - val_loss: 9.6279 - val_mean_absolute_error: 9.6279
# Epoch 19/35
# 1366/1366 [==============================] - 18s 13ms/step - loss: 9.9742 - mean_absolute_error: 9.9742 - val_loss: 9.6860 - val_mean_absolute_error: 9.6860
# Epoch 20/35
# 1366/1366 [==============================] - 24s 17ms/step - loss: 9.9330 - mean_absolute_error: 9.9330 - val_loss: 9.6191 - val_mean_absolute_error: 9.6191
# Epoch 21/35
# 1366/1366 [==============================] - 17s 13ms/step - loss: 9.8924 - mean_absolute_error: 9.8924 - val_loss: 9.5942 - val_mean_absolute_error: 9.5942
# Epoch 22/35
# 1366/1366 [==============================] - 18s 13ms/step - loss: 9.8523 - mean_absolute_error: 9.8523 - val_loss: 9.5306 - val_mean_absolute_error: 9.5306
# Epoch 23/35
# 1366/1366 [==============================] - 23s 17ms/step - loss: 9.8156 - mean_absolute_error: 9.8156 - val_loss: 9.5197 - val_mean_absolute_error: 9.5197
# Epoch 24/35
# 1366/1366 [==============================] - 17s 13ms/step - loss: 9.7803 - mean_absolute_error: 9.7803 - val_loss: 9.4694 - val_mean_absolute_error: 9.4694
# Epoch 25/35
# 1366/1366 [==============================] - 17s 13ms/step - loss: 9.7486 - mean_absolute_error: 9.7486 - val_loss: 9.4506 - val_mean_absolute_error: 9.4506
# Epoch 26/35
# 1366/1366 [==============================] - 23s 17ms/step - loss: 9.7185 - mean_absolute_error: 9.7185 - val_loss: 9.3713 - val_mean_absolute_error: 9.3713
# Epoch 27/35
# 1366/1366 [==============================] - 18s 13ms/step - loss: 9.6840 - mean_absolute_error: 9.6840 - val_loss: 9.3583 - val_mean_absolute_error: 9.3583
# Epoch 28/35
# 1366/1366 [==============================] - 17s 13ms/step - loss: 9.6515 - mean_absolute_error: 9.6515 - val_loss: 9.3354 - val_mean_absolute_error: 9.3354
# Epoch 29/35
# 1366/1366 [==============================] - 23s 17ms/step - loss: 9.6249 - mean_absolute_error: 9.6249 - val_loss: 9.3458 - val_mean_absolute_error: 9.3458
# Epoch 30/35
# 1366/1366 [==============================] - 18s 13ms/step - loss: 9.5918 - mean_absolute_error: 9.5918 - val_loss: 9.3342 - val_mean_absolute_error: 9.3342
# Epoch 31/35
# 1366/1366 [==============================] - 18s 13ms/step - loss: 9.5647 - mean_absolute_error: 9.5647 - val_loss: 9.2701 - val_mean_absolute_error: 9.2701
# Epoch 32/35
# 1366/1366 [==============================] - 22s 16ms/step - loss: 9.5454 - mean_absolute_error: 9.5454 - val_loss: 9.2801 - val_mean_absolute_error: 9.2801
# Epoch 33/35
# 1366/1366 [==============================] - 19s 14ms/step - loss: 9.5134 - mean_absolute_error: 9.5134 - val_loss: 9.3309 - val_mean_absolute_error: 9.3309
# Epoch 34/35
# 1366/1366 [==============================] - 18s 13ms/step - loss: 9.4888 - mean_absolute_error: 9.4888 - val_loss: 9.1984 - val_mean_absolute_error: 9.1984
# Epoch 35/35
# 1366/1366 [==============================] - 20s 14ms/step - loss: 9.4620 - mean_absolute_error: 9.4620 - val_loss: 9.2056 - val_mean_absolute_error: 9.2056

# %%
results = pd.DataFrame(columns=['cutoff', 'MAE'])
for key, model in experiment_models.items():
    predictions = model.predict(x_test, batch_size=BATCH_SIZE)
    results = results.append({'cutoff':key, 
                   'MAE': round(np.mean(np.abs(np.array(y_test) - np.array(predictions).reshape(-1,))), 3)},
                   ignore_index=True)

# %%
results
# Out:
#        cutoff    MAE
# 0  2022-09-01 10.528
# 1  2022-11-01 10.988
# 2  2022-12-01 11.360

# %% [markdown]
# <b>Testing 3 cutoffs: </b>
#
# ['2022-09-01': 5 months,
# '2022-11-01': 3 months,
# '2022-12-01': 2 months]
#
# UNshuffled

# %%
experiment_models_unshuffled = {}

for i, cutoff in enumerate(cutoffs):
    print(f'Running model for cutoff on {cutoff} onwards')
    cutoff_idx = indices[i]
    new_x_train = [x[cutoff_idx:] for x in x_train]
    new_y_train = y_train[cutoff_idx:]
   
    # Normalization layer for the trade history
    trade_history_normalizer = Normalization(name='Trade_history_normalizer')
    trade_history_normalizer.adapt(new_x_train[0],batch_size=BATCH_SIZE)

    # Normalization layer for the non-categorical and binary features
    noncat_binary_normalizer = Normalization(name='Numerical_binary_normalizer')
    noncat_binary_normalizer.adapt(new_x_train[2], batch_size = BATCH_SIZE)
    
    temp_model = train_model(new_x_train, new_y_train, False)
    
    experiment_models_unshuffled[cutoff] = temp_model
    print('\n\n')
# Out:
# Running model for cutoff on 2022-09-01 onwards

# %%
results_unshuffled = pd.DataFrame(columns=['cutoff', 'MAE'])
for key, model in experiment_models_unshuffled.items():
    predictions = model.predict(x_test, batch_size=BATCH_SIZE)
    results_unshuffled = results_unshuffled.append({'cutoff':key, 
                   'MAE': round(np.mean(np.abs(np.array(y_test) - np.array(predictions).reshape(-1,))), 3)},
                   ignore_index=True)

# %%
results_unshuffled
# Out:
#        cutoff    MAE
# 0  2022-09-01 13.144
# 1  2022-11-01 12.699
# 2  2022-12-01 12.255

# %% [markdown]
# <b>Testing 3 cutoffs: </b>
#
# ['2022-09-01': 5 months,
# '2022-11-01': 3 months,
# '2022-12-01': 2 months]
#
# 50% Shuffle Buffer

# %%
import logging

logging.basicConfig(filename='app.log', filemode='w', format='%(name)s - %(levelname)s - %(message)s')
logging.warning('This will get logged to a file')

# %%
experiment_models_partially_shuffled = {}

for i, cutoff in enumerate(cutoffs):
    print(f'Running model for cutoff on {cutoff} onwards')
    cutoff_idx = indices[i]
    new_x_train = [x[cutoff_idx:] for x in x_train]
    new_y_train = y_train[cutoff_idx:]
   
    # Normalization layer for the trade history
    trade_history_normalizer = Normalization(name='Trade_history_normalizer')
    trade_history_normalizer.adapt(new_x_train[0],batch_size=BATCH_SIZE)

    # Normalization layer for the non-categorical and binary features
    noncat_binary_normalizer = Normalization(name='Numerical_binary_normalizer')
    noncat_binary_normalizer.adapt(new_x_train[2], batch_size = BATCH_SIZE)
    
    temp_model = train_model(new_x_train, new_y_train, True, 0.5)
    
    experiment_models_partially_shuffled[cutoff] = temp_model
    print('\n\n')
# Out:
# Running model for cutoff on 2022-09-01 onwards
# Epoch 1/35
# 2023-04-26 06:23:30.810145: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 1083302 of 2212912
# 2023-04-26 06:23:40.810138: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 2165214 of 2212912
#    1/3541 [..............................] - ETA: 24:11:23 - loss: 52.4213 - mean_absolute_error: 52.4213
# 2023-04-26 06:23:41.249566: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:405] Shuffle buffer filled.
# 3541/3541 [==============================] - ETA: 0s - loss: 40.8235 - mean_absolute_error: 40.8235
# 2023-04-26 06:25:11.683213: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 556359 of 2212912
# 2023-04-26 06:25:21.683208: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 1633948 of 2212912
# 2023-04-26 06:25:27.026515: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:405] Shuffle buffer filled.
# 3541/3541 [==============================] - 189s 46ms/step - loss: 40.8235 - mean_absolute_error: 40.8235 - val_loss: 27.4347 - val_mean_absolute_error: 27.4347
# Epoch 2/35
# 3541/3541 [==============================] - 51s 14ms/step - loss: 13.9925 - mean_absolute_error: 13.9925 - val_loss: 10.8950 - val_mean_absolute_error: 10.8950
# Epoch 3/35
# 3541/3541 [==============================] - 46s 13ms/step - loss: 10.9872 - mean_absolute_error: 10.9872 - val_loss: 10.4724 - val_mean_absolute_error: 10.4724
# Epoch 4/35
# 3541/3541 [==============================] - 49s 14ms/step - loss: 10.6564 - mean_absolute_error: 10.6564 - val_loss: 10.2290 - val_mean_absolute_error: 10.2290
# Epoch 5/35
# 3541/3541 [==============================] - 51s 14ms/step - loss: 10.4697 - mean_absolute_error: 10.4697 - val_loss: 10.0442 - val_mean_absolute_error: 10.0442
# Epoch 6/35
# 3541/3541 [==============================] - 50s 14ms/step - loss: 10.3354 - mean_absolute_error: 10.3354 - val_loss: 9.9358 - val_mean_absolute_error: 9.9358
# Epoch 7/35
# 3541/3541 [==============================] - 50s 14ms/step - loss: 10.2259 - mean_absolute_error: 10.2259 - val_loss: 9.8308 - val_mean_absolute_error: 9.8308
# Epoch 8/35
# 3541/3541 [==============================] - 50s 14ms/step - loss: 10.1350 - mean_absolute_error: 10.1350 - val_loss: 9.7326 - val_mean_absolute_error: 9.7326
# Epoch 9/35
# 3541/3541 [==============================] - 45s 13ms/step - loss: 10.0612 - mean_absolute_error: 10.0612 - val_loss: 9.6827 - val_mean_absolute_error: 9.6827
# Epoch 10/35
# 3541/3541 [==============================] - 49s 14ms/step - loss: 9.9937 - mean_absolute_error: 9.9937 - val_loss: 9.6715 - val_mean_absolute_error: 9.6715
# Epoch 11/35
# 3541/3541 [==============================] - 50s 14ms/step - loss: 9.9313 - mean_absolute_error: 9.9313 - val_loss: 9.5974 - val_mean_absolute_error: 9.5974
# Epoch 12/35
# 3541/3541 [==============================] - 50s 14ms/step - loss: 9.8823 - mean_absolute_error: 9.8823 - val_loss: 9.5337 - val_mean_absolute_error: 9.5337
# Epoch 13/35
# 3541/3541 [==============================] - 50s 14ms/step - loss: 9.8313 - mean_absolute_error: 9.8313 - val_loss: 9.5051 - val_mean_absolute_error: 9.5051
# Epoch 14/35
# 3541/3541 [==============================] - 51s 14ms/step - loss: 9.7861 - mean_absolute_error: 9.7861 - val_loss: 9.4612 - val_mean_absolute_error: 9.4612
# Epoch 15/35
# 3541/3541 [==============================] - 45s 13ms/step - loss: 9.7440 - mean_absolute_error: 9.7440 - val_loss: 9.4594 - val_mean_absolute_error: 9.4594
# Epoch 16/35
# 3541/3541 [==============================] - 50s 14ms/step - loss: 9.7058 - mean_absolute_error: 9.7058 - val_loss: 9.3814 - val_mean_absolute_error: 9.3814
# Epoch 17/35
# 3541/3541 [==============================] - 50s 14ms/step - loss: 9.6678 - mean_absolute_error: 9.6678 - val_loss: 9.3584 - val_mean_absolute_error: 9.3584
# Epoch 18/35
# 3541/3541 [==============================] - 50s 14ms/step - loss: 9.6286 - mean_absolute_error: 9.6286 - val_loss: 9.3614 - val_mean_absolute_error: 9.3614
# Epoch 19/35
# 3541/3541 [==============================] - 50s 14ms/step - loss: 9.6000 - mean_absolute_error: 9.6000 - val_loss: 9.3469 - val_mean_absolute_error: 9.3469
# Epoch 20/35
# 3541/3541 [==============================] - 52s 15ms/step - loss: 9.5683 - mean_absolute_error: 9.5683 - val_loss: 9.2652 - val_mean_absolute_error: 9.2652
# Epoch 21/35
# 3541/3541 [==============================] - 46s 13ms/step - loss: 9.5379 - mean_absolute_error: 9.5379 - val_loss: 9.2728 - val_mean_absolute_error: 9.2728
# Epoch 22/35
# 3541/3541 [==============================] - 50s 14ms/step - loss: 9.5097 - mean_absolute_error: 9.5097 - val_loss: 9.2424 - val_mean_absolute_error: 9.2424
# Epoch 23/35
# 3541/3541 [==============================] - 51s 14ms/step - loss: 9.4806 - mean_absolute_error: 9.4806 - val_loss: 9.1991 - val_mean_absolute_error: 9.1991
# Epoch 24/35
# 3541/3541 [==============================] - 50s 14ms/step - loss: 9.4523 - mean_absolute_error: 9.4523 - val_loss: 9.1831 - val_mean_absolute_error: 9.1831
# Epoch 25/35
# 3541/3541 [==============================] - 44s 12ms/step - loss: 9.4305 - mean_absolute_error: 9.4305 - val_loss: 9.1644 - val_mean_absolute_error: 9.1644
# Epoch 26/35
# 3541/3541 [==============================] - 50s 14ms/step - loss: 9.4054 - mean_absolute_error: 9.4054 - val_loss: 9.1960 - val_mean_absolute_error: 9.1960
# Epoch 27/35
# 3541/3541 [==============================] - 50s 14ms/step - loss: 9.3827 - mean_absolute_error: 9.3827 - val_loss: 9.1297 - val_mean_absolute_error: 9.1297
# Epoch 28/35
# 3541/3541 [==============================] - 50s 14ms/step - loss: 9.3573 - mean_absolute_error: 9.3573 - val_loss: 9.1337 - val_mean_absolute_error: 9.1337
# Epoch 29/35
# 3541/3541 [==============================] - 51s 14ms/step - loss: 9.3376 - mean_absolute_error: 9.3376 - val_loss: 9.0968 - val_mean_absolute_error: 9.0968
# Epoch 30/35
# 3541/3541 [==============================] - 50s 14ms/step - loss: 9.3193 - mean_absolute_error: 9.3193 - val_loss: 9.0348 - val_mean_absolute_error: 9.0348
# Epoch 31/35
# 3541/3541 [==============================] - 44s 12ms/step - loss: 9.2989 - mean_absolute_error: 9.2989 - val_loss: 9.0678 - val_mean_absolute_error: 9.0678
# Epoch 32/35
# 3541/3541 [==============================] - 51s 14ms/step - loss: 9.2785 - mean_absolute_error: 9.2785 - val_loss: 9.0241 - val_mean_absolute_error: 9.0241
# Epoch 33/35
# 3541/3541 [==============================] - 51s 14ms/step - loss: 9.2595 - mean_absolute_error: 9.2595 - val_loss: 8.9976 - val_mean_absolute_error: 8.9976
# Epoch 34/35
# 3541/3541 [==============================] - 50s 14ms/step - loss: 9.2435 - mean_absolute_error: 9.2435 - val_loss: 8.9738 - val_mean_absolute_error: 8.9738
# Epoch 35/35
# 3541/3541 [==============================] - 50s 14ms/step - loss: 9.2244 - mean_absolute_error: 9.2244 - val_loss: 8.9934 - val_mean_absolute_error: 8.9934
#
#
#
# Running model for cutoff on 2022-11-01 onwards
# Epoch 1/35
# 2023-04-26 06:55:43.178720: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 1091271 of 1365769
#    5/2186 [..............................] - ETA: 29s - loss: 52.2220 - mean_absolute_error: 52.2220
# 2023-04-26 06:55:45.682214: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:405] Shuffle buffer filled.
# 2186/2186 [==============================] - ETA: 0s - loss: 49.7469 - mean_absolute_error: 49.7469
# 2023-04-26 06:56:46.778473: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 1092857 of 1365769
# 2023-04-26 06:56:49.277211: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:405] Shuffle buffer filled.
# 2186/2186 [==============================] - 117s 46ms/step - loss: 49.7469 - mean_absolute_error: 49.7469 - val_loss: 41.7958 - val_mean_absolute_error: 41.7958
# Epoch 2/35
# 2186/2186 [==============================] - 28s 13ms/step - loss: 31.8769 - mean_absolute_error: 31.8769 - val_loss: 20.6606 - val_mean_absolute_error: 20.6606
# Epoch 3/35
# 2186/2186 [==============================] - 34s 15ms/step - loss: 13.5388 - mean_absolute_error: 13.5388 - val_loss: 10.9443 - val_mean_absolute_error: 10.9443
# Epoch 4/35
# 2186/2186 [==============================] - 28s 13ms/step - loss: 11.1458 - mean_absolute_error: 11.1458 - val_loss: 10.4969 - val_mean_absolute_error: 10.4969
# Epoch 5/35
# 2186/2186 [==============================] - 34s 15ms/step - loss: 10.8709 - mean_absolute_error: 10.8709 - val_loss: 10.3278 - val_mean_absolute_error: 10.3278
# Epoch 6/35
# 2186/2186 [==============================] - 27s 12ms/step - loss: 10.6931 - mean_absolute_error: 10.6931 - val_loss: 10.1870 - val_mean_absolute_error: 10.1870
# Epoch 7/35
# 2186/2186 [==============================] - 34s 16ms/step - loss: 10.5608 - mean_absolute_error: 10.5608 - val_loss: 10.1502 - val_mean_absolute_error: 10.1502
# Epoch 8/35
# 2186/2186 [==============================] - 28s 13ms/step - loss: 10.4503 - mean_absolute_error: 10.4503 - val_loss: 10.0375 - val_mean_absolute_error: 10.0375
# Epoch 9/35
# 2186/2186 [==============================] - 33s 15ms/step - loss: 10.3595 - mean_absolute_error: 10.3595 - val_loss: 9.9920 - val_mean_absolute_error: 9.9920
# Epoch 10/35
# 2186/2186 [==============================] - 31s 14ms/step - loss: 10.2782 - mean_absolute_error: 10.2782 - val_loss: 10.0510 - val_mean_absolute_error: 10.0510
# Epoch 11/35
# 2186/2186 [==============================] - 31s 14ms/step - loss: 10.2073 - mean_absolute_error: 10.2073 - val_loss: 9.8103 - val_mean_absolute_error: 9.8103
# Epoch 12/35
# 2186/2186 [==============================] - 33s 15ms/step - loss: 10.1463 - mean_absolute_error: 10.1463 - val_loss: 9.8912 - val_mean_absolute_error: 9.8912
# Epoch 13/35
# 2186/2186 [==============================] - 29s 13ms/step - loss: 10.0850 - mean_absolute_error: 10.0850 - val_loss: 9.7779 - val_mean_absolute_error: 9.7779
# Epoch 14/35
# 2186/2186 [==============================] - 35s 16ms/step - loss: 10.0346 - mean_absolute_error: 10.0346 - val_loss: 9.8009 - val_mean_absolute_error: 9.8009
# Epoch 15/35
# 2186/2186 [==============================] - 28s 13ms/step - loss: 9.9919 - mean_absolute_error: 9.9919 - val_loss: 9.6495 - val_mean_absolute_error: 9.6495
# Epoch 16/35
# 2186/2186 [==============================] - 34s 15ms/step - loss: 9.9432 - mean_absolute_error: 9.9432 - val_loss: 9.6445 - val_mean_absolute_error: 9.6445
# Epoch 17/35
# 2186/2186 [==============================] - 29s 13ms/step - loss: 9.9010 - mean_absolute_error: 9.9010 - val_loss: 9.6960 - val_mean_absolute_error: 9.6960
# Epoch 18/35
# 2186/2186 [==============================] - 35s 16ms/step - loss: 9.8650 - mean_absolute_error: 9.8650 - val_loss: 9.5993 - val_mean_absolute_error: 9.5993
# Epoch 19/35
# 2186/2186 [==============================] - 28s 13ms/step - loss: 9.8271 - mean_absolute_error: 9.8271 - val_loss: 9.6095 - val_mean_absolute_error: 9.6095
# Epoch 20/35
# 2186/2186 [==============================] - 34s 16ms/step - loss: 9.7916 - mean_absolute_error: 9.7916 - val_loss: 9.5003 - val_mean_absolute_error: 9.5003
# Epoch 21/35
# 2186/2186 [==============================] - 28s 13ms/step - loss: 9.7544 - mean_absolute_error: 9.7544 - val_loss: 9.5304 - val_mean_absolute_error: 9.5304
# Epoch 22/35
# 2186/2186 [==============================] - 34s 15ms/step - loss: 9.7233 - mean_absolute_error: 9.7233 - val_loss: 9.4313 - val_mean_absolute_error: 9.4313
# Epoch 23/35
# 2186/2186 [==============================] - 30s 14ms/step - loss: 9.6896 - mean_absolute_error: 9.6896 - val_loss: 9.3753 - val_mean_absolute_error: 9.3753
# Epoch 24/35
# 2186/2186 [==============================] - 28s 13ms/step - loss: 9.6646 - mean_absolute_error: 9.6646 - val_loss: 9.4176 - val_mean_absolute_error: 9.4176
# Epoch 25/35
# 2186/2186 [==============================] - 33s 15ms/step - loss: 9.6375 - mean_absolute_error: 9.6375 - val_loss: 9.4487 - val_mean_absolute_error: 9.4487
# Epoch 26/35
# 2186/2186 [==============================] - 27s 12ms/step - loss: 9.6090 - mean_absolute_error: 9.6090 - val_loss: 9.3999 - val_mean_absolute_error: 9.3999
# Epoch 27/35
# 2186/2186 [==============================] - 34s 15ms/step - loss: 9.5817 - mean_absolute_error: 9.5817 - val_loss: 9.3258 - val_mean_absolute_error: 9.3258
# Epoch 28/35
# 2186/2186 [==============================] - 28s 13ms/step - loss: 9.5559 - mean_absolute_error: 9.5559 - val_loss: 9.3123 - val_mean_absolute_error: 9.3123
# Epoch 29/35
# 2186/2186 [==============================] - 33s 15ms/step - loss: 9.5278 - mean_absolute_error: 9.5278 - val_loss: 9.2740 - val_mean_absolute_error: 9.2740
# Epoch 30/35
# 2186/2186 [==============================] - 27s 13ms/step - loss: 9.5062 - mean_absolute_error: 9.5062 - val_loss: 9.2490 - val_mean_absolute_error: 9.2490
# Epoch 31/35
# 2186/2186 [==============================] - 33s 15ms/step - loss: 9.4853 - mean_absolute_error: 9.4853 - val_loss: 9.2094 - val_mean_absolute_error: 9.2094
# Epoch 32/35
# 2186/2186 [==============================] - 28s 13ms/step - loss: 9.4631 - mean_absolute_error: 9.4631 - val_loss: 9.2189 - val_mean_absolute_error: 9.2189
# Epoch 33/35
# 2186/2186 [==============================] - 33s 15ms/step - loss: 9.4417 - mean_absolute_error: 9.4417 - val_loss: 9.2085 - val_mean_absolute_error: 9.2085
# Epoch 34/35
# 2186/2186 [==============================] - 27s 12ms/step - loss: 9.4218 - mean_absolute_error: 9.4218 - val_loss: 9.2146 - val_mean_absolute_error: 9.2146
# Epoch 35/35
# 2186/2186 [==============================] - 33s 15ms/step - loss: 9.3996 - mean_absolute_error: 9.3996 - val_loss: 9.1412 - val_mean_absolute_error: 9.1412
#
#
#
# Running model for cutoff on 2022-12-01 onwards
# Epoch 1/35
# 1366/1366 [==============================] - 73s 45ms/step - loss: 56.2326 - mean_absolute_error: 56.2326 - val_loss: 53.1337 - val_mean_absolute_error: 53.1337
# Epoch 2/35
# 1366/1366 [==============================] - 20s 14ms/step - loss: 48.0055 - mean_absolute_error: 48.0055 - val_loss: 41.1928 - val_mean_absolute_error: 41.1928
# Epoch 3/35
# 1366/1366 [==============================] - 20s 15ms/step - loss: 34.3155 - mean_absolute_error: 34.3155 - val_loss: 29.2811 - val_mean_absolute_error: 29.2811
# Epoch 4/35
# 1366/1366 [==============================] - 17s 12ms/step - loss: 19.1518 - mean_absolute_error: 19.1518 - val_loss: 14.0052 - val_mean_absolute_error: 14.0052
# Epoch 5/35
# 1366/1366 [==============================] - 17s 12ms/step - loss: 12.0602 - mean_absolute_error: 12.0602 - val_loss: 10.8335 - val_mean_absolute_error: 10.8335
# Epoch 6/35
# 1366/1366 [==============================] - 21s 15ms/step - loss: 11.2134 - mean_absolute_error: 11.2134 - val_loss: 10.5290 - val_mean_absolute_error: 10.5290
# Epoch 7/35
# 1366/1366 [==============================] - 17s 12ms/step - loss: 10.9919 - mean_absolute_error: 10.9919 - val_loss: 10.3411 - val_mean_absolute_error: 10.3411
# Epoch 8/35
# 1366/1366 [==============================] - 17s 13ms/step - loss: 10.8361 - mean_absolute_error: 10.8361 - val_loss: 10.2687 - val_mean_absolute_error: 10.2687
# Epoch 9/35
# 1366/1366 [==============================] - 23s 17ms/step - loss: 10.7144 - mean_absolute_error: 10.7144 - val_loss: 10.1882 - val_mean_absolute_error: 10.1882
# Epoch 10/35
# 1366/1366 [==============================] - 17s 13ms/step - loss: 10.6080 - mean_absolute_error: 10.6080 - val_loss: 10.0997 - val_mean_absolute_error: 10.0997
# Epoch 11/35
# 1366/1366 [==============================] - 17s 13ms/step - loss: 10.5213 - mean_absolute_error: 10.5213 - val_loss: 10.0190 - val_mean_absolute_error: 10.0190
# Epoch 12/35
# 1366/1366 [==============================] - 23s 17ms/step - loss: 10.4462 - mean_absolute_error: 10.4462 - val_loss: 9.8937 - val_mean_absolute_error: 9.8937
# Epoch 13/35
# 1366/1366 [==============================] - 17s 13ms/step - loss: 10.3774 - mean_absolute_error: 10.3774 - val_loss: 9.8185 - val_mean_absolute_error: 9.8185
# Epoch 14/35
# 1366/1366 [==============================] - 17s 13ms/step - loss: 10.3195 - mean_absolute_error: 10.3195 - val_loss: 9.7409 - val_mean_absolute_error: 9.7409
# Epoch 15/35
# 1366/1366 [==============================] - 23s 17ms/step - loss: 10.2576 - mean_absolute_error: 10.2576 - val_loss: 9.7870 - val_mean_absolute_error: 9.7870
# Epoch 16/35
# 1366/1366 [==============================] - 17s 13ms/step - loss: 10.1984 - mean_absolute_error: 10.1984 - val_loss: 9.6766 - val_mean_absolute_error: 9.6766
# Epoch 17/35
# 1366/1366 [==============================] - 17s 13ms/step - loss: 10.1480 - mean_absolute_error: 10.1480 - val_loss: 9.6056 - val_mean_absolute_error: 9.6056
# Epoch 18/35
# 1366/1366 [==============================] - 23s 17ms/step - loss: 10.1081 - mean_absolute_error: 10.1081 - val_loss: 9.5834 - val_mean_absolute_error: 9.5834
# Epoch 19/35
# 1366/1366 [==============================] - 17s 12ms/step - loss: 10.0574 - mean_absolute_error: 10.0574 - val_loss: 9.5770 - val_mean_absolute_error: 9.5770
# Epoch 20/35
# 1366/1366 [==============================] - 17s 12ms/step - loss: 10.0128 - mean_absolute_error: 10.0128 - val_loss: 9.5049 - val_mean_absolute_error: 9.5049
# Epoch 21/35
# 1366/1366 [==============================] - 23s 17ms/step - loss: 9.9753 - mean_absolute_error: 9.9753 - val_loss: 9.4202 - val_mean_absolute_error: 9.4202
# Epoch 22/35
# 1366/1366 [==============================] - 17s 13ms/step - loss: 9.9398 - mean_absolute_error: 9.9398 - val_loss: 9.4077 - val_mean_absolute_error: 9.4077
# Epoch 23/35
# 1366/1366 [==============================] - 18s 13ms/step - loss: 9.9020 - mean_absolute_error: 9.9020 - val_loss: 9.3761 - val_mean_absolute_error: 9.3761
# Epoch 24/35
# 1366/1366 [==============================] - 23s 17ms/step - loss: 9.8667 - mean_absolute_error: 9.8667 - val_loss: 9.3348 - val_mean_absolute_error: 9.3348
# Epoch 25/35
# 1366/1366 [==============================] - 17s 13ms/step - loss: 9.8302 - mean_absolute_error: 9.8302 - val_loss: 9.3287 - val_mean_absolute_error: 9.3287
# Epoch 26/35
# 1366/1366 [==============================] - 17s 13ms/step - loss: 9.7974 - mean_absolute_error: 9.7974 - val_loss: 9.2910 - val_mean_absolute_error: 9.2910
# Epoch 27/35
# 1366/1366 [==============================] - 23s 17ms/step - loss: 9.7684 - mean_absolute_error: 9.7684 - val_loss: 9.2733 - val_mean_absolute_error: 9.2733
# Epoch 28/35
# 1366/1366 [==============================] - 17s 12ms/step - loss: 9.7354 - mean_absolute_error: 9.7354 - val_loss: 9.2314 - val_mean_absolute_error: 9.2314
# Epoch 29/35
# 1366/1366 [==============================] - 17s 12ms/step - loss: 9.7047 - mean_absolute_error: 9.7047 - val_loss: 9.1947 - val_mean_absolute_error: 9.1947
# Epoch 30/35
# 1366/1366 [==============================] - 23s 17ms/step - loss: 9.6771 - mean_absolute_error: 9.6771 - val_loss: 9.2073 - val_mean_absolute_error: 9.2073
# Epoch 31/35
# 1366/1366 [==============================] - 17s 12ms/step - loss: 9.6473 - mean_absolute_error: 9.6473 - val_loss: 9.1520 - val_mean_absolute_error: 9.1520
# Epoch 32/35
# 1366/1366 [==============================] - 17s 12ms/step - loss: 9.6189 - mean_absolute_error: 9.6189 - val_loss: 9.1705 - val_mean_absolute_error: 9.1705
# Epoch 33/35
# 1366/1366 [==============================] - 19s 14ms/step - loss: 9.5917 - mean_absolute_error: 9.5917 - val_loss: 9.1497 - val_mean_absolute_error: 9.1497
# Epoch 34/35
# 1366/1366 [==============================] - 19s 14ms/step - loss: 9.5733 - mean_absolute_error: 9.5733 - val_loss: 9.0603 - val_mean_absolute_error: 9.0603
# Epoch 35/35
# 1366/1366 [==============================] - 17s 13ms/step - loss: 9.5436 - mean_absolute_error: 9.5436 - val_loss: 9.0574 - val_mean_absolute_error: 9.0574

# %%
results_partially_shuffled = pd.DataFrame(columns=['cutoff', 'MAE'])
for key, model in experiment_models_partially_shuffled.items():
    predictions = model.predict(x_test, batch_size=BATCH_SIZE)
    results_partially_shuffled = results_partially_shuffled.append({'cutoff':key, 
                   'MAE': round(np.mean(np.abs(np.array(y_test) - np.array(predictions).reshape(-1,))), 3)},
          fit_callbacks   ignore_index=True)

# %%
results_partially_shuffled
# Out:
#        cutoff    MAE
# 0  2022-09-01 10.989
# 1  2022-11-01 10.998
# 2  2022-12-01 11.292

# %%
print('Unshuffled:')
display(results_unshuffled)
print('='*50)
print('Shuffled:')
display(results)
print('='*50)
print('Partially Shuffled:')
display(results_partially_shuffled)
# Out:
# Unshuffled:
#        cutoff    MAE
# 0  2022-09-01 13.144
# 1  2022-11-01 12.699
# 2  2022-12-01 12.255
# ==================================================
# Shuffled:
#        cutoff    MAE
# 0  2022-09-01 10.528
# 1  2022-11-01 10.988
# 2  2022-12-01 11.360
# ==================================================
# Partially Shuffled:
#        cutoff    MAE
# 0  2022-09-01 10.989
# 1  2022-11-01 10.998
# 2  2022-12-01 11.292
