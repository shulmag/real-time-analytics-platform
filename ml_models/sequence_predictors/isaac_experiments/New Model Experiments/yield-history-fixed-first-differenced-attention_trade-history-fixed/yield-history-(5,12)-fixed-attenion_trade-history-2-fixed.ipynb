# %% [markdown]
# TRADE HISTORY LENGTH 2, CORRECTLY ORDERED
#
# YIELD CURVE HISTORY 5MIN_12_AVERAGE , CORRECTLY ORDERED, WITH ATTENTION

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import time
import gc

import numpy as np
from google.cloud import bigquery
from google.cloud import storage

import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)


from tensorflow import keras
from tensorflow.keras import layers
import seaborn as sns
from pandas.tseries.offsets import BDay

from tensorflow.keras.layers import Embedding
from tensorflow.keras import activations
from tensorflow.keras import backend as K
from tensorflow.keras import initializers
from tensorflow.keras.layers.experimental.preprocessing import Normalization
from sklearn import preprocessing
from sklearn.metrics import mean_absolute_error
from datetime import datetime
import matplotlib.pyplot as plt
import pickle5 as pickle


from ficc.utils.nelson_siegel_model import *
from ficc.utils.diff_in_days import *
from ficc.utils.auxiliary_functions import sqltodf


from IPython.display import display, HTML
import os


from ficc.data.process_data import process_data
from ficc.utils.auxiliary_variables import PREDICTORS, NON_CAT_FEATURES, BINARY, CATEGORICAL_FEATURES, IDENTIFIERS, PURPOSE_CLASS_DICT, NUM_OF_DAYS_IN_YEAR
from ficc.utils.gcp_storage_functions import upload_data, download_data
from ficc.utils.auxiliary_variables import RELATED_TRADE_BINARY_FEATURES, RELATED_TRADE_NON_CAT_FEATURES, RELATED_TRADE_CATEGORICAL_FEATURES

import sys
sys.path.append('../../')
from ficc_keras_utils import *
import ficc_keras_utils

pd.set_option('display.float_format', lambda x: '%.3f' % x)
print(f'TF Version: {tf.__version__}')
# Out:
# 2023-05-16 17:22:40.728333: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 17:22:40.859667: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 17:22:40.861382: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# Initializing pandarallel with 16.0 cores
# INFO: Pandarallel will run on 16 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# TF Version: 2.7.0

# %%
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="/home/jupyter/ficc/isaac_creds.json"
os.environ['TF_GPU_THREAD_MODE'] = 'gpu_private'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
pd.options.mode.chained_assignment = None

bq_client = bigquery.Client()
storage_client = storage.Client()

##COMMON VARIABLES
#DATA WINDOW
train_start = ficc_keras_utils.train_start
train_end = ficc_keras_utils.train_end
test_start = ficc_keras_utils.test_start
test_end = ficc_keras_utils.test_end
#MODEL PARAMETERS 
VALIDATION_SPLIT = ficc_keras_utils.VALIDATION_SPLIT
LEARNING_RATE = ficc_keras_utils.LEARNING_RATE
BATCH_SIZE = ficc_keras_utils.BATCH_SIZE
NUM_EPOCHS = ficc_keras_utils.NUM_EPOCHS
DROPOUT = ficc_keras_utils.DROPOUT

##NOTEBOOK SPECIFIC VARIABLES 
TRADE_SEQUENCE_LENGTH = 2
YIELD_SEQUENCE_LENGTH = 11
NUM_FEATURES = 6
# target_variable = 'new_ys_diff'
target_variable = 'new_ys'

# %%
print(train_start ,
train_end ,
test_start ,
test_end)
# Out:
# 2023-01-01 2023-03-01 2023-03-01 2023-04-01

# %%
processed_data = pd.read_pickle('../../processed_data-2023-05-12.pkl')

# %%
additional_features = ['ttypes', 'diff_size', 'abs_last_yield_spread', 'abs_diff_size', 'days_duration']
YS_COLS = ['max_ys_ys', 'max_ys_ttypes', 'max_ys_ago', 'max_ys_qdiff', 'min_ys_ys', 'min_ys_ttypes', 'min_ys_ago', 'min_ys_qdiff', 'max_qty_ys', 'max_qty_ttypes', \
           'max_qty_ago', 'max_qty_qdiff', 'min_ago_ys', 'min_ago_ttypes', 'min_ago_ago', 'min_ago_qdiff', 'D_min_ago_ys', 'D_min_ago_ttypes', 'D_min_ago_ago', 'D_min_ago_qdiff',\
           'P_min_ago_ys', 'P_min_ago_ttypes', 'P_min_ago_ago', 'P_min_ago_qdiff', 'S_min_ago_ys', 'S_min_ago_ttypes', 'S_min_ago_ago', 'S_min_ago_qdiff']
encoders = {}
fmax = {}
for f in CATEGORICAL_FEATURES:
    print(f)
    if f in ['rating', 'incorporated_state_code', 'trade_type', 'purpose_class']:
        fprep = preprocessing.LabelEncoder().fit(categorical_feature_values[f])
    else:
        fprep = preprocessing.LabelEncoder().fit(processed_data[f].drop_duplicates())
    fmax[f] = np.max(fprep.transform(fprep.classes_))
    encoders[f] = fprep
    
with open('encoders.pkl','wb') as file:
    pickle.dump(encoders,file)
    
for col in YS_COLS:
    if 'ttypes' in col and col not in PREDICTORS:
        PREDICTORS.append(col)
        CATEGORICAL_FEATURES.append(col)
    elif col not in PREDICTORS:
        NON_CAT_FEATURES.append(col)
        PREDICTORS.append(col)
        
if 'target_attention_features' not in PREDICTORS:
    PREDICTORS.append('target_attention_features')
    
if 'ficc_treasury_spread' not in PREDICTORS:
    PREDICTORS.append('ficc_treasury_spread')
    NON_CAT_FEATURES.append('ficc_treasury_spread')
    
for col in ['new_ficc_ycl', 'new_real_time_ficc_ycl']:     
    if col not in PREDICTORS:
        PREDICTORS.append(col)
        NON_CAT_FEATURES.append(col)
# Out:
# rating
# incorporated_state_code
# trade_type
# purpose_class
# max_ys_ttypes
# min_ys_ttypes
# max_qty_ttypes
# min_ago_ttypes
# D_min_ago_ttypes
# P_min_ago_ttypes
# S_min_ago_ttypes

# %%
# %%time

processed_data['trade_history_shortened'] = processed_data['trade_history'].apply(lambda x: x[:TRADE_SEQUENCE_LENGTH])
# Out:
# CPU times: user 10.9 s, sys: 416 ms, total: 11.3 s
# Wall time: 11.3 s

# %%
# %%time

processed_data['trade_history_fixed'] = processed_data['trade_history_shortened'].apply(lambda x: x[::-1, :])
# Out:
# CPU times: user 10.7 s, sys: 271 ms, total: 11 s
# Wall time: 11 s

# %%
# %%time

processed_data['yield_curve_history_5min_12_averaged_first_differenced'] = processed_data['yield_curve_history_5min_12_averaged']\
.apply(lambda x: -np.diff(x))\
.apply(lambda x: x[::-1])
# Out:
# CPU times: user 32.2 s, sys: 0 ns, total: 32.2 s
# Wall time: 32.2 s

# %%
train_filter = (processed_data.trade_date < train_end) & (processed_data.trade_date >= train_start)
test_filter = (processed_data.trade_date >= test_start) & (processed_data.trade_date <test_end)
                                                            
train_dataframe = processed_data[train_filter]\
.sort_values(by='trade_date', ascending=True)\
.reset_index(drop=True)

test_dataframe = processed_data[test_filter]\
.sort_values(by='trade_date', ascending=True)\
.reset_index(drop=True)

print('Training data start: {}, end: {}'.format(train_dataframe.trade_date.min(),train_dataframe.trade_date.max()))
print('Test data start: {}, end: {}'.format(test_dataframe.trade_date.min(),test_dataframe.trade_date.max()))
# Out:
# Training data start: 2023-01-03 00:00:00, end: 2023-02-28 00:00:00
# Test data start: 2023-03-01 00:00:00, end: 2023-03-31 00:00:00

# %%
def create_input(df):
    global encoders
    datalist = []
    # datalist.append(np.stack(df['yield_curve_history_sq'].to_numpy()))
    # datalist.append(np.stack(df['yield_curve_history'].to_numpy()))
    # datalist.append(np.stack(df['yield_curve_history_fixed'].to_numpy()))
    # datalist.append(np.stack(df['yield_curve_history_5min_12_averaged_fixed'].to_numpy()))
    datalist.append(np.stack(df['yield_curve_history_5min_12_averaged_first_differenced'].to_numpy()))
    datalist.append(np.stack(df['trade_history_fixed'].to_numpy()))
    # datalist.append(np.stack(df['trade_history_shortened'].to_numpy()))
    datalist.append(np.stack(df['target_attention_features'].to_numpy()))

    noncat_and_binary = []
    for f in NON_CAT_FEATURES + BINARY:
        noncat_and_binary.append(np.expand_dims(df[f].to_numpy().astype('float32'), axis=1))
    datalist.append(np.concatenate(noncat_and_binary, axis=-1))
    
    for f in CATEGORICAL_FEATURES:
        encoded = encoders[f].transform(df[f])
        datalist.append(encoded.astype('float32'))
    
    return datalist

# %%
# %%time
np.random.seed(0)
val_idx = np.random.choice(range(len(train_dataframe)), 
                 size = int(VALIDATION_SPLIT*len(train_dataframe)),
                 replace=False)

print(f'TRAINING DATA: N = {len(train_dataframe)-len(val_idx)}, MIN DATE = {train_dataframe.drop(val_idx, axis=0).trade_date.min()}, MAX DATE = {train_dataframe.drop(val_idx, axis=0).trade_date.max()}')
print(f'VALIDATION DATA: N = {len(val_idx)}, MIN DATE = {train_dataframe.iloc[val_idx].trade_date.min()}, MAX DATE = {train_dataframe.iloc[val_idx].trade_date.max()}')
print(f'TEST DATA: N = {len(test_dataframe)}, MIN DATE = {test_dataframe.trade_date.min()}, MAX DATE = {test_dataframe.trade_date.max()}')

x_train = create_input(train_dataframe.drop(val_idx, axis=0))
y_train = train_dataframe.drop(val_idx, axis=0)[target_variable]

x_val = create_input(train_dataframe.iloc[val_idx])
y_val = train_dataframe.iloc[val_idx][target_variable]

x_test = create_input(test_dataframe)
y_test = test_dataframe[target_variable]
# Out:
# TRAINING DATA: N = 1070549, MIN DATE = 2023-01-03 00:00:00, MAX DATE = 2023-02-28 00:00:00
# VALIDATION DATA: N = 267637, MIN DATE = 2023-01-03 00:00:00, MAX DATE = 2023-02-28 00:00:00
# TEST DATA: N = 708432, MIN DATE = 2023-03-01 00:00:00, MAX DATE = 2023-03-31 00:00:00
# CPU times: user 23.9 s, sys: 1.45 s, total: 25.3 s
# Wall time: 25.4 s

# %% [markdown]
# ## Model Training and Testing

# %%
# Normalization layer for the yield history
yield_history_normalizer = Normalization(name='Yield_history_normalizer')
yield_history_normalizer.adapt(x_train[0],batch_size=BATCH_SIZE)

# Normalization layer for the trade history
trade_history_normalizer = Normalization(name='Trade_history_normalizer')
trade_history_normalizer.adapt(x_train[1],batch_size=BATCH_SIZE)

# Normalization layer for the non-categorical and binary features
noncat_binary_normalizer = Normalization(name='Numerical_binary_normalizer')
noncat_binary_normalizer.adapt(x_train[3], batch_size = BATCH_SIZE)

tf.keras.utils.set_random_seed(10)
# Out:
# 2023-05-16 17:30:22.950367: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-16 17:30:22.954670: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 17:30:22.958335: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 17:30:22.960990: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 17:30:29.993412: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 17:30:29.995285: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 17:30:29.996856: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-05-16 17:30:30.019587: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13594 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5

# %%
from keras.layers import LeakyReLU

def generate_model(TRADE_SEQUENCE_LENGTH = 5, YIELD_SEQUENCE_LENGTH = 12, NUM_FEATURES = NUM_FEATURES, trade_history_normalizer = trade_history_normalizer):
    inputs = []
    layer = []

    ############## INPUT BLOCK ###################
    yield_history_input = layers.Input(name="yield_curve_history_input", 
                                       # shape=(2, YIELD_SEQUENCE_LENGTH),
                                       shape=(YIELD_SEQUENCE_LENGTH, 1), 
                                       dtype = tf.float32) 
    
    trade_history_input = layers.Input(name="trade_history_input", 
                                       shape=(TRADE_SEQUENCE_LENGTH, NUM_FEATURES), 
                                       dtype = tf.float32) 

    target_attention_input = layers.Input(name="target_attention_input", 
                                       shape=(1, 3), 
                                       dtype = tf.float32) 

    inputs.append(yield_history_input)
    inputs.append(trade_history_input)
    inputs.append(target_attention_input)

    inputs.append(layers.Input(
        name="NON_CAT_AND_BINARY_FEATURES",
        shape=(len(NON_CAT_FEATURES + BINARY),)
    ))


    layer.append(noncat_binary_normalizer(inputs[3]))
    ####################################################


    ############## TRADE HISTORY MODEL #################

    lstm_layer = layers.Bidirectional(layers.LSTM(50, 
                             activation='tanh',
                             input_shape=(TRADE_SEQUENCE_LENGTH,NUM_FEATURES),
                             return_sequences = True,
                             name='LSTM'))

    lstm_layer_2 = layers.Bidirectional(layers.LSTM(100, 
                                                    activation='tanh',
                                                    input_shape=(TRADE_SEQUENCE_LENGTH, 50),
                                                    return_sequences = True,
                                                    name='LSTM_2'))



    features = lstm_layer(trade_history_normalizer(inputs[1]))
    features = lstm_layer_2(features)


    attention_sequence = layers.Dense(200, activation='relu', name='attention_dense')(target_attention_input)
    attention = layers.Dot(axes=[2, 2])([features, attention_sequence])
    attention = layers.Activation('softmax')(attention)

    context_vector = layers.Dot(axes=[1, 1])([features, attention])
    context_vector = layers.Flatten(name='context_vector_flatten')(context_vector)


    trade_history_output = layers.Dense(100, 
                                        activation='relu')(context_vector)

    ####################################################
    
    ############## YIELD HISTORY MODEL #################

    yield_lstm_layer = layers.Bidirectional(layers.LSTM(50, 
                             activation='tanh',
                             input_shape=(YIELD_SEQUENCE_LENGTH, 1),
                             return_sequences = True,
                             name='Yield_History_LSTM'))

    yield_features = yield_lstm_layer(yield_history_normalizer(inputs[0]))
    
    yield_attention_sequence = layers.Dense(100, activation='relu', name='yield_attention_dense')(target_attention_input)
    yield_attention_sequence = layers.Dot(axes=[2, 2])([yield_features, yield_attention_sequence])
    yield_attention_sequence = layers.Activation('softmax')(yield_attention_sequence)

    yield_context_vector = layers.Dot(axes=[1, 1])([yield_features, yield_attention_sequence])
    yield_context_vector = layers.Flatten(name='yield_context_vector_flatten')(yield_context_vector)


    yield_history_output = layers.Dense(25, 
                                        activation='relu')(yield_context_vector)

 
    ####################################################

    ############## REFERENCE DATA MODEL ################
    global encoders
    for f in CATEGORICAL_FEATURES:
        fin = layers.Input(shape=(1,), name = f)
        inputs.append(fin)
        embedded = layers.Flatten(name = f + "_flat")( layers.Embedding(input_dim = fmax[f]+1,
                                                                        output_dim = max(30,int(np.sqrt(fmax[f]))),
                                                                        input_length= 1,
                                                                        name = f + "_embed")(fin))
        layer.append(embedded)


    reference_hidden = layers.Dense(400,
                                    activation='relu',
                                    name='reference_hidden_1')(layers.concatenate(layer, axis=-1))

    reference_hidden = layers.BatchNormalization()(reference_hidden)
    reference_hidden = layers.Dropout(DROPOUT)(reference_hidden)

    reference_hidden2 = layers.Dense(200,activation='relu',name='reference_hidden_2')(reference_hidden)
    reference_hidden2 = layers.BatchNormalization()(reference_hidden2)
    reference_hidden2 = layers.Dropout(DROPOUT)(reference_hidden2)

    reference_output = layers.Dense(100,activation='tanh',name='reference_hidden_3')(reference_hidden2)

    ####################################################

    feed_forward_input = layers.concatenate([yield_history_output, reference_output, trade_history_output])

    hidden = layers.Dense(300,activation='relu')(feed_forward_input)
    hidden = layers.BatchNormalization()(hidden)
    hidden = layers.Dropout(DROPOUT)(hidden)

    hidden2 = layers.Dense(100,activation='relu')(hidden)
    hidden2 = layers.BatchNormalization()(hidden2)
    hidden2 = layers.Dropout(DROPOUT)(hidden2)
    final = layers.Dense(1)(hidden2)

    model = keras.Model(inputs=inputs, outputs=final)
    
    return model

def create_tf_data(x_train, y_train, shuffle=False, shuffle_buffer=1):
                     
    X=()
    for x in x_train:
        X += (tf.data.Dataset.from_tensor_slices(x),)
        

    temp = tf.data.Dataset.zip((X))
    del X
    dataset = tf.data.Dataset.zip((temp,
                        tf.data.Dataset.from_tensor_slices(y_train)))
    del temp
    if shuffle:
        shuffle_buffer = int(len(x_train[0])*shuffle_buffer)
        dataset = dataset.shuffle(shuffle_buffer)
        
    return dataset

# %%
def train_model(x_train, y_train, x_val, y_val, shuffle, shuffle_buffer=1):
    tf.keras.backend.clear_session()
    gc.collect()

    timestamp = datetime.now().strftime('%Y-%m-%d %H-%M')
    
    fit_callbacks = fit_callbacks = [
    keras.callbacks.EarlyStopping(
        monitor="val_loss",
        patience=10,
        verbose=0,
        mode="auto",
        restore_best_weights=True),
        # time_callback,
        CSVLoggerTimeHistory(timestamp+'_training_logs_yield_history.csv', separator=",", append=False)]
    
    with tf.device('/cpu:0'):
        train_ds = create_tf_data(x_train, y_train, shuffle, shuffle_buffer)
        train_ds = train_ds.batch(BATCH_SIZE).prefetch(2).cache()
        val_ds = create_tf_data(x_val, y_val, shuffle = False)
        val_ds = val_ds.batch(BATCH_SIZE).prefetch(2).cache()

    model_new_ys = generate_model(TRADE_SEQUENCE_LENGTH=TRADE_SEQUENCE_LENGTH,
                                  YIELD_SEQUENCE_LENGTH=YIELD_SEQUENCE_LENGTH,
                                  NUM_FEATURES=6, 
                                  trade_history_normalizer = trade_history_normalizer)
    
    model_new_ys.compile(optimizer=keras.optimizers.Adam(learning_rate=LEARNING_RATE),
          loss=keras.losses.MeanAbsoluteError(),
          metrics=[keras.metrics.MeanAbsoluteError()])

    history_new_ys = model_new_ys.fit(train_ds,
                                      validation_data=val_ds,
                                        epochs=NUM_EPOCHS,     
                                        verbose=1, 
                                        callbacks=fit_callbacks,
                                        use_multiprocessing=True,
                                        workers=8)
    
    return history_new_ys, model_new_ys

# %%
results = []
predictions = []

for i in range(8):
    history, model = train_model(x_train, y_train, x_val, y_val, shuffle=True, shuffle_buffer=0.75)
    pred = model.predict(x_test)
    predictions.append(pred)
    print('='*25+f' TRIAL {i}, MAE: {mean_absolute_error(pred,y_test)} '+'='*25)
    results.append([history, model])
# Out:
# Epoch 1/100
# 2023-05-16 17:42:56.188264: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14254800896 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2023-05-16 17:42:56.189239: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14254800896 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2023-05-16 17:43:07.144038: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 405993 of 802911
# 2023-05-16 17:43:14.415350: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:405] Shuffle buffer filled.
# 2023-05-16 17:43:16.071589: I tensorflow/stream_executor/cuda/cuda_dnn.cc:366] Loaded cuDNN version 8200
# 1046/1046 [==============================] - ETA: 0s - loss: 53.7464 - mean_absolute_error: 53.7464
# 2023-05-16 17:43:47.624785: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14254800896 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2023-05-16 17:43:47.625218: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14254800896 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 1046/1046 [==============================] - 65s 31ms/step - loss: 53.7464 - mean_absolute_error: 53.7464 - val_loss: 48.6388 - val_mean_absolute_error: 48.6388
# Epoch 2/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 48.2645 - mean_absolute_error: 48.2645 - val_loss: 44.8436 - val_mean_absolute_error: 44.8436
# Epoch 3/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 39.9887 - mean_absolute_error: 39.9887 - val_loss: 35.9916 - val_mean_absolute_error: 35.9916
# Epoch 4/100
# 1046/1046 [==============================] - 19s 19ms/step - loss: 28.9512 - mean_absolute_error: 28.9512 - val_loss: 22.7116 - val_mean_absolute_error: 22.7116
# Epoch 5/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 18.1375 - mean_absolute_error: 18.1375 - val_loss: 13.0177 - val_mean_absolute_error: 13.0177
# Epoch 6/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 12.4238 - mean_absolute_error: 12.4238 - val_loss: 10.4568 - val_mean_absolute_error: 10.4568
# Epoch 7/100
# 1046/1046 [==============================] - 19s 19ms/step - loss: 11.2576 - mean_absolute_error: 11.2576 - val_loss: 10.0911 - val_mean_absolute_error: 10.0911
# Epoch 8/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 10.9967 - mean_absolute_error: 10.9967 - val_loss: 9.9418 - val_mean_absolute_error: 9.9418
# Epoch 9/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 10.8386 - mean_absolute_error: 10.8386 - val_loss: 9.8492 - val_mean_absolute_error: 9.8492
# Epoch 10/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 10.7120 - mean_absolute_error: 10.7120 - val_loss: 9.6920 - val_mean_absolute_error: 9.6920
# Epoch 11/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 10.6051 - mean_absolute_error: 10.6051 - val_loss: 9.5451 - val_mean_absolute_error: 9.5451
# Epoch 12/100
# 1046/1046 [==============================] - 19s 19ms/step - loss: 10.5029 - mean_absolute_error: 10.5029 - val_loss: 9.4383 - val_mean_absolute_error: 9.4383
# Epoch 13/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 10.4164 - mean_absolute_error: 10.4164 - val_loss: 9.3750 - val_mean_absolute_error: 9.3750
# Epoch 14/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 10.3450 - mean_absolute_error: 10.3450 - val_loss: 9.2935 - val_mean_absolute_error: 9.2935
# Epoch 15/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 10.2769 - mean_absolute_error: 10.2769 - val_loss: 9.2463 - val_mean_absolute_error: 9.2463
# Epoch 16/100
# 1046/1046 [==============================] - 26s 25ms/step - loss: 10.2157 - mean_absolute_error: 10.2157 - val_loss: 9.1906 - val_mean_absolute_error: 9.1906
# Epoch 17/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 10.1642 - mean_absolute_error: 10.1642 - val_loss: 9.1157 - val_mean_absolute_error: 9.1157
# Epoch 18/100
# 1046/1046 [==============================] - 21s 20ms/step - loss: 10.1036 - mean_absolute_error: 10.1036 - val_loss: 9.0981 - val_mean_absolute_error: 9.0981
# Epoch 19/100
# 1046/1046 [==============================] - 26s 25ms/step - loss: 10.0666 - mean_absolute_error: 10.0666 - val_loss: 9.0809 - val_mean_absolute_error: 9.0809
# Epoch 20/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 10.0140 - mean_absolute_error: 10.0140 - val_loss: 8.9901 - val_mean_absolute_error: 8.9901
# Epoch 21/100
# 1046/1046 [==============================] - 26s 25ms/step - loss: 9.9762 - mean_absolute_error: 9.9762 - val_loss: 8.9794 - val_mean_absolute_error: 8.9794
# Epoch 22/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 9.9432 - mean_absolute_error: 9.9432 - val_loss: 8.9529 - val_mean_absolute_error: 8.9529
# Epoch 23/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 9.8941 - mean_absolute_error: 9.8941 - val_loss: 8.9728 - val_mean_absolute_error: 8.9728
# Epoch 24/100
# 1046/1046 [==============================] - 26s 25ms/step - loss: 9.8678 - mean_absolute_error: 9.8678 - val_loss: 8.9112 - val_mean_absolute_error: 8.9112
# Epoch 25/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 9.8323 - mean_absolute_error: 9.8323 - val_loss: 8.8540 - val_mean_absolute_error: 8.8540
# Epoch 26/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 9.8068 - mean_absolute_error: 9.8068 - val_loss: 8.8516 - val_mean_absolute_error: 8.8516
# Epoch 27/100
# 1046/1046 [==============================] - 26s 25ms/step - loss: 9.7781 - mean_absolute_error: 9.7781 - val_loss: 8.8375 - val_mean_absolute_error: 8.8375
# Epoch 28/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 9.7489 - mean_absolute_error: 9.7489 - val_loss: 8.7986 - val_mean_absolute_error: 8.7986
# Epoch 29/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 9.7222 - mean_absolute_error: 9.7222 - val_loss: 8.7777 - val_mean_absolute_error: 8.7777
# Epoch 30/100
# 1046/1046 [==============================] - 19s 18ms/step - loss: 9.6882 - mean_absolute_error: 9.6882 - val_loss: 8.7856 - val_mean_absolute_error: 8.7856
# Epoch 31/100
# 1046/1046 [==============================] - 19s 19ms/step - loss: 9.6734 - mean_absolute_error: 9.6734 - val_loss: 8.7271 - val_mean_absolute_error: 8.7271
# Epoch 32/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 9.6436 - mean_absolute_error: 9.6436 - val_loss: 8.7514 - val_mean_absolute_error: 8.7514
# Epoch 33/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 9.6232 - mean_absolute_error: 9.6232 - val_loss: 8.7126 - val_mean_absolute_error: 8.7126
# Epoch 34/100
# 1046/1046 [==============================] - 19s 18ms/step - loss: 9.6040 - mean_absolute_error: 9.6040 - val_loss: 8.7070 - val_mean_absolute_error: 8.7070
# Epoch 35/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 9.5745 - mean_absolute_error: 9.5745 - val_loss: 8.6803 - val_mean_absolute_error: 8.6803
# Epoch 36/100
# 1046/1046 [==============================] - 19s 19ms/step - loss: 9.5611 - mean_absolute_error: 9.5611 - val_loss: 8.6763 - val_mean_absolute_error: 8.6763
# Epoch 37/100
# 1046/1046 [==============================] - 19s 19ms/step - loss: 9.5387 - mean_absolute_error: 9.5387 - val_loss: 8.6501 - val_mean_absolute_error: 8.6501
# Epoch 38/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 9.5199 - mean_absolute_error: 9.5199 - val_loss: 8.6503 - val_mean_absolute_error: 8.6503
# Epoch 39/100
# 1046/1046 [==============================] - 19s 19ms/step - loss: 9.4998 - mean_absolute_error: 9.4998 - val_loss: 8.6184 - val_mean_absolute_error: 8.6184
# Epoch 40/100
# 1046/1046 [==============================] - 19s 19ms/step - loss: 9.4779 - mean_absolute_error: 9.4779 - val_loss: 8.6313 - val_mean_absolute_error: 8.6313
# Epoch 41/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 9.4594 - mean_absolute_error: 9.4594 - val_loss: 8.6025 - val_mean_absolute_error: 8.6025
# Epoch 42/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 9.4483 - mean_absolute_error: 9.4483 - val_loss: 8.6679 - val_mean_absolute_error: 8.6679
# Epoch 43/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 9.4285 - mean_absolute_error: 9.4285 - val_loss: 8.5871 - val_mean_absolute_error: 8.5871
# Epoch 44/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 9.4170 - mean_absolute_error: 9.4170 - val_loss: 8.5965 - val_mean_absolute_error: 8.5965
# Epoch 45/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 9.3912 - mean_absolute_error: 9.3912 - val_loss: 8.5720 - val_mean_absolute_error: 8.5720
# Epoch 46/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 9.3850 - mean_absolute_error: 9.3850 - val_loss: 8.5652 - val_mean_absolute_error: 8.5652
# Epoch 47/100
# 1046/1046 [==============================] - 19s 19ms/step - loss: 9.3741 - mean_absolute_error: 9.3741 - val_loss: 8.5344 - val_mean_absolute_error: 8.5344
# Epoch 48/100
# 1046/1046 [==============================] - 19s 18ms/step - loss: 9.3468 - mean_absolute_error: 9.3468 - val_loss: 8.5533 - val_mean_absolute_error: 8.5533
# Epoch 49/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 9.3375 - mean_absolute_error: 9.3375 - val_loss: 8.5503 - val_mean_absolute_error: 8.5503
# Epoch 50/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 9.3229 - mean_absolute_error: 9.3229 - val_loss: 8.5425 - val_mean_absolute_error: 8.5425
# Epoch 51/100
# 1046/1046 [==============================] - 19s 18ms/step - loss: 9.3143 - mean_absolute_error: 9.3143 - val_loss: 8.5096 - val_mean_absolute_error: 8.5096
# Epoch 52/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 9.2931 - mean_absolute_error: 9.2931 - val_loss: 8.5034 - val_mean_absolute_error: 8.5034
# Epoch 53/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 9.2797 - mean_absolute_error: 9.2797 - val_loss: 8.5012 - val_mean_absolute_error: 8.5012
# Epoch 54/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 9.2683 - mean_absolute_error: 9.2683 - val_loss: 8.4911 - val_mean_absolute_error: 8.4911
# Epoch 55/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 9.2540 - mean_absolute_error: 9.2540 - val_loss: 8.4631 - val_mean_absolute_error: 8.4631
# Epoch 56/100
# 1046/1046 [==============================] - 19s 18ms/step - loss: 9.2479 - mean_absolute_error: 9.2479 - val_loss: 8.5100 - val_mean_absolute_error: 8.5100
# Epoch 57/100
# 1046/1046 [==============================] - 23s 22ms/step - loss: 9.2288 - mean_absolute_error: 9.2288 - val_loss: 8.4549 - val_mean_absolute_error: 8.4549
# Epoch 58/100
# 1046/1046 [==============================] - 19s 19ms/step - loss: 9.2272 - mean_absolute_error: 9.2272 - val_loss: 8.4699 - val_mean_absolute_error: 8.4699
# Epoch 59/100
# 1046/1046 [==============================] - 24s 22ms/step - loss: 9.2108 - mean_absolute_error: 9.2108 - val_loss: 8.4428 - val_mean_absolute_error: 8.4428
# Epoch 60/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 9.1948 - mean_absolute_error: 9.1948 - val_loss: 8.4303 - val_mean_absolute_error: 8.4303
# Epoch 61/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 9.1807 - mean_absolute_error: 9.1807 - val_loss: 8.4161 - val_mean_absolute_error: 8.4161
# Epoch 62/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 9.1745 - mean_absolute_error: 9.1745 - val_loss: 8.4928 - val_mean_absolute_error: 8.4928
# Epoch 63/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 9.1671 - mean_absolute_error: 9.1671 - val_loss: 8.4267 - val_mean_absolute_error: 8.4267
# Epoch 64/100
# 1046/1046 [==============================] - 19s 19ms/step - loss: 9.1482 - mean_absolute_error: 9.1482 - val_loss: 8.4618 - val_mean_absolute_error: 8.4618
# Epoch 65/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 9.1367 - mean_absolute_error: 9.1367 - val_loss: 8.5228 - val_mean_absolute_error: 8.5228
# Epoch 66/100
# 1046/1046 [==============================] - 19s 19ms/step - loss: 9.1236 - mean_absolute_error: 9.1236 - val_loss: 8.3964 - val_mean_absolute_error: 8.3964
# Epoch 67/100
# 1046/1046 [==============================] - 19s 18ms/step - loss: 9.1150 - mean_absolute_error: 9.1150 - val_loss: 8.3860 - val_mean_absolute_error: 8.3860
# Epoch 68/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 9.1128 - mean_absolute_error: 9.1128 - val_loss: 8.3893 - val_mean_absolute_error: 8.3893
# Epoch 69/100
# 1046/1046 [==============================] - 19s 18ms/step - loss: 9.0966 - mean_absolute_error: 9.0966 - val_loss: 8.3806 - val_mean_absolute_error: 8.3806
# Epoch 70/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 9.0960 - mean_absolute_error: 9.0960 - val_loss: 8.3950 - val_mean_absolute_error: 8.3950
# Epoch 71/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 9.0828 - mean_absolute_error: 9.0828 - val_loss: 8.3953 - val_mean_absolute_error: 8.3953
# Epoch 72/100
# 1046/1046 [==============================] - 19s 18ms/step - loss: 9.0677 - mean_absolute_error: 9.0677 - val_loss: 8.3787 - val_mean_absolute_error: 8.3787
# Epoch 73/100
# 1046/1046 [==============================] - 19s 18ms/step - loss: 9.0613 - mean_absolute_error: 9.0613 - val_loss: 8.3856 - val_mean_absolute_error: 8.3856
# Epoch 74/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 9.0511 - mean_absolute_error: 9.0511 - val_loss: 8.4073 - val_mean_absolute_error: 8.4073
# Epoch 75/100
# 1046/1046 [==============================] - 19s 18ms/step - loss: 9.0379 - mean_absolute_error: 9.0379 - val_loss: 8.3588 - val_mean_absolute_error: 8.3588
# Epoch 76/100
# 1046/1046 [==============================] - 23s 22ms/step - loss: 9.0385 - mean_absolute_error: 9.0385 - val_loss: 8.3985 - val_mean_absolute_error: 8.3985
# Epoch 77/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 9.0205 - mean_absolute_error: 9.0205 - val_loss: 8.3612 - val_mean_absolute_error: 8.3612
# Epoch 78/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 9.0153 - mean_absolute_error: 9.0153 - val_loss: 8.3630 - val_mean_absolute_error: 8.3630
# Epoch 79/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 9.0102 - mean_absolute_error: 9.0102 - val_loss: 8.4116 - val_mean_absolute_error: 8.4116
# Epoch 80/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 9.0029 - mean_absolute_error: 9.0029 - val_loss: 8.3370 - val_mean_absolute_error: 8.3370
# Epoch 81/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 8.9902 - mean_absolute_error: 8.9902 - val_loss: 8.3297 - val_mean_absolute_error: 8.3297
# Epoch 82/100
# 1046/1046 [==============================] - 25s 24ms/step - loss: 8.9790 - mean_absolute_error: 8.9790 - val_loss: 8.3329 - val_mean_absolute_error: 8.3329
# Epoch 83/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 8.9759 - mean_absolute_error: 8.9759 - val_loss: 8.3226 - val_mean_absolute_error: 8.3226
# Epoch 84/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 8.9703 - mean_absolute_error: 8.9703 - val_loss: 8.3271 - val_mean_absolute_error: 8.3271
# Epoch 85/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 8.9569 - mean_absolute_error: 8.9569 - val_loss: 8.3056 - val_mean_absolute_error: 8.3056
# Epoch 86/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 8.9553 - mean_absolute_error: 8.9553 - val_loss: 8.3055 - val_mean_absolute_error: 8.3055
# Epoch 87/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 8.9494 - mean_absolute_error: 8.9494 - val_loss: 8.3547 - val_mean_absolute_error: 8.3547
# Epoch 88/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 8.9337 - mean_absolute_error: 8.9337 - val_loss: 8.3000 - val_mean_absolute_error: 8.3000
# Epoch 89/100
# 1046/1046 [==============================] - 21s 20ms/step - loss: 8.9276 - mean_absolute_error: 8.9276 - val_loss: 8.3139 - val_mean_absolute_error: 8.3139
# Epoch 90/100
# 1046/1046 [==============================] - 25s 24ms/step - loss: 8.9205 - mean_absolute_error: 8.9205 - val_loss: 8.3092 - val_mean_absolute_error: 8.3092
# Epoch 91/100
# 1046/1046 [==============================] - 21s 20ms/step - loss: 8.9135 - mean_absolute_error: 8.9135 - val_loss: 8.3290 - val_mean_absolute_error: 8.3290
# Epoch 92/100
# 1046/1046 [==============================] - 21s 20ms/step - loss: 8.9108 - mean_absolute_error: 8.9108 - val_loss: 8.3002 - val_mean_absolute_error: 8.3002
# Epoch 93/100
# 1046/1046 [==============================] - 25s 24ms/step - loss: 8.8943 - mean_absolute_error: 8.8943 - val_loss: 8.2984 - val_mean_absolute_error: 8.2984
# Epoch 94/100
# 1046/1046 [==============================] - 21s 20ms/step - loss: 8.8910 - mean_absolute_error: 8.8910 - val_loss: 8.2819 - val_mean_absolute_error: 8.2819
# Epoch 95/100
# 1046/1046 [==============================] - 21s 20ms/step - loss: 8.8833 - mean_absolute_error: 8.8833 - val_loss: 8.3173 - val_mean_absolute_error: 8.3173
# Epoch 96/100
# 1046/1046 [==============================] - 25s 24ms/step - loss: 8.8842 - mean_absolute_error: 8.8842 - val_loss: 8.2835 - val_mean_absolute_error: 8.2835
# Epoch 97/100
# 1046/1046 [==============================] - 21s 20ms/step - loss: 8.8664 - mean_absolute_error: 8.8664 - val_loss: 8.2628 - val_mean_absolute_error: 8.2628
# Epoch 98/100
# 1046/1046 [==============================] - 25s 24ms/step - loss: 8.8691 - mean_absolute_error: 8.8691 - val_loss: 8.2664 - val_mean_absolute_error: 8.2664
# Epoch 99/100
# 1046/1046 [==============================] - 21s 20ms/step - loss: 8.8589 - mean_absolute_error: 8.8589 - val_loss: 8.2757 - val_mean_absolute_error: 8.2757
# Epoch 100/100
# 1046/1046 [==============================] - 21s 20ms/step - loss: 8.8498 - mean_absolute_error: 8.8498 - val_loss: 8.3115 - val_mean_absolute_error: 8.3115
# Model training time was 36.42 minutes (2185.22 seconds).
# Average time for each epoch was 0.36 minutes (21.85 seconds).
# 2023-05-16 18:19:56.278236: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14254800896 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2023-05-16 18:19:56.278757: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14254800896 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# ========================= TRIAL 0, MAE: 9.37121381551886 =========================
# Epoch 1/100
# 2023-05-16 18:21:55.348272: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14254800896 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2023-05-16 18:21:55.349259: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14254800896 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2023-05-16 18:22:06.414533: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 437840 of 802911
# 2023-05-16 18:22:13.747257: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:405] Shuffle buffer filled.
# 1046/1046 [==============================] - ETA: 0s - loss: 53.6183 - mean_absolute_error: 53.6183
# 2023-05-16 18:22:41.142783: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14254800896 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2023-05-16 18:22:41.143265: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14254800896 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 1046/1046 [==============================] - 58s 31ms/step - loss: 53.6183 - mean_absolute_error: 53.6183 - val_loss: 49.3275 - val_mean_absolute_error: 49.3275
# Epoch 2/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 48.1293 - mean_absolute_error: 48.1293 - val_loss: 45.2721 - val_mean_absolute_error: 45.2721
# Epoch 3/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 39.7700 - mean_absolute_error: 39.7700 - val_loss: 35.4754 - val_mean_absolute_error: 35.4754
# Epoch 4/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 28.6848 - mean_absolute_error: 28.6848 - val_loss: 20.9179 - val_mean_absolute_error: 20.9179
# Epoch 5/100
# 1046/1046 [==============================] - 25s 24ms/step - loss: 17.8943 - mean_absolute_error: 17.8943 - val_loss: 13.0984 - val_mean_absolute_error: 13.0984
# Epoch 6/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 12.3176 - mean_absolute_error: 12.3176 - val_loss: 10.6687 - val_mean_absolute_error: 10.6687
# Epoch 7/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 11.2047 - mean_absolute_error: 11.2047 - val_loss: 10.1128 - val_mean_absolute_error: 10.1128
# Epoch 8/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 10.9535 - mean_absolute_error: 10.9535 - val_loss: 10.0254 - val_mean_absolute_error: 10.0254
# Epoch 9/100
# 1046/1046 [==============================] - 19s 19ms/step - loss: 10.8047 - mean_absolute_error: 10.8047 - val_loss: 9.9020 - val_mean_absolute_error: 9.9020
# Epoch 10/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 10.6765 - mean_absolute_error: 10.6765 - val_loss: 9.7076 - val_mean_absolute_error: 9.7076
# Epoch 11/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 10.5721 - mean_absolute_error: 10.5721 - val_loss: 9.7057 - val_mean_absolute_error: 9.7057
# Epoch 12/100
# 1046/1046 [==============================] - 19s 19ms/step - loss: 10.4818 - mean_absolute_error: 10.4818 - val_loss: 9.5941 - val_mean_absolute_error: 9.5941
# Epoch 13/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 10.3935 - mean_absolute_error: 10.3935 - val_loss: 9.5652 - val_mean_absolute_error: 9.5652
# Epoch 14/100
# 1046/1046 [==============================] - 19s 18ms/step - loss: 10.3185 - mean_absolute_error: 10.3185 - val_loss: 9.4548 - val_mean_absolute_error: 9.4548
# Epoch 15/100
# 1046/1046 [==============================] - 19s 19ms/step - loss: 10.2500 - mean_absolute_error: 10.2500 - val_loss: 9.4174 - val_mean_absolute_error: 9.4174
# Epoch 16/100
# 1046/1046 [==============================] - 26s 25ms/step - loss: 10.1961 - mean_absolute_error: 10.1961 - val_loss: 9.3199 - val_mean_absolute_error: 9.3199
# Epoch 17/100
# 1046/1046 [==============================] - 19s 19ms/step - loss: 10.1446 - mean_absolute_error: 10.1446 - val_loss: 9.2904 - val_mean_absolute_error: 9.2904
# Epoch 18/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 10.0749 - mean_absolute_error: 10.0749 - val_loss: 9.2825 - val_mean_absolute_error: 9.2825
# Epoch 19/100
# 1046/1046 [==============================] - 25s 24ms/step - loss: 10.0357 - mean_absolute_error: 10.0357 - val_loss: 9.1505 - val_mean_absolute_error: 9.1505
# Epoch 20/100
# 1046/1046 [==============================] - 19s 18ms/step - loss: 9.9931 - mean_absolute_error: 9.9931 - val_loss: 9.2160 - val_mean_absolute_error: 9.2160
# Epoch 21/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 9.9517 - mean_absolute_error: 9.9517 - val_loss: 9.0739 - val_mean_absolute_error: 9.0739
# Epoch 22/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 9.9097 - mean_absolute_error: 9.9097 - val_loss: 9.0871 - val_mean_absolute_error: 9.0871
# Epoch 23/100
# 1046/1046 [==============================] - 19s 18ms/step - loss: 9.8744 - mean_absolute_error: 9.8744 - val_loss: 9.0285 - val_mean_absolute_error: 9.0285
# Epoch 24/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 9.8400 - mean_absolute_error: 9.8400 - val_loss: 8.9547 - val_mean_absolute_error: 8.9547
# Epoch 25/100
# 1046/1046 [==============================] - 23s 22ms/step - loss: 9.8064 - mean_absolute_error: 9.8064 - val_loss: 8.9949 - val_mean_absolute_error: 8.9949
# Epoch 26/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 9.7685 - mean_absolute_error: 9.7685 - val_loss: 8.9369 - val_mean_absolute_error: 8.9369
# Epoch 27/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 9.7466 - mean_absolute_error: 9.7466 - val_loss: 8.9897 - val_mean_absolute_error: 8.9897
# Epoch 28/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 9.7181 - mean_absolute_error: 9.7181 - val_loss: 8.9254 - val_mean_absolute_error: 8.9254
# Epoch 29/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 9.6853 - mean_absolute_error: 9.6853 - val_loss: 8.9446 - val_mean_absolute_error: 8.9446
# Epoch 30/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 9.6688 - mean_absolute_error: 9.6688 - val_loss: 8.9487 - val_mean_absolute_error: 8.9487
# Epoch 31/100
# 1046/1046 [==============================] - 19s 18ms/step - loss: 9.6462 - mean_absolute_error: 9.6462 - val_loss: 9.1275 - val_mean_absolute_error: 9.1275
# Epoch 32/100
# 1046/1046 [==============================] - 19s 18ms/step - loss: 9.6154 - mean_absolute_error: 9.6154 - val_loss: 8.8950 - val_mean_absolute_error: 8.8950
# Epoch 33/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 9.5890 - mean_absolute_error: 9.5890 - val_loss: 8.8151 - val_mean_absolute_error: 8.8151
# Epoch 34/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 9.5658 - mean_absolute_error: 9.5658 - val_loss: 8.7579 - val_mean_absolute_error: 8.7579
# Epoch 35/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 9.5476 - mean_absolute_error: 9.5476 - val_loss: 8.8422 - val_mean_absolute_error: 8.8422
# Epoch 36/100
# 1046/1046 [==============================] - 26s 25ms/step - loss: 9.5254 - mean_absolute_error: 9.5254 - val_loss: 8.8666 - val_mean_absolute_error: 8.8666
# Epoch 37/100
# 1046/1046 [==============================] - 19s 18ms/step - loss: 9.5097 - mean_absolute_error: 9.5097 - val_loss: 8.8218 - val_mean_absolute_error: 8.8218
# Epoch 38/100
# 1046/1046 [==============================] - 25s 23ms/step - loss: 9.4801 - mean_absolute_error: 9.4801 - val_loss: 8.8492 - val_mean_absolute_error: 8.8492
# Epoch 39/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 9.4686 - mean_absolute_error: 9.4686 - val_loss: 8.8420 - val_mean_absolute_error: 8.8420
# Epoch 40/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 9.4448 - mean_absolute_error: 9.4448 - val_loss: 8.6932 - val_mean_absolute_error: 8.6932
# Epoch 41/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 9.4277 - mean_absolute_error: 9.4277 - val_loss: 8.7201 - val_mean_absolute_error: 8.7201
# Epoch 42/100
# 1046/1046 [==============================] - 19s 18ms/step - loss: 9.4162 - mean_absolute_error: 9.4162 - val_loss: 8.8395 - val_mean_absolute_error: 8.8395
# Epoch 43/100
# 1046/1046 [==============================] - 19s 18ms/step - loss: 9.4024 - mean_absolute_error: 9.4024 - val_loss: 8.7189 - val_mean_absolute_error: 8.7189
# Epoch 44/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 9.3758 - mean_absolute_error: 9.3758 - val_loss: 8.7135 - val_mean_absolute_error: 8.7135
# Epoch 45/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 9.3682 - mean_absolute_error: 9.3682 - val_loss: 8.7277 - val_mean_absolute_error: 8.7277
# Epoch 46/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 9.3468 - mean_absolute_error: 9.3468 - val_loss: 8.6750 - val_mean_absolute_error: 8.6750
# Epoch 47/100
# 1046/1046 [==============================] - 26s 25ms/step - loss: 9.3338 - mean_absolute_error: 9.3338 - val_loss: 8.6641 - val_mean_absolute_error: 8.6641
# Epoch 48/100
# 1046/1046 [==============================] - 25s 24ms/step - loss: 9.3195 - mean_absolute_error: 9.3195 - val_loss: 8.6179 - val_mean_absolute_error: 8.6179
# Epoch 49/100
# 1046/1046 [==============================] - 40s 38ms/step - loss: 9.3080 - mean_absolute_error: 9.3080 - val_loss: 8.5721 - val_mean_absolute_error: 8.5721
# Epoch 50/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 9.2879 - mean_absolute_error: 9.2879 - val_loss: 8.6957 - val_mean_absolute_error: 8.6957
# Epoch 51/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 9.2745 - mean_absolute_error: 9.2745 - val_loss: 8.5988 - val_mean_absolute_error: 8.5988
# Epoch 52/100
# 1046/1046 [==============================] - 19s 18ms/step - loss: 9.2601 - mean_absolute_error: 9.2601 - val_loss: 8.7041 - val_mean_absolute_error: 8.7041
# Epoch 53/100
# 1046/1046 [==============================] - 19s 18ms/step - loss: 9.2459 - mean_absolute_error: 9.2459 - val_loss: 8.6205 - val_mean_absolute_error: 8.6205
# Epoch 54/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 9.2346 - mean_absolute_error: 9.2346 - val_loss: 8.5384 - val_mean_absolute_error: 8.5384
# Epoch 55/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 9.2202 - mean_absolute_error: 9.2202 - val_loss: 8.5683 - val_mean_absolute_error: 8.5683
# Epoch 56/100
# 1046/1046 [==============================] - 19s 18ms/step - loss: 9.2068 - mean_absolute_error: 9.2068 - val_loss: 8.5672 - val_mean_absolute_error: 8.5672
# Epoch 57/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 9.1991 - mean_absolute_error: 9.1991 - val_loss: 8.5735 - val_mean_absolute_error: 8.5735
# Epoch 58/100
# 1046/1046 [==============================] - 19s 19ms/step - loss: 9.1850 - mean_absolute_error: 9.1850 - val_loss: 8.4946 - val_mean_absolute_error: 8.4946
# Epoch 59/100
# 1046/1046 [==============================] - 19s 18ms/step - loss: 9.1726 - mean_absolute_error: 9.1726 - val_loss: 8.5466 - val_mean_absolute_error: 8.5466
# Epoch 60/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 9.1626 - mean_absolute_error: 9.1626 - val_loss: 8.4597 - val_mean_absolute_error: 8.4597
# Epoch 61/100
# 1046/1046 [==============================] - 19s 18ms/step - loss: 9.1504 - mean_absolute_error: 9.1504 - val_loss: 8.4928 - val_mean_absolute_error: 8.4928
# Epoch 62/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 9.1439 - mean_absolute_error: 9.1439 - val_loss: 8.4757 - val_mean_absolute_error: 8.4757
# Epoch 63/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 9.1298 - mean_absolute_error: 9.1298 - val_loss: 8.5656 - val_mean_absolute_error: 8.5656
# Epoch 64/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 9.1144 - mean_absolute_error: 9.1144 - val_loss: 8.4629 - val_mean_absolute_error: 8.4629
# Epoch 65/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 9.1057 - mean_absolute_error: 9.1057 - val_loss: 8.4385 - val_mean_absolute_error: 8.4385
# Epoch 66/100
# 1046/1046 [==============================] - 19s 18ms/step - loss: 9.0965 - mean_absolute_error: 9.0965 - val_loss: 8.4519 - val_mean_absolute_error: 8.4519
# Epoch 67/100
# 1046/1046 [==============================] - 19s 18ms/step - loss: 9.0830 - mean_absolute_error: 9.0830 - val_loss: 8.4907 - val_mean_absolute_error: 8.4907
# Epoch 68/100
# 1046/1046 [==============================] - 25s 24ms/step - loss: 9.0726 - mean_absolute_error: 9.0726 - val_loss: 8.4595 - val_mean_absolute_error: 8.4595
# Epoch 69/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 9.0621 - mean_absolute_error: 9.0621 - val_loss: 8.4260 - val_mean_absolute_error: 8.4260
# Epoch 70/100
# 1046/1046 [==============================] - 19s 19ms/step - loss: 9.0557 - mean_absolute_error: 9.0557 - val_loss: 8.4354 - val_mean_absolute_error: 8.4354
# Epoch 71/100
# 1046/1046 [==============================] - 30s 29ms/step - loss: 9.0451 - mean_absolute_error: 9.0451 - val_loss: 8.4792 - val_mean_absolute_error: 8.4792
# Epoch 72/100
# 1046/1046 [==============================] - 25s 24ms/step - loss: 9.0298 - mean_absolute_error: 9.0298 - val_loss: 8.5291 - val_mean_absolute_error: 8.5291
# Epoch 73/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 9.0245 - mean_absolute_error: 9.0245 - val_loss: 8.4364 - val_mean_absolute_error: 8.4364
# Epoch 74/100
# 1046/1046 [==============================] - 19s 18ms/step - loss: 9.0122 - mean_absolute_error: 9.0122 - val_loss: 8.4550 - val_mean_absolute_error: 8.4550
# Epoch 75/100
# 1046/1046 [==============================] - 19s 18ms/step - loss: 9.0059 - mean_absolute_error: 9.0059 - val_loss: 8.3904 - val_mean_absolute_error: 8.3904
# Epoch 76/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 8.9984 - mean_absolute_error: 8.9984 - val_loss: 8.4468 - val_mean_absolute_error: 8.4468
# Epoch 77/100
# 1046/1046 [==============================] - 19s 18ms/step - loss: 8.9883 - mean_absolute_error: 8.9883 - val_loss: 8.4221 - val_mean_absolute_error: 8.4221
# Epoch 78/100
# 1046/1046 [==============================] - 19s 18ms/step - loss: 8.9818 - mean_absolute_error: 8.9818 - val_loss: 8.4337 - val_mean_absolute_error: 8.4337
# Epoch 79/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 8.9724 - mean_absolute_error: 8.9724 - val_loss: 8.5032 - val_mean_absolute_error: 8.5032
# Epoch 80/100
# 1046/1046 [==============================] - 19s 19ms/step - loss: 8.9608 - mean_absolute_error: 8.9608 - val_loss: 8.3656 - val_mean_absolute_error: 8.3656
# Epoch 81/100
# 1046/1046 [==============================] - 21s 20ms/step - loss: 8.9552 - mean_absolute_error: 8.9552 - val_loss: 8.3770 - val_mean_absolute_error: 8.3770
# Epoch 82/100
# 1046/1046 [==============================] - 19s 19ms/step - loss: 8.9491 - mean_absolute_error: 8.9491 - val_loss: 8.3886 - val_mean_absolute_error: 8.3886
# Epoch 83/100
# 1046/1046 [==============================] - 21s 20ms/step - loss: 8.9439 - mean_absolute_error: 8.9439 - val_loss: 8.3854 - val_mean_absolute_error: 8.3854
# Epoch 84/100
# 1046/1046 [==============================] - 22s 21ms/step - loss: 8.9283 - mean_absolute_error: 8.9283 - val_loss: 8.3374 - val_mean_absolute_error: 8.3374
# Epoch 85/100
# 1046/1046 [==============================] - 19s 18ms/step - loss: 8.9251 - mean_absolute_error: 8.9251 - val_loss: 8.3929 - val_mean_absolute_error: 8.3929
# Epoch 86/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 8.9121 - mean_absolute_error: 8.9121 - val_loss: 8.3561 - val_mean_absolute_error: 8.3561
# Epoch 87/100
# 1046/1046 [==============================] - 19s 18ms/step - loss: 8.9061 - mean_absolute_error: 8.9061 - val_loss: 8.3701 - val_mean_absolute_error: 8.3701
# Epoch 88/100
# 1046/1046 [==============================] - 19s 19ms/step - loss: 8.8988 - mean_absolute_error: 8.8988 - val_loss: 8.3661 - val_mean_absolute_error: 8.3661
# Epoch 89/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 8.8880 - mean_absolute_error: 8.8880 - val_loss: 8.3283 - val_mean_absolute_error: 8.3283
# Epoch 90/100
# 1046/1046 [==============================] - 19s 18ms/step - loss: 8.8839 - mean_absolute_error: 8.8839 - val_loss: 8.4101 - val_mean_absolute_error: 8.4101
# Epoch 91/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 8.8837 - mean_absolute_error: 8.8837 - val_loss: 8.3560 - val_mean_absolute_error: 8.3560
# Epoch 92/100
# 1046/1046 [==============================] - 26s 24ms/step - loss: 8.8737 - mean_absolute_error: 8.8737 - val_loss: 8.4709 - val_mean_absolute_error: 8.4709
# Epoch 93/100
# 1046/1046 [==============================] - 19s 18ms/step - loss: 8.8604 - mean_absolute_error: 8.8604 - val_loss: 8.3792 - val_mean_absolute_error: 8.3792
# Epoch 94/100
# 1046/1046 [==============================] - 19s 18ms/step - loss: 8.8551 - mean_absolute_error: 8.8551 - val_loss: 8.4179 - val_mean_absolute_error: 8.4179
# Epoch 95/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 8.8520 - mean_absolute_error: 8.8520 - val_loss: 8.3501 - val_mean_absolute_error: 8.3501
# Epoch 96/100
# 1046/1046 [==============================] - 19s 18ms/step - loss: 8.8376 - mean_absolute_error: 8.8376 - val_loss: 8.3003 - val_mean_absolute_error: 8.3003
# Epoch 97/100
# 1046/1046 [==============================] - 19s 19ms/step - loss: 8.8355 - mean_absolute_error: 8.8355 - val_loss: 8.3110 - val_mean_absolute_error: 8.3110
# Epoch 98/100
# 1046/1046 [==============================] - 25s 24ms/step - loss: 8.8361 - mean_absolute_error: 8.8361 - val_loss: 8.2883 - val_mean_absolute_error: 8.2883
# Epoch 99/100
# 1046/1046 [==============================] - 20s 20ms/step - loss: 8.8265 - mean_absolute_error: 8.8265 - val_loss: 8.3629 - val_mean_absolute_error: 8.3629
# Epoch 100/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 8.8127 - mean_absolute_error: 8.8127 - val_loss: 8.3501 - val_mean_absolute_error: 8.3501
# Model training time was 36.66 minutes (2199.37 seconds).
# Average time for each epoch was 0.37 minutes (21.99 seconds).
# 2023-05-16 18:59:13.053867: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14254800896 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2023-05-16 18:59:13.054318: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14254800896 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# ========================= TRIAL 1, MAE: 9.327779575869577 =========================
# Epoch 1/100
# 2023-05-16 19:01:19.576771: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14254800896 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2023-05-16 19:01:19.577698: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14254800896 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2023-05-16 19:01:30.534953: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 594091 of 802911
# 2023-05-16 19:01:34.039397: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:405] Shuffle buffer filled.
# 1046/1046 [==============================] - ETA: 0s - loss: 53.7362 - mean_absolute_error: 53.7362
# 2023-05-16 19:02:00.877136: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14254800896 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2023-05-16 19:02:00.877562: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14254800896 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 1046/1046 [==============================] - 58s 34ms/step - loss: 53.7362 - mean_absolute_error: 53.7362 - val_loss: 49.3785 - val_mean_absolute_error: 49.3785
# Epoch 2/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 48.2949 - mean_absolute_error: 48.2949 - val_loss: 45.1967 - val_mean_absolute_error: 45.1967
# Epoch 3/100
# 1046/1046 [==============================] - 19s 19ms/step - loss: 40.0488 - mean_absolute_error: 40.0488 - val_loss: 36.6111 - val_mean_absolute_error: 36.6111
# Epoch 4/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 29.0096 - mean_absolute_error: 29.0096 - val_loss: 21.0930 - val_mean_absolute_error: 21.0930
# Epoch 5/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 18.1443 - mean_absolute_error: 18.1443 - val_loss: 13.2104 - val_mean_absolute_error: 13.2104
# Epoch 6/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 12.4127 - mean_absolute_error: 12.4127 - val_loss: 10.3633 - val_mean_absolute_error: 10.3633
# Epoch 7/100
# 1046/1046 [==============================] - 24s 23ms/step - loss: 11.2342 - mean_absolute_error: 11.2342 - val_loss: 10.0472 - val_mean_absolute_error: 10.0472
# Epoch 8/100
# 1046/1046 [==============================] - 20s 19ms/step - loss: 10.9879 - mean_absolute_error: 10.9879 - val_loss: 9.8925 - val_mean_absolute_error: 9.8925
# Epoch 9/100
# ...
# Epoch 36/100
# 1046/1046 [==============================] - 29s 28ms/step - loss: 9.5599 - mean_absolute_error: 9.5599 - val_loss: 8.7124 - val_mean_absolute_error: 8.7124
# Epoch 37/100
# 1046/1046 [==============================] - 34s 33ms/step - loss: 9.5386 - mean_absolute_error: 9.5386 - val_loss: 8.6906 - val_mean_absolute_error: 8.6906
# Epoch 38/100
# 1046/1046 [==============================] - 29s 27ms/step - loss: 9.5137 - mean_absolute_error: 9.5137 - val_loss: 8.7063 - val_mean_absolute_error: 8.7063
# Epoch 39/100
# 1046/1046 [==============================] - 34s 32ms/step - loss: 9.4950 - mean_absolute_error: 9.4950 - val_loss: 8.7082 - val_mean_absolute_error: 8.7082
# Epoch 40/100
# 1046/1046 [==============================] - 29s 28ms/step - loss: 9.4751 - mean_absolute_error: 9.4751 - val_loss: 8.7871 - val_mean_absolute_error: 8.7871
# Epoch 41/100
# 1046/1046 [==============================] - 34s 33ms/step - loss: 9.4562 - mean_absolute_error: 9.4562 - val_loss: 8.6924 - val_mean_absolute_error: 8.6924
# Epoch 42/100
# 1046/1046 [==============================] - 29s 28ms/step - loss: 9.4432 - mean_absolute_error: 9.4432 - val_loss: 8.6282 - val_mean_absolute_error: 8.6282
# Epoch 43/100
# 1046/1046 [==============================] - 34s 32ms/step - loss: 9.4252 - mean_absolute_error: 9.4252 - val_loss: 8.6579 - val_mean_absolute_error: 8.6579
# Epoch 44/100
# 1046/1046 [==============================] - 29s 28ms/step - loss: 9.4071 - mean_absolute_error: 9.4071 - val_loss: 8.6370 - val_mean_absolute_error: 8.6370
# Epoch 45/100
# 1046/1046 [==============================] - 35s 33ms/step - loss: 9.3941 - mean_absolute_error: 9.3941 - val_loss: 8.6610 - val_mean_absolute_error: 8.6610
# Epoch 46/100
# 1046/1046 [==============================] - 29s 28ms/step - loss: 9.3788 - mean_absolute_error: 9.3788 - val_loss: 8.5863 - val_mean_absolute_error: 8.5863
# Epoch 47/100
# 1046/1046 [==============================] - 34s 33ms/step - loss: 9.3579 - mean_absolute_error: 9.3579 - val_loss: 8.5701 - val_mean_absolute_error: 8.5701
# Epoch 48/100
# 1046/1046 [==============================] - 29s 28ms/step - loss: 9.3467 - mean_absolute_error: 9.3467 - val_loss: 8.6601 - val_mean_absolute_error: 8.6601
# Epoch 49/100
# 1046/1046 [==============================] - 34s 33ms/step - loss: 9.3365 - mean_absolute_error: 9.3365 - val_loss: 8.5719 - val_mean_absolute_error: 8.5719
# Epoch 50/100
# 1046/1046 [==============================] - 33s 32ms/step - loss: 9.3183 - mean_absolute_error: 9.3183 - val_loss: 8.5513 - val_mean_absolute_error: 8.5513
# Epoch 51/100
# 1046/1046 [==============================] - 29s 28ms/step - loss: 9.2984 - mean_absolute_error: 9.2984 - val_loss: 8.5413 - val_mean_absolute_error: 8.5413
# Epoch 52/100
# 1046/1046 [==============================] - 34s 32ms/step - loss: 9.2919 - mean_absolute_error: 9.2919 - val_loss: 8.6229 - val_mean_absolute_error: 8.6229
# Epoch 53/100
# 1046/1046 [==============================] - 29s 28ms/step - loss: 9.2707 - mean_absolute_error: 9.2707 - val_loss: 8.5347 - val_mean_absolute_error: 8.5347
# Epoch 54/100
# 1046/1046 [==============================] - 34s 33ms/step - loss: 9.2561 - mean_absolute_error: 9.2561 - val_loss: 8.5215 - val_mean_absolute_error: 8.5215
# Epoch 55/100
# 1046/1046 [==============================] - 29s 28ms/step - loss: 9.2471 - mean_absolute_error: 9.2471 - val_loss: 8.5564 - val_mean_absolute_error: 8.5564
# Epoch 56/100
# 1046/1046 [==============================] - 34s 32ms/step - loss: 9.2344 - mean_absolute_error: 9.2344 - val_loss: 8.5213 - val_mean_absolute_error: 8.5213
# Epoch 57/100
# 1046/1046 [==============================] - 29s 28ms/step - loss: 9.2216 - mean_absolute_error: 9.2216 - val_loss: 8.5426 - val_mean_absolute_error: 8.5426
# Epoch 58/100
# 1046/1046 [==============================] - 34s 33ms/step - loss: 9.2164 - mean_absolute_error: 9.2164 - val_loss: 8.5335 - val_mean_absolute_error: 8.5335
# Epoch 59/100
# 1046/1046 [==============================] - 30s 28ms/step - loss: 9.1987 - mean_absolute_error: 9.1987 - val_loss: 8.5283 - val_mean_absolute_error: 8.5283
# Epoch 60/100
# 1046/1046 [==============================] - 34s 32ms/step - loss: 9.1841 - mean_absolute_error: 9.1841 - val_loss: 8.5067 - val_mean_absolute_error: 8.5067
# Epoch 61/100
# 1046/1046 [==============================] - 29s 28ms/step - loss: 9.1769 - mean_absolute_error: 9.1769 - val_loss: 8.4746 - val_mean_absolute_error: 8.4746
# Epoch 62/100
# 1046/1046 [==============================] - 35s 33ms/step - loss: 9.1661 - mean_absolute_error: 9.1661 - val_loss: 8.5017 - val_mean_absolute_error: 8.5017
# Epoch 63/100
# 1046/1046 [==============================] - 29s 28ms/step - loss: 9.1549 - mean_absolute_error: 9.1549 - val_loss: 8.4440 - val_mean_absolute_error: 8.4440
# Epoch 64/100
# 1046/1046 [==============================] - 34s 33ms/step - loss: 9.1401 - mean_absolute_error: 9.1401 - val_loss: 8.4936 - val_mean_absolute_error: 8.4936
# Epoch 65/100
# 1046/1046 [==============================] - 34s 32ms/step - loss: 9.1292 - mean_absolute_error: 9.1292 - val_loss: 8.4688 - val_mean_absolute_error: 8.4688
# Epoch 66/100
# 1046/1046 [==============================] - 29s 28ms/step - loss: 9.1284 - mean_absolute_error: 9.1284 - val_loss: 8.4348 - val_mean_absolute_error: 8.4348
# Epoch 67/100
# 1046/1046 [==============================] - 34s 33ms/step - loss: 9.1038 - mean_absolute_error: 9.1038 - val_loss: 8.4511 - val_mean_absolute_error: 8.4511
# Epoch 68/100
# 1046/1046 [==============================] - 29s 28ms/step - loss: 9.0949 - mean_absolute_error: 9.0949 - val_loss: 8.4502 - val_mean_absolute_error: 8.4502
# Epoch 69/100
# 1046/1046 [==============================] - 35s 33ms/step - loss: 9.0941 - mean_absolute_error: 9.0941 - val_loss: 8.4286 - val_mean_absolute_error: 8.4286
# Epoch 70/100
# 1046/1046 [==============================] - 29s 28ms/step - loss: 9.0794 - mean_absolute_error: 9.0794 - val_loss: 8.4191 - val_mean_absolute_error: 8.4191
# Epoch 71/100
# 1046/1046 [==============================] - 34s 32ms/step - loss: 9.0710 - mean_absolute_error: 9.0710 - val_loss: 8.4468 - val_mean_absolute_error: 8.4468
# Epoch 72/100
# 1046/1046 [==============================] - 29s 28ms/step - loss: 9.0602 - mean_absolute_error: 9.0602 - val_loss: 8.4264 - val_mean_absolute_error: 8.4264
# Epoch 73/100
# 1046/1046 [==============================] - 34s 32ms/step - loss: 9.0415 - mean_absolute_error: 9.0415 - val_loss: 8.4284 - val_mean_absolute_error: 8.4284
# Epoch 74/100
# 1046/1046 [==============================] - 29s 28ms/step - loss: 9.0382 - mean_absolute_error: 9.0382 - val_loss: 8.4063 - val_mean_absolute_error: 8.4063
# Epoch 75/100
# 1046/1046 [==============================] - 34s 33ms/step - loss: 9.0339 - mean_absolute_error: 9.0339 - val_loss: 8.3869 - val_mean_absolute_error: 8.3869
# Epoch 76/100
# 1046/1046 [==============================] - 29s 28ms/step - loss: 9.0294 - mean_absolute_error: 9.0294 - val_loss: 8.3874 - val_mean_absolute_error: 8.3874
# Epoch 77/100
# 1046/1046 [==============================] - 34s 33ms/step - loss: 9.0245 - mean_absolute_error: 9.0245 - val_loss: 8.4065 - val_mean_absolute_error: 8.4065
# Epoch 78/100
# 1046/1046 [==============================] - 29s 28ms/step - loss: 9.0079 - mean_absolute_error: 9.0079 - val_loss: 8.3746 - val_mean_absolute_error: 8.3746
# Epoch 79/100
# 1046/1046 [==============================] - 34s 32ms/step - loss: 9.0023 - mean_absolute_error: 9.0023 - val_loss: 8.3952 - val_mean_absolute_error: 8.3952
# Epoch 80/100
# 1046/1046 [==============================] - 30s 29ms/step - loss: 8.9862 - mean_absolute_error: 8.9862 - val_loss: 8.3831 - val_mean_absolute_error: 8.3831
# Epoch 81/100
# 1046/1046 [==============================] - 29s 28ms/step - loss: 8.9826 - mean_absolute_error: 8.9826 - val_loss: 8.3686 - val_mean_absolute_error: 8.3686
# Epoch 82/100
# 1046/1046 [==============================] - 34s 32ms/step - loss: 8.9761 - mean_absolute_error: 8.9761 - val_loss: 8.3833 - val_mean_absolute_error: 8.3833
# Epoch 83/100
# 1046/1046 [==============================] - 29s 28ms/step - loss: 8.9596 - mean_absolute_error: 8.9596 - val_loss: 8.3715 - val_mean_absolute_error: 8.3715
# Epoch 84/100
# 1046/1046 [==============================] - 34s 33ms/step - loss: 8.9585 - mean_absolute_error: 8.9585 - val_loss: 8.4339 - val_mean_absolute_error: 8.4339
# Epoch 85/100
# 1046/1046 [==============================] - 29s 28ms/step - loss: 8.9497 - mean_absolute_error: 8.9497 - val_loss: 8.3643 - val_mean_absolute_error: 8.3643
# Epoch 86/100
# 1046/1046 [==============================] - 33s 32ms/step - loss: 8.9382 - mean_absolute_error: 8.9382 - val_loss: 8.3621 - val_mean_absolute_error: 8.3621
# Epoch 87/100
# 1046/1046 [==============================] - 28s 27ms/step - loss: 8.9266 - mean_absolute_error: 8.9266 - val_loss: 8.3219 - val_mean_absolute_error: 8.3219
# Epoch 88/100
# 1046/1046 [==============================] - 35s 33ms/step - loss: 8.9273 - mean_absolute_error: 8.9273 - val_loss: 8.3689 - val_mean_absolute_error: 8.3689
# Epoch 89/100
# 1046/1046 [==============================] - 29s 27ms/step - loss: 8.9152 - mean_absolute_error: 8.9152 - val_loss: 8.3616 - val_mean_absolute_error: 8.3616
# Epoch 90/100
# 1046/1046 [==============================] - 34s 32ms/step - loss: 8.9108 - mean_absolute_error: 8.9108 - val_loss: 8.3240 - val_mean_absolute_error: 8.3240
# Epoch 91/100
# 1046/1046 [==============================] - 29s 28ms/step - loss: 8.9006 - mean_absolute_error: 8.9006 - val_loss: 8.3152 - val_mean_absolute_error: 8.3152
# Epoch 92/100
# 1046/1046 [==============================] - 33s 32ms/step - loss: 8.8920 - mean_absolute_error: 8.8920 - val_loss: 8.3511 - val_mean_absolute_error: 8.3511
# Epoch 93/100
# 1046/1046 [==============================] - 31s 30ms/step - loss: 8.8891 - mean_absolute_error: 8.8891 - val_loss: 8.2982 - val_mean_absolute_error: 8.2982
# Epoch 94/100
# 1046/1046 [==============================] - 31s 29ms/step - loss: 8.8835 - mean_absolute_error: 8.8835 - val_loss: 8.2956 - val_mean_absolute_error: 8.2956
# Epoch 95/100
# 1046/1046 [==============================] - 34s 32ms/step - loss: 8.8764 - mean_absolute_error: 8.8764 - val_loss: 8.3114 - val_mean_absolute_error: 8.3114
# Epoch 96/100
# 1046/1046 [==============================] - 30s 29ms/step - loss: 8.8636 - mean_absolute_error: 8.8636 - val_loss: 8.3115 - val_mean_absolute_error: 8.3115
# Epoch 97/100
# 1046/1046 [==============================] - 35s 33ms/step - loss: 8.8564 - mean_absolute_error: 8.8564 - val_loss: 8.2944 - val_mean_absolute_error: 8.2944
# Epoch 98/100
# 1046/1046 [==============================] - 29s 28ms/step - loss: 8.8547 - mean_absolute_error: 8.8547 - val_loss: 8.3068 - val_mean_absolute_error: 8.3068
# Epoch 99/100
# 1046/1046 [==============================] - 34s 32ms/step - loss: 8.8514 - mean_absolute_error: 8.8514 - val_loss: 8.3174 - val_mean_absolute_error: 8.3174
# Epoch 100/100
# 1046/1046 [==============================] - 29s 28ms/step - loss: 8.8489 - mean_absolute_error: 8.8489 - val_loss: 8.3135 - val_mean_absolute_error: 8.3135
# Model training time was 52.54 minutes (3152.49 seconds).
# Average time for each epoch was 0.53 minutes (31.52 seconds).
# 2023-05-16 21:47:51.094153: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14254800896 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2023-05-16 21:47:51.094622: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14254800896 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# ========================= TRIAL 5, MAE: 9.366007664963334 =========================
# Epoch 1/100
# 2023-05-16 21:50:27.758793: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14254800896 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2023-05-16 21:50:27.759824: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14254800896 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2023-05-16 21:50:38.904456: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 568433 of 802911
# 2023-05-16 21:50:43.076210: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:405] Shuffle buffer filled.
# 1046/1046 [==============================] - ETA: 0s - loss: 53.8068 - mean_absolute_error: 53.8068
# 2023-05-16 21:51:21.996929: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14254800896 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2023-05-16 21:51:21.997348: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "11020" } environment { key: "cudnn" value: "8100" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14254800896 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 1046/1046 [==============================] - 67s 42ms/step - loss: 53.8068 - mean_absolute_error: 53.8068 - val_loss: 50.5644 - val_mean_absolute_error: 50.5644
# Epoch 2/100
#  317/1046 [========>.....................] - ETA: 18s - loss: 51.8434 - mean_absolute_error: 51.8434

# %%
for i, prediction in enumerate(predictions):
    print(f'{mean_absolute_error(prediction, y_test)}')
# Out:
# 9.37121381551886
# 9.327779575869577
# 9.256888634500992
# 9.301693011337479
# 9.36830252436482
# 9.366007664963334
# 9.304872700187547
# 9.393162411273245

# %% [markdown]
# # Save Results

# %%
pred_df = pd.DataFrame(np.stack(predictions).reshape(8, -1).T, columns = [f'model_{i}' for i in range(1,9)])
test_dataframe[[f'prediction_{i}' for i in range(1,9)]] = pred_df

# %%
test_dataframe.to_pickle('diff_ys-yield_history_2-2023_05_09.pkl')
