# %% [markdown]
# ## Yield spread model with reference data
#
#
# We try to use gradient boosted trees to predict the yield spread, the input to the model is the reference data for the CUSIP

# %%
import pandas as pd
import numpy as np

from google.cloud import bigquery
import os
from sklearn import preprocessing
from datetime import datetime
import matplotlib.pyplot as plt

from catboost import CatBoostRegressor, Pool


import plotly.graph_objects as go
from IPython.display import display, HTML
# Out:
# 2021-07-19 13:44:46.869549: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.11.0

# %% [markdown]
# Initializing the big query client

# %%
bq_client = bigquery.Client()

# %% [markdown]
# #### Hyper-parameters for the model
# The batch size and learning rate have an impact on the smoothness of convergence of the model.\
# Larger the batch size the smoother the convergence. For a larger batch size we need a higher learning rate and vice-versa

# %%
TRAIN_TEST_SPLIT = 0.85
LEARNING_RATE = 0.001
BATCH_SIZE = 1000
NUM_EPOCHS = 50

# %% [markdown]
# ### Query to fetch data from BigQuery
#
# The SQL query uses the trade history with reference data view. We only use the trades which occurred after 01/01/2021. All three trade directions, namely dealer-dealer (D), dealer-sells (S), and dealer-purchases (P) are included. We are limiting the training to only tax exempt bonds which have a rating available and the yield is a positive number less than three.

# %%
DATA_QUERY = """ SELECT
  rtrs_control_number,
  cusip,
  trade_datetime,
  trade_date,
  time_of_trade,
  ifnull(settlement_date, assumed_settlement_date) AS settle_date,
  maturity_date,
  coupon,
  trade_type,
  is_non_transaction_based_compensation,
  yield_spread,
  yield AS ytw,
  dollar_price AS price,
  par_traded AS quantity,
  dated_date,
  issue_price,
  interest_payment_frequency,
  par_call_date,
  next_call_price,
  par_call_price,
  previous_coupon_payment_date,
  next_coupon_payment_date,
  first_coupon_date,
  coupon_type,
  muni_security_type,
  called_redemption_type,
  refund_price,
  call_timing,
  next_call_date AS call_date,
  next_sink_date AS sink_date,
  delivery_date AS deliv_date,
  refund_date AS refund_date,
  organization_primary_name AS issuer,
  is_callable,
  is_called,
  sp_long AS sp_lt_rating,
  assumed_redemption_date,
  is_lop_or_takedown,
  incorporated_state_code,
  security_description,
  instrument_primary_name,
  is_general_obligation,
  daycount_basis_type,
  capital_type,
  use_of_proceeds
FROM
  `eng-reactor-287421.primary_views.trade_history_with_reference_data`
WHERE
  yield IS NOT NULL
  AND yield > 0 
  AND yield <= 3 
  AND par_traded IS NOT NULL
  AND par_traded > 5000
  AND sp_long IS NOT NULL
  AND sp_long != "NR"
  AND federal_tax_status = 2 --tax exempt bonds
  AND trade_date >= '2021-01-01' 
  AND msrb_valid_to_date > current_date -- condition to remove cancelled trades
ORDER BY
  trade_date DESC
            """

# %% [markdown]
# ### Data Preparation
#
# We grab the data from BigQuery and converts it into a format suitable for input to the model. The fetch_data function uses the big query functionality to return the data from the SQL query as a dataframe.

# %%
def fetch_data(query):
    df = bq_client.query(query).result().to_dataframe()
    return df

# %%
# %%time
if os.path.isfile('data.pkl'):
    reference_data = pd.read_pickle('data.pkl')
else:
    reference_data = fetch_data(DATA_QUERY)
    reference_data.to_pickle('data.pkl')
# Out:
# CPU times: user 9.57 s, sys: 2.85 s, total: 12.4 s
# Wall time: 3min 3s

# %% [markdown]
# Converting the columns to correct datatypes. We also restrict the universe of trades to only investment grade bonds

# %%
# %%time
df = reference_data.copy()

df.quantity = np.log10(df.quantity.astype(float))
df.coupon = df.coupon.astype(float)

df['timestamp'] = pd.to_datetime(df['trade_datetime'], format='%Y-%m-%d %H:%M:%S')
df['trade_date'] = pd.to_datetime(df['trade_date'], format='%Y-%m-%d')
df['settle_date'] = pd.to_datetime(df['settle_date'], format='%Y-%m-%d')
df['maturity_date'] = pd.to_datetime(df['maturity_date'], format='%Y-%m-%d')
df['call_date'] = pd.to_datetime(df['call_date'], format='%Y-%m-%d')
df['sink_date'] = pd.to_datetime(df['sink_date'], format='%Y-%m-%d')
df['deliv_date'] = pd.to_datetime(df['deliv_date'], format='%Y-%m-%d')
df['assumed_redemption_date'] = pd.to_datetime(df['assumed_redemption_date'], format='%Y-%m-%d')
df['yield_spread'] = df['yield_spread'] * 100

#add dates from the ytw calculator for test: 
df['dated_date'] = pd.to_datetime(df['dated_date'], format='%Y-%m-%d')
df['par_call_date'] = pd.to_datetime(df['par_call_date'], format='%Y-%m-%d')
df['maturity_date'] = pd.to_datetime(df['maturity_date'], format='%Y-%m-%d')
df['previous_coupon_payment_date'] = pd.to_datetime(df['previous_coupon_payment_date'], format='%Y-%m-%d')
df['next_coupon_payment_date'] = pd.to_datetime(df['next_coupon_payment_date'], format='%Y-%m-%d')
df['first_coupon_date'] = pd.to_datetime(df['first_coupon_date'], format='%Y-%m-%d')

rd = pd.to_datetime(df['refund_date'], format='%Y-%m-%d')
rd[rd < df.trade_date] = pd.NaT
df['refund_date'] = rd
df['rating'] = df.sp_lt_rating

# Just including investment grade bonds
df = df[df.rating.isin(['A-','A','A+','AA-','AA','AA+','AAA'])] 

print(len(df))
# Out:
# 2622490
# CPU times: user 8.19 s, sys: 1.68 s, total: 9.87 s
# Wall time: 9.86 s

# %% [markdown]
# Creating Binary features

# %%
df['callable'] = df.is_callable  
df['called'] = df.is_called 
df['zerocoupon'] = df.coupon == 0
df['whenissued'] = df.deliv_date >= df.trade_date
df['sinking'] = ~df.sink_date.isnull()

# if the redemption type is NA we fill it with zero i.e unknown ref ice
df.called_redemption_type.fillna(0, inplace=True)

# %% [markdown]
# Converting the dates to number of days from settlement date. We only consider trades to be reportedly correctly if the trades are settled within on month of the trade date.

# %%
# Dropping trades settled one month after the trade
df['days_to_settle'] = (df.settle_date - df.trade_date).dt.days
df = df[df.days_to_settle <= 31]

# %%
df['days_to_maturity'] =  np.log10(1 + (df.assumed_redemption_date - df.settle_date).dt.days)
df['days_to_call'] = np.log10(1 + (df.call_date - df.settle_date).dt.days.fillna(0))
df['days_to_coupon'] = (df.next_coupon_payment_date - df.settle_date).dt.days
df.days_to_coupon = df.days_to_coupon.apply(lambda x: x if x > 0 else 0)
df.days_to_coupon = np.log(1 + df.days_to_coupon)

# Removing bonds from Puerto Rico
df = df[df.incorporated_state_code != 'PR']

# %% [markdown]
# Creating flags for different settlement pace

# %%
def settlement_pace(x):
    if x <= 3:
        return 'Fast'
    elif x>3 and x <=15:
        return 'Medium'
    else:
        return 'Slow'

# %%
df['settle_pace'] = df.days_to_settle.apply(settlement_pace)

# %% [markdown]
# Features used to tran the model

# %%
# features: 
BINARY = ['callable','called','sinking','whenissued','zerocoupon','is_non_transaction_based_compensation','is_general_obligation']
CATEGORICAL_FEATURES = ['trade_type','rating','coupon_type', 'muni_security_type','called_redemption_type','issuer','settle_pace']
NON_CAT_FEATURES = ['quantity','days_to_maturity','days_to_call','coupon',]
TARGET = ['yield_spread']

# %%
processed_data = df[BINARY + NON_CAT_FEATURES + CATEGORICAL_FEATURES + TARGET]

# %%
processed_data = processed_data.dropna()
len(processed_data)
# Out:
# 2604340

# %%
train_index = int( len(processed_data) * (1-TRAIN_TEST_SPLIT))
print(train_index)
train_dataframe = processed_data[train_index:]
test_dataframe = processed_data[:train_index]

print(len(train_dataframe))
print(len(test_dataframe))
# Out:
# 390651
# 2213689
# 390651

# %% [markdown]
# ### Reference data model
# CatBoost is a machine learning algorithm that uses gradient boosting on decision trees. We use this model to predict yield spreads only using the reference data.

# %%
model = CatBoostRegressor(iterations=300,
                          depth=14,
                          loss_function='RMSE',
                          verbose=True)

# %%
# %%time
train_dataframe = train_dataframe.copy()
train_dataframe['callable'] = train_dataframe.callable.astype('str')
train_dataframe['called'] = train_dataframe.called.astype('str')
train_dataframe['sinking'] = train_dataframe.sinking.astype('str')
train_dataframe['whenissued'] = train_dataframe.whenissued.astype('str')
train_dataframe['zerocoupon'] = train_dataframe.zerocoupon.astype('str')
train_dataframe['is_non_transaction_based_compensation'] = train_dataframe.is_non_transaction_based_compensation.astype('str')
train_dataframe['is_general_obligation'] = train_dataframe.is_general_obligation.astype('str')

#some categorical features are stores as numbers, we need to change them to strings
train_dataframe['coupon_type'] = train_dataframe.coupon_type.astype('str')
train_dataframe['muni_security_type'] = train_dataframe.muni_security_type.astype('str')
train_dataframe['called_redemption_type'] = train_dataframe.called_redemption_type.astype('str')
# Out:
# CPU times: user 2.63 s, sys: 180 ms, total: 2.81 s
# Wall time: 2.81 s

# %%
target = train_dataframe[TARGET]
train_data = train_dataframe[NON_CAT_FEATURES + BINARY + CATEGORICAL_FEATURES]

# %%
CATF = CATEGORICAL_FEATURES + BINARY
trainset = Pool(train_data, target, cat_features=CATF)

# %%
model.fit(trainset)
# Out:
# Learning rate set to 0.383901
# 0:	learn: 43.2034391	total: 5.17s	remaining: 25m 44s
# 1:	learn: 34.1072060	total: 10.8s	remaining: 26m 46s
# 2:	learn: 29.5194161	total: 16s	remaining: 26m 26s
# 3:	learn: 27.2178095	total: 21.7s	remaining: 26m 42s
# 4:	learn: 25.7226684	total: 26.6s	remaining: 26m 12s
# 5:	learn: 24.9472322	total: 30.8s	remaining: 25m 9s
# 6:	learn: 24.3362727	total: 35.4s	remaining: 24m 40s
# 7:	learn: 23.9573118	total: 39.9s	remaining: 24m 15s
# 8:	learn: 23.5788527	total: 44.3s	remaining: 23m 52s
# 9:	learn: 23.4076342	total: 48.8s	remaining: 23m 34s
# 10:	learn: 23.2159794	total: 54.3s	remaining: 23m 46s
# 11:	learn: 23.0735083	total: 59.4s	remaining: 23m 46s
# 12:	learn: 22.9844691	total: 1m 3s	remaining: 23m 25s
# 13:	learn: 22.9077379	total: 1m 8s	remaining: 23m 15s
# 14:	learn: 22.7965219	total: 1m 12s	remaining: 23m 4s
# 15:	learn: 22.6834726	total: 1m 18s	remaining: 23m 12s
# 16:	learn: 22.5450863	total: 1m 23s	remaining: 23m 16s
# 17:	learn: 22.4639053	total: 1m 29s	remaining: 23m 23s
# 18:	learn: 22.3650248	total: 1m 35s	remaining: 23m 28s
# 19:	learn: 22.2492274	total: 1m 40s	remaining: 23m 22s
# 20:	learn: 22.1690674	total: 1m 45s	remaining: 23m 21s
# 21:	learn: 22.0364204	total: 1m 50s	remaining: 23m 16s
# 22:	learn: 21.9752493	total: 1m 55s	remaining: 23m 11s
# 23:	learn: 21.8394543	total: 2m	remaining: 23m 6s
# 24:	learn: 21.7844098	total: 2m 5s	remaining: 22m 55s
# 25:	learn: 21.7409173	total: 2m 10s	remaining: 22m 51s
# 26:	learn: 21.6629203	total: 2m 15s	remaining: 22m 48s
# 27:	learn: 21.6093069	total: 2m 20s	remaining: 22m 47s
# 28:	learn: 21.5830607	total: 2m 26s	remaining: 22m 44s
# 29:	learn: 21.5314550	total: 2m 31s	remaining: 22m 42s
# 30:	learn: 21.4857282	total: 2m 37s	remaining: 22m 42s
# 31:	learn: 21.4195248	total: 2m 41s	remaining: 22m 34s
# 32:	learn: 21.3713507	total: 2m 47s	remaining: 22m 32s
# 33:	learn: 21.2937764	total: 2m 52s	remaining: 22m 30s
# 34:	learn: 21.2415882	total: 2m 58s	remaining: 22m 30s
# 35:	learn: 21.1894272	total: 3m 3s	remaining: 22m 26s
# 36:	learn: 21.1339410	total: 3m 9s	remaining: 22m 26s
# 37:	learn: 21.0910791	total: 3m 14s	remaining: 22m 20s
# 38:	learn: 21.0676175	total: 3m 19s	remaining: 22m 16s
# 39:	learn: 21.0288414	total: 3m 25s	remaining: 22m 13s
# 40:	learn: 20.9767390	total: 3m 30s	remaining: 22m 9s
# 41:	learn: 20.9463415	total: 3m 35s	remaining: 22m 3s
# 42:	learn: 20.9202355	total: 3m 40s	remaining: 21m 55s
# 43:	learn: 20.8967947	total: 3m 44s	remaining: 21m 48s
# 44:	learn: 20.8476773	total: 3m 50s	remaining: 21m 48s
# 45:	learn: 20.7900978	total: 3m 56s	remaining: 21m 43s
# 46:	learn: 20.7208873	total: 4m 2s	remaining: 21m 45s
# 47:	learn: 20.6651343	total: 4m 8s	remaining: 21m 43s
# 48:	learn: 20.6264402	total: 4m 12s	remaining: 21m 35s
# 49:	learn: 20.6083776	total: 4m 18s	remaining: 21m 30s
# 50:	learn: 20.5720581	total: 4m 22s	remaining: 21m 21s
# 51:	learn: 20.5197319	total: 4m 27s	remaining: 21m 15s
# 52:	learn: 20.4943792	total: 4m 32s	remaining: 21m 11s
# 53:	learn: 20.4585749	total: 4m 38s	remaining: 21m 7s
# 54:	learn: 20.4346898	total: 4m 43s	remaining: 21m 4s
# 55:	learn: 20.4190032	total: 4m 48s	remaining: 20m 55s
# 56:	learn: 20.3949734	total: 4m 52s	remaining: 20m 49s
# 57:	learn: 20.3533074	total: 4m 58s	remaining: 20m 44s
# 58:	learn: 20.2783609	total: 5m 3s	remaining: 20m 40s
# 59:	learn: 20.2633512	total: 5m 9s	remaining: 20m 39s
# 60:	learn: 20.2473718	total: 5m 15s	remaining: 20m 35s
# 61:	learn: 20.2040038	total: 5m 21s	remaining: 20m 33s
# 62:	learn: 20.1789021	total: 5m 26s	remaining: 20m 27s
# 63:	learn: 20.1558860	total: 5m 31s	remaining: 20m 21s
# 64:	learn: 20.1135947	total: 5m 36s	remaining: 20m 16s
# 65:	learn: 20.0942535	total: 5m 41s	remaining: 20m 10s
# 66:	learn: 20.0658810	total: 5m 46s	remaining: 20m 4s
# 67:	learn: 20.0527279	total: 5m 50s	remaining: 19m 56s
# 68:	learn: 20.0383937	total: 5m 56s	remaining: 19m 51s
# 69:	learn: 20.0213994	total: 6m	remaining: 19m 44s
# 70:	learn: 19.9845771	total: 6m 5s	remaining: 19m 39s
# 71:	learn: 19.9731094	total: 6m 11s	remaining: 19m 34s
# 72:	learn: 19.9578153	total: 6m 16s	remaining: 19m 31s
# 73:	learn: 19.9368611	total: 6m 22s	remaining: 19m 27s
# 74:	learn: 19.9142515	total: 6m 27s	remaining: 19m 23s
# 75:	learn: 19.8971134	total: 6m 33s	remaining: 19m 19s
# 76:	learn: 19.8730986	total: 6m 38s	remaining: 19m 14s
# 77:	learn: 19.8426368	total: 6m 43s	remaining: 19m 9s
# 78:	learn: 19.8200795	total: 6m 48s	remaining: 19m 3s
# 79:	learn: 19.8113602	total: 6m 53s	remaining: 18m 58s
# 80:	learn: 19.7635651	total: 6m 59s	remaining: 18m 53s
# 81:	learn: 19.7497900	total: 7m 4s	remaining: 18m 49s
# 82:	learn: 19.7139128	total: 7m 9s	remaining: 18m 43s
# 83:	learn: 19.6913725	total: 7m 14s	remaining: 18m 36s
# 84:	learn: 19.6671355	total: 7m 19s	remaining: 18m 32s
# 85:	learn: 19.6283692	total: 7m 25s	remaining: 18m 29s
# 86:	learn: 19.6086875	total: 7m 31s	remaining: 18m 25s
# 87:	learn: 19.5986003	total: 7m 36s	remaining: 18m 19s
# 88:	learn: 19.5717108	total: 7m 41s	remaining: 18m 15s
# 89:	learn: 19.5340943	total: 7m 47s	remaining: 18m 11s
# 90:	learn: 19.5089804	total: 7m 53s	remaining: 18m 8s
# 91:	learn: 19.4902557	total: 7m 58s	remaining: 18m 1s
# 92:	learn: 19.4651114	total: 8m 3s	remaining: 17m 56s
# 93:	learn: 19.4386392	total: 8m 9s	remaining: 17m 52s
# 94:	learn: 19.4240028	total: 8m 14s	remaining: 17m 47s
# 95:	learn: 19.4045509	total: 8m 19s	remaining: 17m 41s
# 96:	learn: 19.3808919	total: 8m 25s	remaining: 17m 38s
# 97:	learn: 19.3651325	total: 8m 31s	remaining: 17m 33s
# 98:	learn: 19.3507510	total: 8m 35s	remaining: 17m 27s
# 99:	learn: 19.3348479	total: 8m 41s	remaining: 17m 22s
# 100:	learn: 19.3137634	total: 8m 46s	remaining: 17m 16s
# 101:	learn: 19.2979287	total: 8m 51s	remaining: 17m 12s
# 102:	learn: 19.2734388	total: 8m 56s	remaining: 17m 6s
# 103:	learn: 19.2606554	total: 9m 1s	remaining: 17m
# 104:	learn: 19.2331944	total: 9m 6s	remaining: 16m 54s
# 105:	learn: 19.2158943	total: 9m 11s	remaining: 16m 49s
# 106:	learn: 19.2031081	total: 9m 16s	remaining: 16m 43s
# 107:	learn: 19.1973203	total: 9m 20s	remaining: 16m 36s
# 108:	learn: 19.1701397	total: 9m 26s	remaining: 16m 32s
# 109:	learn: 19.1484733	total: 9m 32s	remaining: 16m 28s
# 110:	learn: 19.1372937	total: 9m 37s	remaining: 16m 22s
# 111:	learn: 19.1160211	total: 9m 42s	remaining: 16m 18s
# 112:	learn: 19.1066160	total: 9m 48s	remaining: 16m 14s
# 113:	learn: 19.0929493	total: 9m 53s	remaining: 16m 8s
# 114:	learn: 19.0596330	total: 9m 58s	remaining: 16m 3s
# 115:	learn: 19.0404140	total: 10m 4s	remaining: 15m 58s
# 116:	learn: 19.0123799	total: 10m 9s	remaining: 15m 53s
# 117:	learn: 19.0012653	total: 10m 15s	remaining: 15m 48s
# 118:	learn: 18.9822470	total: 10m 20s	remaining: 15m 43s
# 119:	learn: 18.9697283	total: 10m 25s	remaining: 15m 38s
# 120:	learn: 18.9627135	total: 10m 30s	remaining: 15m 33s
# 121:	learn: 18.9498091	total: 10m 36s	remaining: 15m 28s
# 122:	learn: 18.9412174	total: 10m 41s	remaining: 15m 23s
# 123:	learn: 18.9250545	total: 10m 47s	remaining: 15m 18s
# 124:	learn: 18.9040125	total: 10m 52s	remaining: 15m 14s
# 125:	learn: 18.8939207	total: 10m 57s	remaining: 15m 7s
# 126:	learn: 18.8612928	total: 11m 3s	remaining: 15m 3s
# 127:	learn: 18.8398201	total: 11m 8s	remaining: 14m 58s
# 128:	learn: 18.8199927	total: 11m 13s	remaining: 14m 53s
# 129:	learn: 18.8068556	total: 11m 19s	remaining: 14m 48s
# 130:	learn: 18.8017948	total: 11m 24s	remaining: 14m 42s
# 131:	learn: 18.7764577	total: 11m 30s	remaining: 14m 38s
# 132:	learn: 18.7645989	total: 11m 34s	remaining: 14m 32s
# 133:	learn: 18.7403144	total: 11m 40s	remaining: 14m 27s
# 134:	learn: 18.7082199	total: 11m 45s	remaining: 14m 22s
# 135:	learn: 18.6917896	total: 11m 50s	remaining: 14m 16s
# 136:	learn: 18.6827260	total: 11m 55s	remaining: 14m 11s
# 137:	learn: 18.6672163	total: 12m	remaining: 14m 5s
# 138:	learn: 18.6517476	total: 12m 5s	remaining: 13m 59s
# 139:	learn: 18.6354241	total: 12m 10s	remaining: 13m 54s
# 140:	learn: 18.6215816	total: 12m 15s	remaining: 13m 48s
# 141:	learn: 18.6039079	total: 12m 20s	remaining: 13m 44s
# 142:	learn: 18.5865855	total: 12m 25s	remaining: 13m 38s
# 143:	learn: 18.5796908	total: 12m 32s	remaining: 13m 34s
# 144:	learn: 18.5654058	total: 12m 37s	remaining: 13m 30s
# 145:	learn: 18.5500709	total: 12m 43s	remaining: 13m 25s
# 146:	learn: 18.5318465	total: 12m 49s	remaining: 13m 20s
# 147:	learn: 18.5185309	total: 12m 53s	remaining: 13m 14s
# 148:	learn: 18.5142694	total: 12m 57s	remaining: 13m 8s
# 149:	learn: 18.4938731	total: 13m 2s	remaining: 13m 2s
# 150:	learn: 18.4691313	total: 13m 8s	remaining: 12m 58s
# 151:	learn: 18.4493135	total: 13m 13s	remaining: 12m 52s
# 152:	learn: 18.4341975	total: 13m 19s	remaining: 12m 47s
# 153:	learn: 18.4293881	total: 13m 24s	remaining: 12m 42s
# 154:	learn: 18.4178287	total: 13m 30s	remaining: 12m 37s
# 155:	learn: 18.4060623	total: 13m 36s	remaining: 12m 33s
# 156:	learn: 18.3792216	total: 13m 42s	remaining: 12m 29s
# 157:	learn: 18.3721878	total: 13m 47s	remaining: 12m 24s
# 158:	learn: 18.3678233	total: 13m 52s	remaining: 12m 18s
# 159:	learn: 18.3535927	total: 13m 58s	remaining: 12m 13s
# 160:	learn: 18.3409241	total: 14m 3s	remaining: 12m 8s
# 161:	learn: 18.3327978	total: 14m 8s	remaining: 12m 3s
# 162:	learn: 18.3101486	total: 14m 14s	remaining: 11m 57s
# 163:	learn: 18.2983156	total: 14m 19s	remaining: 11m 52s
# 164:	learn: 18.2891850	total: 14m 24s	remaining: 11m 47s
# 165:	learn: 18.2779440	total: 14m 30s	remaining: 11m 42s
# 166:	learn: 18.2689439	total: 14m 36s	remaining: 11m 38s
# 167:	learn: 18.2589772	total: 14m 41s	remaining: 11m 32s
# 168:	learn: 18.2527336	total: 14m 45s	remaining: 11m 26s
# 169:	learn: 18.2309213	total: 14m 51s	remaining: 11m 21s
# 170:	learn: 18.2215807	total: 14m 56s	remaining: 11m 16s
# 171:	learn: 18.2169546	total: 15m 2s	remaining: 11m 11s
# 172:	learn: 18.2035491	total: 15m 6s	remaining: 11m 5s
# 173:	learn: 18.1968313	total: 15m 11s	remaining: 11m
# 174:	learn: 18.1881732	total: 15m 17s	remaining: 10m 55s
# 175:	learn: 18.1798203	total: 15m 22s	remaining: 10m 50s
# 176:	learn: 18.1672728	total: 15m 28s	remaining: 10m 45s
# 177:	learn: 18.1527432	total: 15m 33s	remaining: 10m 39s
# 178:	learn: 18.1312583	total: 15m 39s	remaining: 10m 35s
# 179:	learn: 18.1038749	total: 15m 46s	remaining: 10m 30s
# 180:	learn: 18.0887469	total: 15m 51s	remaining: 10m 25s
# 181:	learn: 18.0822307	total: 15m 56s	remaining: 10m 20s
# 182:	learn: 18.0725947	total: 16m 1s	remaining: 10m 14s
# 183:	learn: 18.0585401	total: 16m 6s	remaining: 10m 9s
# 184:	learn: 18.0264058	total: 16m 11s	remaining: 10m 4s
# 185:	learn: 18.0097590	total: 16m 16s	remaining: 9m 58s
# 186:	learn: 18.0019952	total: 16m 21s	remaining: 9m 53s
# 187:	learn: 17.9890014	total: 16m 26s	remaining: 9m 47s
# 188:	learn: 17.9850206	total: 16m 30s	remaining: 9m 41s
# 189:	learn: 17.9573361	total: 16m 35s	remaining: 9m 36s
# 190:	learn: 17.9485311	total: 16m 41s	remaining: 9m 31s
# 191:	learn: 17.9415610	total: 16m 45s	remaining: 9m 25s
# 192:	learn: 17.9258978	total: 16m 50s	remaining: 9m 20s
# 193:	learn: 17.9212018	total: 16m 55s	remaining: 9m 14s
# 194:	learn: 17.9046557	total: 17m	remaining: 9m 9s
# 195:	learn: 17.8947287	total: 17m 6s	remaining: 9m 4s
# 196:	learn: 17.8783613	total: 17m 11s	remaining: 8m 59s
# 197:	learn: 17.8597226	total: 17m 17s	remaining: 8m 54s
# 198:	learn: 17.8465494	total: 17m 23s	remaining: 8m 49s
# 199:	learn: 17.8381314	total: 17m 28s	remaining: 8m 44s
# 200:	learn: 17.8303698	total: 17m 33s	remaining: 8m 39s
# 201:	learn: 17.8226964	total: 17m 38s	remaining: 8m 33s
# 202:	learn: 17.8077582	total: 17m 44s	remaining: 8m 28s
# 203:	learn: 17.8012460	total: 17m 49s	remaining: 8m 23s
# 204:	learn: 17.7925271	total: 17m 55s	remaining: 8m 18s
# 205:	learn: 17.7784451	total: 18m 1s	remaining: 8m 13s
# 206:	learn: 17.7685523	total: 18m 5s	remaining: 8m 7s
# 207:	learn: 17.7547209	total: 18m 10s	remaining: 8m 2s
# 208:	learn: 17.7393170	total: 18m 15s	remaining: 7m 57s
# 209:	learn: 17.7284835	total: 18m 21s	remaining: 7m 51s
# 210:	learn: 17.7063976	total: 18m 26s	remaining: 7m 46s
# 211:	learn: 17.6953504	total: 18m 32s	remaining: 7m 41s
# 212:	learn: 17.6866899	total: 18m 38s	remaining: 7m 36s
# 213:	learn: 17.6765703	total: 18m 43s	remaining: 7m 31s
# 214:	learn: 17.6684655	total: 18m 49s	remaining: 7m 26s
# 215:	learn: 17.6587852	total: 18m 54s	remaining: 7m 21s
# 216:	learn: 17.6531346	total: 18m 58s	remaining: 7m 15s
# 217:	learn: 17.6465539	total: 19m 4s	remaining: 7m 10s
# 218:	learn: 17.6429636	total: 19m 9s	remaining: 7m 5s
# 219:	learn: 17.6332306	total: 19m 14s	remaining: 6m 59s
# 220:	learn: 17.6197187	total: 19m 19s	remaining: 6m 54s
# 221:	learn: 17.6120772	total: 19m 25s	remaining: 6m 49s
# 222:	learn: 17.6019246	total: 19m 30s	remaining: 6m 44s
# 223:	learn: 17.5962352	total: 19m 36s	remaining: 6m 39s
# 224:	learn: 17.5855087	total: 19m 42s	remaining: 6m 34s
# 225:	learn: 17.5680488	total: 19m 47s	remaining: 6m 28s
# 226:	learn: 17.5607352	total: 19m 52s	remaining: 6m 23s
# 227:	learn: 17.5479186	total: 19m 58s	remaining: 6m 18s
# 228:	learn: 17.5337711	total: 20m 2s	remaining: 6m 12s
# 229:	learn: 17.5300501	total: 20m 7s	remaining: 6m 7s
# 230:	learn: 17.5215992	total: 20m 12s	remaining: 6m 2s
# 231:	learn: 17.4991456	total: 20m 19s	remaining: 5m 57s
# 232:	learn: 17.4802068	total: 20m 24s	remaining: 5m 52s
# 233:	learn: 17.4735491	total: 20m 29s	remaining: 5m 46s
# 234:	learn: 17.4660748	total: 20m 35s	remaining: 5m 41s
# 235:	learn: 17.4580812	total: 20m 41s	remaining: 5m 36s
# 236:	learn: 17.4482404	total: 20m 46s	remaining: 5m 31s
# 237:	learn: 17.4328603	total: 20m 51s	remaining: 5m 26s
# 238:	learn: 17.4241279	total: 20m 56s	remaining: 5m 20s
# 239:	learn: 17.4170393	total: 21m 1s	remaining: 5m 15s
# 240:	learn: 17.4120853	total: 21m 6s	remaining: 5m 10s
# 241:	learn: 17.4063505	total: 21m 12s	remaining: 5m 4s
# 242:	learn: 17.4017392	total: 21m 17s	remaining: 4m 59s
# 243:	learn: 17.3908310	total: 21m 22s	remaining: 4m 54s
# 244:	learn: 17.3848352	total: 21m 27s	remaining: 4m 49s
# 245:	learn: 17.3741016	total: 21m 32s	remaining: 4m 43s
# 246:	learn: 17.3675379	total: 21m 37s	remaining: 4m 38s
# 247:	learn: 17.3595951	total: 21m 43s	remaining: 4m 33s
# 248:	learn: 17.3568432	total: 21m 48s	remaining: 4m 28s
# 249:	learn: 17.3551658	total: 21m 53s	remaining: 4m 22s
# 250:	learn: 17.3437675	total: 21m 59s	remaining: 4m 17s
# 251:	learn: 17.3350972	total: 22m 4s	remaining: 4m 12s
# 252:	learn: 17.3281000	total: 22m 10s	remaining: 4m 7s
# 253:	learn: 17.3197115	total: 22m 16s	remaining: 4m 2s
# 254:	learn: 17.3127393	total: 22m 21s	remaining: 3m 56s
# 255:	learn: 17.2992401	total: 22m 26s	remaining: 3m 51s
# 256:	learn: 17.2906396	total: 22m 32s	remaining: 3m 46s
# 257:	learn: 17.2810493	total: 22m 37s	remaining: 3m 41s
# 258:	learn: 17.2705593	total: 22m 43s	remaining: 3m 35s
# 259:	learn: 17.2590882	total: 22m 48s	remaining: 3m 30s
# 260:	learn: 17.2576369	total: 22m 53s	remaining: 3m 25s
# 261:	learn: 17.2504580	total: 22m 59s	remaining: 3m 20s
# 262:	learn: 17.2467771	total: 23m 4s	remaining: 3m 14s
# 263:	learn: 17.2376856	total: 23m 9s	remaining: 3m 9s
# 264:	learn: 17.2333362	total: 23m 15s	remaining: 3m 4s
# 265:	learn: 17.2261225	total: 23m 21s	remaining: 2m 59s
# 266:	learn: 17.2184001	total: 23m 27s	remaining: 2m 53s
# 267:	learn: 17.2080139	total: 23m 31s	remaining: 2m 48s
# 268:	learn: 17.2011956	total: 23m 37s	remaining: 2m 43s
# 269:	learn: 17.1864563	total: 23m 42s	remaining: 2m 38s
# 270:	learn: 17.1842702	total: 23m 47s	remaining: 2m 32s
# 271:	learn: 17.1777392	total: 23m 52s	remaining: 2m 27s
# 272:	learn: 17.1770282	total: 23m 58s	remaining: 2m 22s
# 273:	learn: 17.1723016	total: 24m 3s	remaining: 2m 16s
# 274:	learn: 17.1559618	total: 24m 8s	remaining: 2m 11s
# 275:	learn: 17.1427068	total: 24m 14s	remaining: 2m 6s
# 276:	learn: 17.1380274	total: 24m 18s	remaining: 2m 1s
# 277:	learn: 17.1274009	total: 24m 24s	remaining: 1m 55s
# 278:	learn: 17.1243333	total: 24m 28s	remaining: 1m 50s
# 279:	learn: 17.1064964	total: 24m 34s	remaining: 1m 45s
# 280:	learn: 17.0961466	total: 24m 40s	remaining: 1m 40s
# 281:	learn: 17.0807431	total: 24m 45s	remaining: 1m 34s
# 282:	learn: 17.0758020	total: 24m 49s	remaining: 1m 29s
# 283:	learn: 17.0685914	total: 24m 54s	remaining: 1m 24s
# 284:	learn: 17.0627631	total: 24m 59s	remaining: 1m 18s
# 285:	learn: 17.0523310	total: 25m 4s	remaining: 1m 13s
# 286:	learn: 17.0425680	total: 25m 9s	remaining: 1m 8s
# 287:	learn: 17.0373877	total: 25m 14s	remaining: 1m 3s
# 288:	learn: 17.0285892	total: 25m 19s	remaining: 57.8s
# 289:	learn: 17.0203487	total: 25m 25s	remaining: 52.6s
# 290:	learn: 17.0119717	total: 25m 30s	remaining: 47.3s
# 291:	learn: 17.0086572	total: 25m 35s	remaining: 42.1s
# 292:	learn: 16.9994000	total: 25m 40s	remaining: 36.8s
# 293:	learn: 16.9964408	total: 25m 46s	remaining: 31.6s
# 294:	learn: 16.9866990	total: 25m 50s	remaining: 26.3s
# 295:	learn: 16.9855069	total: 25m 55s	remaining: 21s
# 296:	learn: 16.9765644	total: 26m 1s	remaining: 15.8s
# 297:	learn: 16.9706011	total: 26m 6s	remaining: 10.5s
# 298:	learn: 16.9544309	total: 26m 11s	remaining: 5.26s
# 299:	learn: 16.9441484	total: 26m 16s	remaining: 0us

# %% [markdown]
# Processing the test set

# %%
# %%time
test_dataframe = test_dataframe.copy()
test_dataframe['callable'] = test_dataframe.callable.astype('str')
test_dataframe['called'] = test_dataframe.called.astype('str')
test_dataframe['sinking'] = test_dataframe.sinking.astype('str')
test_dataframe['whenissued'] = test_dataframe.whenissued.astype('str')
test_dataframe['zerocoupon'] = test_dataframe.zerocoupon.astype('str')
test_dataframe['is_non_transaction_based_compensation'] = test_dataframe.is_non_transaction_based_compensation.astype('str')
test_dataframe['is_general_obligation'] = test_dataframe.is_general_obligation.astype('str')

#some categorical features are stores as numbers, we need to change them to strings
test_dataframe['coupon_type'] = test_dataframe.coupon_type.astype('str')
test_dataframe['muni_security_type'] = test_dataframe.muni_security_type.astype('str')
test_dataframe['called_redemption_type'] = test_dataframe.called_redemption_type.astype('str')
# Out:
# CPU times: user 145 ms, sys: 52 ms, total: 197 ms
# Wall time: 195 ms

# %%
test_target = test_dataframe[TARGET]
test_data = test_dataframe[NON_CAT_FEATURES + CATEGORICAL_FEATURES + BINARY]

# %%
CATF = CATEGORICAL_FEATURES + BINARY

# %%
test_set = Pool(test_data, test_target, cat_features=CATF)

# %%
print(model.get_params())
model.eval_metrics(test_set,['RMSE','MAE'],eval_period=50)
# Out:
# {'iterations': 300, 'depth': 14, 'loss_function': 'RMSE', 'verbose': True}
# {'RMSE': [42.424831515991116,
#   22.72216295152427,
#   22.525442832853138,
#   22.49961569281253,
#   22.494903842810697,
#   22.50526629079192,
#   22.514857050816218],
#  'MAE': [31.746718645503293,
#   16.30957875945107,
#   16.12666597602852,
#   16.08625526251984,
#   16.074700939425835,
#   16.071119742405664,
#   16.072864987958393]}

# %%
predicted_yield_spreads = model.predict(test_set)

# %%
evaluation_dataframe = test_dataframe.copy()
evaluation_dataframe['predicted_yield_spreads'] = predicted_yield_spreads
evaluation_dataframe['delta_yield_spreads'] = evaluation_dataframe.yield_spread - evaluation_dataframe.predicted_yield_spreads

# %%
evaluation_dataframe.sort_values('delta_yield_spreads', ascending=False)
# Out:
#        callable called sinking whenissued zerocoupon  \
# 396982     True  False   False      False      False
# 52475     False   True   False      False      False
# 377118    False  False   False      False      False
# 381947     True  False   False      False      False
# 161457    False  False   False      False      False
# ...         ...    ...     ...        ...        ...
# 87186      True  False    True      False      False
# 310422     True  False   False      False      False
# 194115    False   True   False      False      False
# 79012     False   True   False      False       True
# 179490     True  False    True      False      False
#
#        is_non_transaction_based_compensation is_general_obligation  quantity  \
# 396982                                 False                 False  4.301030
# 52475                                  False                 False  4.397940
# 377118                                 False                 False  4.000000
# 381947                                 False                 False  5.000000
# 161457                                 False                  True  5.161368
# ...                                      ...                   ...       ...
# 87186                                  False                 False  4.000000
# 310422                                 False                  True  4.000000
# 194115                                 False                  True  4.000000
# 79012                                  False                  True  4.301030
# 179490                                 False                 False  4.397940
#
#         days_to_maturity  days_to_call  ...  trade_type rating coupon_type  \
# 396982          2.029384      2.029384  ...           S     A+           8
# 52475           2.752816      2.752816  ...           S     A+           8
# 377118          1.653213      0.000000  ...           D    AA+           8
# 381947          1.477121      1.477121  ...           P     AA           8
# 161457          1.397940      0.000000  ...           P     AA           8
# ...                  ...           ...  ...         ...    ...         ...
# 87186           2.235528      2.235528  ...           D     AA          17
# 310422          1.591065      1.591065  ...           P     AA           8
# 194115          1.875061      1.792392  ...           D    AA-           8
# 79012           1.278754      0.000000  ...           D     AA           4
# 179490          1.431364      1.431364  ...           P     A-          17
#
#        muni_security_type called_redemption_type  \
# 396982                  8                    0.0
# 52475                   3                   13.0
# 377118                  1                    0.0
# 381947                  8                    0.0
# 161457                  5                    0.0
# ...                   ...                    ...
# 87186                   8                    0.0
# 310422                  6                    0.0
# 194115                  5                    6.0
# 79012                   5                   17.0
# 179490                  8                    0.0
#
#                                                    issuer settle_pace  \
# 396982                      DE KALB CNTY GA WTR & SEW REV        Fast
# 52475              MIAMI-DADE CNTY FLA SCH BRD CTFS PARTN        Fast
# 377118  SOUTHERN CALIF WTR REPLENISHMENT DIST FING AUT...        Fast
# 381947  NEW YORK N Y CITY TRANSITIONAL FIN AUTH BLDG A...        Fast
# 161457            WILLIAMSON CNTY TEX MUN UTIL DIST NO 11        Fast
# ...                                                   ...         ...
# 87186                      KANSAS CITY MO SAN SWR SYS REV        Fast
# 310422                        ROSE TREE MEDIA PA SCH DIST        Fast
# 194115                                      CALIFORNIA ST        Fast
# 79012                          ROSS VALLEY CALIF SCH DIST        Fast
# 179490      DADEVILLE ALA WTR WKS & SEW BRD WTR & SWR REV      Medium
#
#        yield_spread  predicted_yield_spreads  delta_yield_spreads
# 396982   162.211440              -109.242426           271.453866
# 52475    197.752258               -71.982415           269.734673
# 377118   196.553637               -69.768999           266.322636
# 381947   200.353637               -65.568553           265.922191
# 161457   163.009603               -97.892641           260.902244
# ...             ...                      ...                  ...
# 87186    -91.988858                77.923862          -169.912720
# 310422   -98.618239                87.670027          -186.288266
# 194115   -80.631237               111.867634          -192.498872
# 79012    -61.488858               160.835883          -222.324740
# 179490   -68.833553               170.479351          -239.312905
#
# [390651 rows x 21 columns]
