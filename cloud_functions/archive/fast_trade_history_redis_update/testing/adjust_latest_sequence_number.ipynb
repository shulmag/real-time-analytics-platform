# %%
import os
from datetime import datetime

# TODO: comment the below line out when not running the function locally
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = '/Users/user/ficc/ficc/mitas_creds.json'

from main import eastern, YEAR_MONTH_DAY, HOUR_MIN_SEC, get_latest_sequence_number, update_latest_sequence_number

# %%
current_timestamp = datetime.now(eastern).strftime(f'{YEAR_MONTH_DAY}_{HOUR_MIN_SEC}')
latest_sequence_number = get_latest_sequence_number(current_timestamp)

# %%
latest_sequence_number

# %%
sequence_number_to_set = 53037
update_latest_sequence_number(current_timestamp, sequence_number_to_set)
