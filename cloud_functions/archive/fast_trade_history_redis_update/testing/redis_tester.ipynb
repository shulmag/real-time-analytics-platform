# %%
'''
Date: 2023-08-08
Last Edit Date: 2024-11-15
Description: Used to test the redis that is used in `cloud_functions/fast_trade_history_redis_update/main.py`.
'''

# %%
import os

import pandas as pd
import pickle

import redis

# %%
from tqdm import tqdm

# %%
FEATURES_FOR_EACH_TRADE_IN_HISTORY = {'msrb_valid_from_date': 'DATETIME', 
                                      'msrb_valid_to_date': 'DATETIME', 
                                      'rtrs_control_number': 'INTEGER', 
                                      'trade_datetime': 'DATETIME', 
                                      'publish_datetime': 'DATETIME', 
                                      'yield': 'FLOAT', 
                                      'dollar_price': 'FLOAT', 
                                      'par_traded': 'NUMERIC', 
                                      'trade_type': 'STRING', 
                                      'is_non_transaction_based_compensation': 'BOOLEAN', 
                                      'is_lop_or_takedown': 'BOOLEAN', 
                                      'brokers_broker': 'STRING', 
                                      'is_alternative_trading_system': 'BOOLEAN', 
                                      'is_weighted_average_price': 'BOOLEAN', 
                                      'settlement_date': 'DATE', 
                                      'calc_date': 'DATE', 
                                      'calc_day_cat': 'INTEGER', 
                                      'maturity_date': 'DATE', 
                                      'next_call_date': 'DATE', 
                                      'par_call_date': 'DATE', 
                                      'refund_date': 'DATE', 
                                      'transaction_type': 'STRING', 
                                      'sequence_number': 'INTEGER'}

# %%
trade_history_redis_host = os.environ.get('REDISHOST', '10.84.7.180')    # TODO: update this redis to have more memory and read replicas in similar vein to the current reference data redis (currently this redis is for testing)
trade_history_redis_port = int(os.environ.get('REDISPORT', 6379))
trade_history_redis_client = redis.Redis(host=trade_history_redis_host, port=trade_history_redis_port, db=0)

# %%
cusip_of_interest = '64971XQM3'

# %%
trade_history = trade_history_redis_client.get(cusip_of_interest)
trade_history = pd.DataFrame(pickle.loads(trade_history), columns=list(FEATURES_FOR_EACH_TRADE_IN_HISTORY.keys()))

# %%
trade_history
# Out:
#    msrb_valid_from_date msrb_valid_to_date rtrs_control_number  \
# 0   2023-09-07 12:38:52         2100-01-01    2023090705654800
# 1   2023-08-28 15:47:35         2100-01-01    2023082809802500
# 2   2023-08-28 15:47:35         2100-01-01    2023082809802000
# 3   2023-08-28 12:33:10         2100-01-01    2023082804845500
# 4   2023-08-28 12:33:10         2100-01-01    2023082804845600
# 5   2023-08-25 10:51:40         2100-01-01    2023082502332300
# 6   2023-08-22 15:57:08         2100-01-01    2023082211667900
# 7   2023-08-22 15:52:58         2100-01-01    2023082211581700
# 8   2023-08-21 12:16:39         2100-01-01    2023082104730000
# 9   2023-08-21 12:16:20         2100-01-01    2023082104717500
# 10  2023-08-09 13:01:22         2100-01-01    2023080906192100
# 11  2023-08-09 12:58:35         2100-01-01    2023080906191900
# 12  2023-08-09 10:28:34         2100-01-01    2023080901748300
# 13  2023-08-09 09:46:18         2100-01-01    2023080900976600
# 14  2023-08-09 09:46:18         2100-01-01    2023080900981000
# 15  2023-08-09 09:46:18         2100-01-01    2023080900983500
# 16  2023-08-09 09:46:18         2100-01-01    2023080900983200
# 17  2023-08-09 09:44:21         2100-01-01    2023080900949700
# 18  2023-08-07 11:03:28         2100-01-01    2023080702642400
# 19  2023-08-04 10:37:13         2100-01-01    2023080402337200
# 20  2023-08-04 10:37:13         2100-01-01    2023080402347400
# 21  2023-08-03 12:36:20         2100-01-01    2023080306281400
# 22  2023-08-03 12:36:21         2100-01-01    2023080306268900
# 23  2023-08-03 12:28:34         2100-01-01    2023080305980700
# 24  2023-08-03 11:02:30         2100-01-01    2023080303185000
# 25  2023-08-03 11:02:30         2100-01-01    2023080303184900
# 26  2023-08-03 10:42:04         2100-01-01    2023080302608600
# 27  2023-08-03 10:41:14         2100-01-01    2023080302589600
# 28  2023-08-03 10:08:16         2100-01-01    2023080301767700
# 29  2023-08-03 10:07:15         2100-01-01    2023080301742500
# 30  2023-08-02 15:09:42         2100-01-01    2023080210936300
# 31  2023-08-02 15:07:31         2100-01-01    2023080210864700
#
#         trade_datetime    publish_datetime  yield dollar_price  \
# 0  2023-09-07 12:38:39 2023-09-07 12:38:52  4.351        95.11
# 1  2023-08-28 15:47:25 2023-08-28 15:47:35  4.297        95.83
# 2  2023-08-28 15:47:25 2023-08-28 15:47:35  4.153        97.83
# 3  2023-08-28 12:32:57 2023-08-28 12:33:10  4.454        93.73
# 4  2023-08-28 12:32:57 2023-08-28 12:33:10  4.454        93.73
# 5  2023-08-25 10:51:28 2023-08-25 10:51:40  4.155       97.793
# 6  2023-08-22 15:56:55 2023-08-22 15:57:08  4.155       97.793
# 7  2023-08-22 15:52:44 2023-08-22 15:52:58  4.155       97.793
# 8  2023-08-21 12:15:26 2023-08-21 12:16:39  4.306       95.708
# 9  2023-08-21 12:15:21 2023-08-21 12:16:20    4.3       95.793
# 10 2023-08-09 12:58:24 2023-08-09 13:01:22  4.195       97.233
# 11 2023-08-09 12:58:24 2023-08-09 12:58:35  4.195       97.233
# 12 2023-08-09 10:28:28 2023-08-09 10:28:34  4.125       98.209
# 13 2023-08-09 09:45:42 2023-08-09 09:46:18  4.218       96.913
# 14 2023-08-09 09:45:42 2023-08-09 09:46:18    4.2       97.163
# 15 2023-08-09 09:45:42 2023-08-09 09:46:18  4.167       97.628
# 16 2023-08-09 09:45:42 2023-08-09 09:46:18  4.195       97.228
# 17 2023-08-09 09:44:01 2023-08-09 09:44:21  4.277       96.102
# 18 2023-08-07 11:00:20 2023-08-07 11:03:28   4.11       98.424
# 19 2023-08-04 10:36:33 2023-08-04 10:37:13  4.299       95.797
# 20 2023-08-04 10:36:32 2023-08-04 10:37:13   4.29       95.922
# 21 2023-08-03 12:36:10 2023-08-03 12:36:20  4.125       98.212
# 22 2023-08-03 12:35:21 2023-08-03 12:36:21    4.2       97.162
# 23 2023-08-03 12:27:35 2023-08-03 12:28:34  4.204       97.102
# 24 2023-08-03 11:02:15 2023-08-03 11:02:30   4.19       97.301
# 25 2023-08-03 11:02:15 2023-08-03 11:02:30  4.048       99.301
# 26 2023-08-03 10:40:58 2023-08-03 10:42:04  4.187       97.338
# 27 2023-08-03 10:40:57 2023-08-03 10:41:14  4.046       99.338
# 28 2023-08-03 10:07:05 2023-08-03 10:08:16  4.211       97.006
# 29 2023-08-03 10:07:04 2023-08-03 10:07:15  4.069       99.006
# 30 2023-08-02 15:07:23 2023-08-02 15:09:42  4.192       97.276
# 31 2023-08-02 15:07:22 2023-08-02 15:07:31   4.05       99.276
#
#           par_traded trade_type is_non_transaction_based_compensation  ...  \
# 0    50000.000000000          P                                 False  ...
# 1    15000.000000000          D                                 False  ...
# 2    15000.000000000          S                                 False  ...
# 3    15000.000000000          P                                  True  ...
# 4    15000.000000000          D                                 False  ...
# 5    25000.000000000          S                                 False  ...
# 6    15000.000000000          S                                 False  ...
# 7    30000.000000000          S                                 False  ...
# 8    70000.000000000          D                                 False  ...
# 9    70000.000000000          D                                 False  ...
# 10   15000.000000000          D                                 False  ...
# 11   15000.000000000          P                                  True  ...
# 12   50000.000000000          S                                 False  ...
# 13   25000.000000000          D                                 False  ...
# 14   25000.000000000          D                                 False  ...
# 15   25000.000000000          S                                 False  ...
# 16   25000.000000000          D                                 False  ...
# 17   50000.000000000          P                                 False  ...
# 18   25000.000000000          S                                 False  ...
# 19   50000.000000000          D                                 False  ...
# 20   50000.000000000          D                                 False  ...
# 21  385000.000000000          S                                 False  ...
# 22  385000.000000000          D                                 False  ...
# 23  385000.000000000          D                                 False  ...
# 24   50000.000000000          D                                 False  ...
# 25   50000.000000000          S                                 False  ...
# 26   30000.000000000          D                                 False  ...
# 27   30000.000000000          S                                 False  ...
# 28   75000.000000000          D                                 False  ...
# 29   75000.000000000          S                                 False  ...
# 30   15000.000000000          D                                 False  ...
# 31   15000.000000000          S                                 False  ...
#
#    is_weighted_average_price settlement_date   calc_date calc_day_cat  \
# 0                      False      2023-09-11  2045-05-01            2
# 1                      False      2023-08-30  2045-05-01            2
# 2                      False      2023-08-30  2045-05-01            2
# 3                      False      2023-08-30  2045-05-01            2
# 4                      False      2023-08-30  2045-05-01            2
# 5                      False      2023-08-29  2045-05-01            2
# 6                      False      2023-08-24  2045-05-01            2
# 7                      False      2023-08-24  2045-05-01            2
# 8                      False      2023-08-23  2045-05-01            2
# 9                      False      2023-08-23  2045-05-01            2
# 10                     False      2023-08-11  2045-05-01            2
# 11                     False      2023-08-11  2045-05-01            2
# 12                     False      2023-08-11  2045-05-01            2
# 13                     False      2023-08-11  2045-05-01            2
# 14                     False      2023-08-11  2045-05-01            2
# 15                     False      2023-08-11  2045-05-01            2
# 16                     False      2023-08-11  2045-05-01            2
# 17                     False      2023-08-10  2045-05-01            2
# 18                     False      2023-08-09  2045-05-01            2
# 19                     False      2023-08-08  2045-05-01            2
# 20                     False      2023-08-08  2045-05-01            2
# 21                     False      2023-08-07  2045-05-01            2
# 22                     False      2023-08-07  2045-05-01            2
# 23                     False      2023-08-07  2045-05-01            2
# 24                     False      2023-08-07  2045-05-01            2
# 25                     False      2023-08-07  2045-05-01            2
# 26                     False      2023-08-07  2045-05-01            2
# 27                     False      2023-08-07  2045-05-01            2
# 28                     False      2023-08-07  2045-05-01            2
# 29                     False      2023-08-07  2045-05-01            2
# 30                     False      2023-08-04  2045-05-01            2
# 31                     False      2023-08-04  2045-05-01            2
#
#    maturity_date next_call_date par_call_date refund_date transaction_type  \
# 0     2045-05-01     2030-11-01    2030-11-01        None                I
# 1     2045-05-01     2030-11-01    2030-11-01        None                I
# 2     2045-05-01     2030-11-01    2030-11-01        None                I
# 3     2045-05-01     2030-11-01    2030-11-01        None                I
# 4     2045-05-01     2030-11-01    2030-11-01        None                I
# 5     2045-05-01     2030-11-01    2030-11-01        None                I
# 6     2045-05-01     2030-11-01    2030-11-01        None                I
# 7     2045-05-01     2030-11-01    2030-11-01        None                I
# 8     2045-05-01     2030-11-01    2030-11-01        None                I
# 9     2045-05-01     2030-11-01    2030-11-01        None                I
# 10    2045-05-01     2030-11-01    2030-11-01        None                I
# 11    2045-05-01     2030-11-01    2030-11-01        None                I
# 12    2045-05-01     2030-11-01    2030-11-01        None                I
# 13    2045-05-01     2030-11-01    2030-11-01        None                I
# 14    2045-05-01     2030-11-01    2030-11-01        None                I
# 15    2045-05-01     2030-11-01    2030-11-01        None                I
# 16    2045-05-01     2030-11-01    2030-11-01        None                I
# 17    2045-05-01     2030-11-01    2030-11-01        None                I
# 18    2045-05-01     2030-11-01    2030-11-01        None                I
# 19    2045-05-01     2030-11-01    2030-11-01        None                I
# 20    2045-05-01     2030-11-01    2030-11-01        None                I
# 21    2045-05-01     2030-11-01    2030-11-01        None                I
# 22    2045-05-01     2030-11-01    2030-11-01        None                I
# 23    2045-05-01     2030-11-01    2030-11-01        None                I
# 24    2045-05-01     2030-11-01    2030-11-01        None                I
# 25    2045-05-01     2030-11-01    2030-11-01        None                I
# 26    2045-05-01     2030-11-01    2030-11-01        None                I
# 27    2045-05-01     2030-11-01    2030-11-01        None                I
# 28    2045-05-01     2030-11-01    2030-11-01        None                I
# 29    2045-05-01     2030-11-01    2030-11-01        None                I
# 30    2045-05-01     2030-11-01    2030-11-01        None                I
# 31    2045-05-01     2030-11-01    2030-11-01        None                I
#
#    sequence_number
# 0          25381.0
# 1          43754.0
# 2          43750.0
# 3          21818.0
# 4          21819.0
# 5           9504.0
# 6          51438.0
# 7          51085.0
# 8          20579.0
# 9          20520.0
# 10         28819.0
# 11         28395.0
# 12          7620.0
# 13          4456.0
# 14          4472.0
# 15          4466.0
# 16          4468.0
# 17          4329.0
# 18         10433.0
# 19          9129.0
# 20          9131.0
# 21         25801.0
# 22         25817.0
# 23         24610.0
# 24         12470.0
# 25         12469.0
# 26         10043.0
# 27          9966.0
# 28          6701.0
# 29          6606.0
# 30         47040.0
# 31         46746.0
#
# [32 rows x 23 columns]

# %%
trade_history.to_dict('records')
# Out:
# [{'msrb_valid_from_date': Timestamp('2023-09-07 12:38:52'),
#   'msrb_valid_to_date': Timestamp('2100-01-01 00:00:00'),
#   'rtrs_control_number': 2023090705654800,
#   'trade_datetime': Timestamp('2023-09-07 12:38:39'),
#   'publish_datetime': Timestamp('2023-09-07 12:38:52'),
#   'yield': 4.351,
#   'dollar_price': 95.11,
#   'par_traded': Decimal('50000.000000000'),
#   'trade_type': 'P',
#   'is_non_transaction_based_compensation': False,
#   'is_lop_or_takedown': False,
#   'brokers_broker': None,
#   'is_alternative_trading_system': False,
#   'is_weighted_average_price': False,
#   'settlement_date': datetime.date(2023, 9, 11),
#   'calc_date': datetime.date(2045, 5, 1),
#   'calc_day_cat': 2,
#   'maturity_date': datetime.date(2045, 5, 1),
#   'next_call_date': datetime.date(2030, 11, 1),
#   'par_call_date': datetime.date(2030, 11, 1),
#   'refund_date': None,
#   'transaction_type': 'I',
#   'sequence_number': 25381.0},
#  {'msrb_valid_from_date': Timestamp('2023-08-28 15:47:35'),
#   'msrb_valid_to_date': Timestamp('2100-01-01 00:00:00'),
#   'rtrs_control_number': 2023082809802500,
#   'trade_datetime': Timestamp('2023-08-28 15:47:25'),
#   'publish_datetime': Timestamp('2023-08-28 15:47:35'),
#   'yield': 4.297,
#   'dollar_price': 95.83,
#   'par_traded': Decimal('15000.000000000'),
#   'trade_type': 'D',
#   'is_non_transaction_based_compensation': False,
#   'is_lop_or_takedown': False,
#   'brokers_broker': None,
#   'is_alternative_trading_system': True,
#   'is_weighted_average_price': False,
#   'settlement_date': datetime.date(2023, 8, 30),
#   'calc_date': datetime.date(2045, 5, 1),
#   'calc_day_cat': 2,
#   'maturity_date': datetime.date(2045, 5, 1),
#   'next_call_date': datetime.date(2030, 11, 1),
#   'par_call_date': datetime.date(2030, 11, 1),
#   'refund_date': None,
#   'transaction_type': 'I',
#   'sequence_number': 43754.0},
#  {'msrb_valid_from_date': Timestamp('2023-08-28 15:47:35'),
#   'msrb_valid_to_date': Timestamp('2100-01-01 00:00:00'),
#   'rtrs_control_number': 2023082809802000,
#   'trade_datetime': Timestamp('2023-08-28 15:47:25'),
#   'publish_datetime': Timestamp('2023-08-28 15:47:35'),
#   'yield': 4.153,
#   'dollar_price': 97.83,
#   'par_traded': Decimal('15000.000000000'),
#   'trade_type': 'S',
#   'is_non_transaction_based_compensation': False,
#   'is_lop_or_takedown': False,
#   'brokers_broker': None,
#   'is_alternative_trading_system': False,
#   'is_weighted_average_price': False,
#   'settlement_date': datetime.date(2023, 8, 30),
#   'calc_date': datetime.date(2045, 5, 1),
#   'calc_day_cat': 2,
#   'maturity_date': datetime.date(2045, 5, 1),
#   'next_call_date': datetime.date(2030, 11, 1),
#   'par_call_date': datetime.date(2030, 11, 1),
#   'refund_date': None,
#   'transaction_type': 'I',
#   'sequence_number': 43750.0},
#  {'msrb_valid_from_date': Timestamp('2023-08-28 12:33:10'),
#   'msrb_valid_to_date': Timestamp('2100-01-01 00:00:00'),
#   'rtrs_control_number': 2023082804845500,
#   'trade_datetime': Timestamp('2023-08-28 12:32:57'),
#   'publish_datetime': Timestamp('2023-08-28 12:33:10'),
#   'yield': 4.454,
#   'dollar_price': 93.73,
#   'par_traded': Decimal('15000.000000000'),
#   'trade_type': 'P',
#   'is_non_transaction_based_compensation': True,
#   'is_lop_or_takedown': False,
#   'brokers_broker': None,
#   'is_alternative_trading_system': False,
#   'is_weighted_average_price': False,
#   'settlement_date': datetime.date(2023, 8, 30),
#   'calc_date': datetime.date(2045, 5, 1),
#   'calc_day_cat': 2,
#   'maturity_date': datetime.date(2045, 5, 1),
#   'next_call_date': datetime.date(2030, 11, 1),
#   'par_call_date': datetime.date(2030, 11, 1),
#   'refund_date': None,
#   'transaction_type': 'I',
#   'sequence_number': 21818.0},
#  {'msrb_valid_from_date': Timestamp('2023-08-28 12:33:10'),
#   'msrb_valid_to_date': Timestamp('2100-01-01 00:00:00'),
#   'rtrs_control_number': 2023082804845600,
#   'trade_datetime': Timestamp('2023-08-28 12:32:57'),
#   'publish_datetime': Timestamp('2023-08-28 12:33:10'),
#   'yield': 4.454,
#   'dollar_price': 93.73,
#   'par_traded': Decimal('15000.000000000'),
#   'trade_type': 'D',
#   'is_non_transaction_based_compensation': False,
#   'is_lop_or_takedown': False,
#   'brokers_broker': None,
#   'is_alternative_trading_system': False,
#   'is_weighted_average_price': False,
#   'settlement_date': datetime.date(2023, 8, 30),
#   'calc_date': datetime.date(2045, 5, 1),
#   'calc_day_cat': 2,
#   'maturity_date': datetime.date(2045, 5, 1),
#   'next_call_date': datetime.date(2030, 11, 1),
#   'par_call_date': datetime.date(2030, 11, 1),
#   'refund_date': None,
#   'transaction_type': 'I',
#   'sequence_number': 21819.0},
#  {'msrb_valid_from_date': Timestamp('2023-08-25 10:51:40'),
#   'msrb_valid_to_date': Timestamp('2100-01-01 00:00:00'),
#   'rtrs_control_number': 2023082502332300,
#   'trade_datetime': Timestamp('2023-08-25 10:51:28'),
#   'publish_datetime': Timestamp('2023-08-25 10:51:40'),
#   'yield': 4.155,
#   'dollar_price': 97.793,
#   'par_traded': Decimal('25000.000000000'),
#   'trade_type': 'S',
#   'is_non_transaction_based_compensation': False,
#   'is_lop_or_takedown': False,
#   'brokers_broker': None,
#   'is_alternative_trading_system': False,
#   'is_weighted_average_price': False,
#   'settlement_date': datetime.date(2023, 8, 29),
#   'calc_date': datetime.date(2045, 5, 1),
#   'calc_day_cat': 2,
#   'maturity_date': datetime.date(2045, 5, 1),
#   'next_call_date': datetime.date(2030, 11, 1),
#   'par_call_date': datetime.date(2030, 11, 1),
#   'refund_date': None,
#   'transaction_type': 'I',
#   'sequence_number': 9504.0},
#  {'msrb_valid_from_date': Timestamp('2023-08-22 15:57:08'),
#   'msrb_valid_to_date': Timestamp('2100-01-01 00:00:00'),
#   'rtrs_control_number': 2023082211667900,
#   'trade_datetime': Timestamp('2023-08-22 15:56:55'),
#   'publish_datetime': Timestamp('2023-08-22 15:57:08'),
#   'yield': 4.155,
#   'dollar_price': 97.793,
#   'par_traded': Decimal('15000.000000000'),
#   'trade_type': 'S',
#   'is_non_transaction_based_compensation': False,
#   'is_lop_or_takedown': False,
#   'brokers_broker': None,
#   'is_alternative_trading_system': False,
#   'is_weighted_average_price': False,
#   'settlement_date': datetime.date(2023, 8, 24),
#   'calc_date': datetime.date(2045, 5, 1),
#   'calc_day_cat': 2,
#   'maturity_date': datetime.date(2045, 5, 1),
#   'next_call_date': datetime.date(2030, 11, 1),
#   'par_call_date': datetime.date(2030, 11, 1),
#   'refund_date': None,
#   'transaction_type': 'I',
#   'sequence_number': 51438.0},
#  {'msrb_valid_from_date': Timestamp('2023-08-22 15:52:58'),
#   'msrb_valid_to_date': Timestamp('2100-01-01 00:00:00'),
#   'rtrs_control_number': 2023082211581700,
#   'trade_datetime': Timestamp('2023-08-22 15:52:44'),
#   'publish_datetime': Timestamp('2023-08-22 15:52:58'),
#   'yield': 4.155,
#   'dollar_price': 97.793,
#   'par_traded': Decimal('30000.000000000'),
#   'trade_type': 'S',
#   'is_non_transaction_based_compensation': False,
#   'is_lop_or_takedown': False,
#   'brokers_broker': None,
#   'is_alternative_trading_system': False,
#   'is_weighted_average_price': False,
#   'settlement_date': datetime.date(2023, 8, 24),
#   'calc_date': datetime.date(2045, 5, 1),
#   'calc_day_cat': 2,
#   'maturity_date': datetime.date(2045, 5, 1),
#   'next_call_date': datetime.date(2030, 11, 1),
#   'par_call_date': datetime.date(2030, 11, 1),
#   'refund_date': None,
#   'transaction_type': 'I',
#   'sequence_number': 51085.0},
#  {'msrb_valid_from_date': Timestamp('2023-08-21 12:16:39'),
#   'msrb_valid_to_date': Timestamp('2100-01-01 00:00:00'),
#   'rtrs_control_number': 2023082104730000,
#   'trade_datetime': Timestamp('2023-08-21 12:15:26'),
#   'publish_datetime': Timestamp('2023-08-21 12:16:39'),
#   'yield': 4.306,
#   'dollar_price': 95.708,
#   'par_traded': Decimal('70000.000000000'),
#   'trade_type': 'D',
#   'is_non_transaction_based_compensation': False,
#   'is_lop_or_takedown': False,
#   'brokers_broker': None,
#   'is_alternative_trading_system': True,
#   'is_weighted_average_price': False,
#   'settlement_date': datetime.date(2023, 8, 23),
#   'calc_date': datetime.date(2045, 5, 1),
#   'calc_day_cat': 2,
#   'maturity_date': datetime.date(2045, 5, 1),
#   'next_call_date': datetime.date(2030, 11, 1),
#   'par_call_date': datetime.date(2030, 11, 1),
#   'refund_date': None,
#   'transaction_type': 'I',
#   'sequence_number': 20579.0},
#  {'msrb_valid_from_date': Timestamp('2023-08-21 12:16:20'),
#   'msrb_valid_to_date': Timestamp('2100-01-01 00:00:00'),
#   'rtrs_control_number': 2023082104717500,
#   'trade_datetime': Timestamp('2023-08-21 12:15:21'),
#   'publish_datetime': Timestamp('2023-08-21 12:16:20'),
#   'yield': 4.3,
#   'dollar_price': 95.793,
#   'par_traded': Decimal('70000.000000000'),
#   'trade_type': 'D',
#   'is_non_transaction_based_compensation': False,
#   'is_lop_or_takedown': False,
#   'brokers_broker': None,
#   'is_alternative_trading_system': True,
#   'is_weighted_average_price': False,
#   'settlement_date': datetime.date(2023, 8, 23),
#   'calc_date': datetime.date(2045, 5, 1),
#   'calc_day_cat': 2,
#   'maturity_date': datetime.date(2045, 5, 1),
#   'next_call_date': datetime.date(2030, 11, 1),
#   'par_call_date': datetime.date(2030, 11, 1),
#   'refund_date': None,
#   'transaction_type': 'I',
#   'sequence_number': 20520.0},
#  {'msrb_valid_from_date': Timestamp('2023-08-09 13:01:22'),
#   'msrb_valid_to_date': Timestamp('2100-01-01 00:00:00'),
#   'rtrs_control_number': 2023080906192100,
#   'trade_datetime': Timestamp('2023-08-09 12:58:24'),
#   'publish_datetime': Timestamp('2023-08-09 13:01:22'),
#   'yield': 4.195,
#   'dollar_price': 97.233,
#   'par_traded': Decimal('15000.000000000'),
#   'trade_type': 'D',
#   'is_non_transaction_based_compensation': False,
#   'is_lop_or_takedown': False,
#   'brokers_broker': None,
#   'is_alternative_trading_system': False,
#   'is_weighted_average_price': False,
#   'settlement_date': datetime.date(2023, 8, 11),
#   'calc_date': datetime.date(2045, 5, 1),
#   'calc_day_cat': 2,
#   'maturity_date': datetime.date(2045, 5, 1),
#   'next_call_date': datetime.date(2030, 11, 1),
#   'par_call_date': datetime.date(2030, 11, 1),
#   'refund_date': None,
#   'transaction_type': 'I',
#   'sequence_number': 28819.0},
#  {'msrb_valid_from_date': Timestamp('2023-08-09 12:58:35'),
#   'msrb_valid_to_date': Timestamp('2100-01-01 00:00:00'),
#   'rtrs_control_number': 2023080906191900,
#   'trade_datetime': Timestamp('2023-08-09 12:58:24'),
#   'publish_datetime': Timestamp('2023-08-09 12:58:35'),
#   'yield': 4.195,
#   'dollar_price': 97.233,
#   'par_traded': Decimal('15000.000000000'),
#   'trade_type': 'P',
#   'is_non_transaction_based_compensation': True,
#   'is_lop_or_takedown': False,
#   'brokers_broker': None,
#   'is_alternative_trading_system': False,
#   'is_weighted_average_price': False,
#   'settlement_date': datetime.date(2023, 8, 11),
#   'calc_date': datetime.date(2045, 5, 1),
#   'calc_day_cat': 2,
#   'maturity_date': datetime.date(2045, 5, 1),
#   'next_call_date': datetime.date(2030, 11, 1),
#   'par_call_date': datetime.date(2030, 11, 1),
#   'refund_date': None,
#   'transaction_type': 'I',
#   'sequence_number': 28395.0},
#  {'msrb_valid_from_date': Timestamp('2023-08-09 10:28:34'),
#   'msrb_valid_to_date': Timestamp('2100-01-01 00:00:00'),
#   'rtrs_control_number': 2023080901748300,
#   'trade_datetime': Timestamp('2023-08-09 10:28:28'),
#   'publish_datetime': Timestamp('2023-08-09 10:28:34'),
#   'yield': 4.125,
#   'dollar_price': 98.209,
#   'par_traded': Decimal('50000.000000000'),
#   'trade_type': 'S',
#   'is_non_transaction_based_compensation': False,
#   'is_lop_or_takedown': False,
#   'brokers_broker': None,
#   'is_alternative_trading_system': False,
#   'is_weighted_average_price': False,
#   'settlement_date': datetime.date(2023, 8, 11),
#   'calc_date': datetime.date(2045, 5, 1),
#   'calc_day_cat': 2,
#   'maturity_date': datetime.date(2045, 5, 1),
#   'next_call_date': datetime.date(2030, 11, 1),
#   'par_call_date': datetime.date(2030, 11, 1),
#   'refund_date': None,
#   'transaction_type': 'I',
#   'sequence_number': 7620.0},
#  {'msrb_valid_from_date': Timestamp('2023-08-09 09:46:18'),
#   'msrb_valid_to_date': Timestamp('2100-01-01 00:00:00'),
#   'rtrs_control_number': 2023080900976600,
#   'trade_datetime': Timestamp('2023-08-09 09:45:42'),
#   'publish_datetime': Timestamp('2023-08-09 09:46:18'),
#   'yield': 4.218,
#   'dollar_price': 96.913,
#   'par_traded': Decimal('25000.000000000'),
#   'trade_type': 'D',
#   'is_non_transaction_based_compensation': False,
#   'is_lop_or_takedown': False,
#   'brokers_broker': None,
#   'is_alternative_trading_system': True,
#   'is_weighted_average_price': False,
#   'settlement_date': datetime.date(2023, 8, 11),
#   'calc_date': datetime.date(2045, 5, 1),
#   'calc_day_cat': 2,
#   'maturity_date': datetime.date(2045, 5, 1),
#   'next_call_date': datetime.date(2030, 11, 1),
#   'par_call_date': datetime.date(2030, 11, 1),
#   'refund_date': None,
#   'transaction_type': 'I',
#   'sequence_number': 4456.0},
#  {'msrb_valid_from_date': Timestamp('2023-08-09 09:46:18'),
#   'msrb_valid_to_date': Timestamp('2100-01-01 00:00:00'),
#   'rtrs_control_number': 2023080900981000,
#   'trade_datetime': Timestamp('2023-08-09 09:45:42'),
#   'publish_datetime': Timestamp('2023-08-09 09:46:18'),
#   'yield': 4.2,
#   'dollar_price': 97.163,
#   'par_traded': Decimal('25000.000000000'),
#   'trade_type': 'D',
#   'is_non_transaction_based_compensation': False,
#   'is_lop_or_takedown': False,
#   'brokers_broker': None,
#   'is_alternative_trading_system': True,
#   'is_weighted_average_price': False,
#   'settlement_date': datetime.date(2023, 8, 11),
#   'calc_date': datetime.date(2045, 5, 1),
#   'calc_day_cat': 2,
#   'maturity_date': datetime.date(2045, 5, 1),
#   'next_call_date': datetime.date(2030, 11, 1),
#   'par_call_date': datetime.date(2030, 11, 1),
#   'refund_date': None,
#   'transaction_type': 'I',
#   'sequence_number': 4472.0},
#  {'msrb_valid_from_date': Timestamp('2023-08-09 09:46:18'),
#   'msrb_valid_to_date': Timestamp('2100-01-01 00:00:00'),
#   'rtrs_control_number': 2023080900983500,
#   'trade_datetime': Timestamp('2023-08-09 09:45:42'),
#   'publish_datetime': Timestamp('2023-08-09 09:46:18'),
#   'yield': 4.167,
#   'dollar_price': 97.628,
#   'par_traded': Decimal('25000.000000000'),
#   'trade_type': 'S',
#   'is_non_transaction_based_compensation': False,
#   'is_lop_or_takedown': False,
#   'brokers_broker': None,
#   'is_alternative_trading_system': False,
#   'is_weighted_average_price': False,
#   'settlement_date': datetime.date(2023, 8, 11),
#   'calc_date': datetime.date(2045, 5, 1),
#   'calc_day_cat': 2,
#   'maturity_date': datetime.date(2045, 5, 1),
#   'next_call_date': datetime.date(2030, 11, 1),
#   'par_call_date': datetime.date(2030, 11, 1),
#   'refund_date': None,
#   'transaction_type': 'I',
#   'sequence_number': 4466.0},
#  {'msrb_valid_from_date': Timestamp('2023-08-09 09:46:18'),
#   'msrb_valid_to_date': Timestamp('2100-01-01 00:00:00'),
#   'rtrs_control_number': 2023080900983200,
#   'trade_datetime': Timestamp('2023-08-09 09:45:42'),
#   'publish_datetime': Timestamp('2023-08-09 09:46:18'),
#   'yield': 4.195,
#   'dollar_price': 97.228,
#   'par_traded': Decimal('25000.000000000'),
#   'trade_type': 'D',
#   'is_non_transaction_based_compensation': False,
#   'is_lop_or_takedown': False,
#   'brokers_broker': None,
#   'is_alternative_trading_system': False,
#   'is_weighted_average_price': False,
#   'settlement_date': datetime.date(2023, 8, 11),
#   'calc_date': datetime.date(2045, 5, 1),
#   'calc_day_cat': 2,
#   'maturity_date': datetime.date(2045, 5, 1),
#   'next_call_date': datetime.date(2030, 11, 1),
#   'par_call_date': datetime.date(2030, 11, 1),
#   'refund_date': None,
#   'transaction_type': 'I',
#   'sequence_number': 4468.0},
#  {'msrb_valid_from_date': Timestamp('2023-08-09 09:44:21'),
#   'msrb_valid_to_date': Timestamp('2100-01-01 00:00:00'),
#   'rtrs_control_number': 2023080900949700,
#   'trade_datetime': Timestamp('2023-08-09 09:44:01'),
#   'publish_datetime': Timestamp('2023-08-09 09:44:21'),
#   'yield': 4.277,
#   'dollar_price': 96.102,
#   'par_traded': Decimal('50000.000000000'),
#   'trade_type': 'P',
#   'is_non_transaction_based_compensation': False,
#   'is_lop_or_takedown': False,
#   'brokers_broker': None,
#   'is_alternative_trading_system': False,
#   'is_weighted_average_price': False,
#   'settlement_date': datetime.date(2023, 8, 10),
#   'calc_date': datetime.date(2045, 5, 1),
#   'calc_day_cat': 2,
#   'maturity_date': datetime.date(2045, 5, 1),
#   'next_call_date': datetime.date(2030, 11, 1),
#   'par_call_date': datetime.date(2030, 11, 1),
#   'refund_date': None,
#   'transaction_type': 'I',
#   'sequence_number': 4329.0},
#  {'msrb_valid_from_date': Timestamp('2023-08-07 11:03:28'),
#   'msrb_valid_to_date': Timestamp('2100-01-01 00:00:00'),
#   'rtrs_control_number': 2023080702642400,
#   'trade_datetime': Timestamp('2023-08-07 11:00:20'),
#   'publish_datetime': Timestamp('2023-08-07 11:03:28'),
#   'yield': 4.11,
#   'dollar_price': 98.424,
#   'par_traded': Decimal('25000.000000000'),
#   'trade_type': 'S',
#   'is_non_transaction_based_compensation': False,
#   'is_lop_or_takedown': False,
#   'brokers_broker': None,
#   'is_alternative_trading_system': False,
#   'is_weighted_average_price': False,
#   'settlement_date': datetime.date(2023, 8, 9),
#   'calc_date': datetime.date(2045, 5, 1),
#   'calc_day_cat': 2,
#   'maturity_date': datetime.date(2045, 5, 1),
#   'next_call_date': datetime.date(2030, 11, 1),
#   'par_call_date': datetime.date(2030, 11, 1),
#   'refund_date': None,
#   'transaction_type': 'I',
#   'sequence_number': 10433.0},
#  {'msrb_valid_from_date': Timestamp('2023-08-04 10:37:13'),
#   'msrb_valid_to_date': Timestamp('2100-01-01 00:00:00'),
#   'rtrs_control_number': 2023080402337200,
#   'trade_datetime': Timestamp('2023-08-04 10:36:33'),
#   'publish_datetime': Timestamp('2023-08-04 10:37:13'),
#   'yield': 4.299,
#   'dollar_price': 95.797,
#   'par_traded': Decimal('50000.000000000'),
#   'trade_type': 'D',
#   'is_non_transaction_based_compensation': False,
#   'is_lop_or_takedown': False,
#   'brokers_broker': None,
#   'is_alternative_trading_system': True,
#   'is_weighted_average_price': False,
#   'settlement_date': datetime.date(2023, 8, 8),
#   'calc_date': datetime.date(2045, 5, 1),
#   'calc_day_cat': 2,
#   'maturity_date': datetime.date(2045, 5, 1),
#   'next_call_date': datetime.date(2030, 11, 1),
#   'par_call_date': datetime.date(2030, 11, 1),
#   'refund_date': None,
#   'transaction_type': 'I',
#   'sequence_number': 9129.0},
#  {'msrb_valid_from_date': Timestamp('2023-08-04 10:37:13'),
#   'msrb_valid_to_date': Timestamp('2100-01-01 00:00:00'),
#   'rtrs_control_number': 2023080402347400,
#   'trade_datetime': Timestamp('2023-08-04 10:36:32'),
#   'publish_datetime': Timestamp('2023-08-04 10:37:13'),
#   'yield': 4.29,
#   'dollar_price': 95.922,
#   'par_traded': Decimal('50000.000000000'),
#   'trade_type': 'D',
#   'is_non_transaction_based_compensation': False,
#   'is_lop_or_takedown': False,
#   'brokers_broker': None,
#   'is_alternative_trading_system': True,
#   'is_weighted_average_price': False,
#   'settlement_date': datetime.date(2023, 8, 8),
#   'calc_date': datetime.date(2045, 5, 1),
#   'calc_day_cat': 2,
#   'maturity_date': datetime.date(2045, 5, 1),
#   'next_call_date': datetime.date(2030, 11, 1),
#   'par_call_date': datetime.date(2030, 11, 1),
#   'refund_date': None,
#   'transaction_type': 'I',
#   'sequence_number': 9131.0},
#  {'msrb_valid_from_date': Timestamp('2023-08-03 12:36:20'),
#   'msrb_valid_to_date': Timestamp('2100-01-01 00:00:00'),
#   'rtrs_control_number': 2023080306281400,
#   'trade_datetime': Timestamp('2023-08-03 12:36:10'),
#   'publish_datetime': Timestamp('2023-08-03 12:36:20'),
#   'yield': 4.125,
#   'dollar_price': 98.212,
#   'par_traded': Decimal('385000.000000000'),
#   'trade_type': 'S',
#   'is_non_transaction_based_compensation': False,
#   'is_lop_or_takedown': False,
#   'brokers_broker': None,
#   'is_alternative_trading_system': False,
#   'is_weighted_average_price': False,
#   'settlement_date': datetime.date(2023, 8, 7),
#   'calc_date': datetime.date(2045, 5, 1),
#   'calc_day_cat': 2,
#   'maturity_date': datetime.date(2045, 5, 1),
#   'next_call_date': datetime.date(2030, 11, 1),
#   'par_call_date': datetime.date(2030, 11, 1),
#   'refund_date': None,
#   'transaction_type': 'I',
#   'sequence_number': 25801.0},
#  {'msrb_valid_from_date': Timestamp('2023-08-03 12:36:21'),
#   'msrb_valid_to_date': Timestamp('2100-01-01 00:00:00'),
#   'rtrs_control_number': 2023080306268900,
#   'trade_datetime': Timestamp('2023-08-03 12:35:21'),
#   'publish_datetime': Timestamp('2023-08-03 12:36:21'),
#   'yield': 4.2,
#   'dollar_price': 97.162,
#   'par_traded': Decimal('385000.000000000'),
#   'trade_type': 'D',
#   'is_non_transaction_based_compensation': False,
#   'is_lop_or_takedown': False,
#   'brokers_broker': 'S',
#   'is_alternative_trading_system': False,
#   'is_weighted_average_price': False,
#   'settlement_date': datetime.date(2023, 8, 7),
#   'calc_date': datetime.date(2045, 5, 1),
#   'calc_day_cat': 2,
#   'maturity_date': datetime.date(2045, 5, 1),
#   'next_call_date': datetime.date(2030, 11, 1),
#   'par_call_date': datetime.date(2030, 11, 1),
#   'refund_date': None,
#   'transaction_type': 'I',
#   'sequence_number': 25817.0},
#  {'msrb_valid_from_date': Timestamp('2023-08-03 12:28:34'),
#   'msrb_valid_to_date': Timestamp('2100-01-01 00:00:00'),
#   'rtrs_control_number': 2023080305980700,
#   'trade_datetime': Timestamp('2023-08-03 12:27:35'),
#   'publish_datetime': Timestamp('2023-08-03 12:28:34'),
#   'yield': 4.204,
#   'dollar_price': 97.102,
#   'par_traded': Decimal('385000.000000000'),
#   'trade_type': 'D',
#   'is_non_transaction_based_compensation': False,
#   'is_lop_or_takedown': False,
#   'brokers_broker': 'P',
#   'is_alternative_trading_system': False,
#   'is_weighted_average_price': False,
#   'settlement_date': datetime.date(2023, 8, 7),
#   'calc_date': datetime.date(2045, 5, 1),
#   'calc_day_cat': 2,
#   'maturity_date': datetime.date(2045, 5, 1),
#   'next_call_date': datetime.date(2030, 11, 1),
#   'par_call_date': datetime.date(2030, 11, 1),
#   'refund_date': None,
#   'transaction_type': 'I',
#   'sequence_number': 24610.0},
#  {'msrb_valid_from_date': Timestamp('2023-08-03 11:02:30'),
#   'msrb_valid_to_date': Timestamp('2100-01-01 00:00:00'),
#   'rtrs_control_number': 2023080303185000,
#   'trade_datetime': Timestamp('2023-08-03 11:02:15'),
#   'publish_datetime': Timestamp('2023-08-03 11:02:30'),
#   'yield': 4.19,
#   'dollar_price': 97.301,
#   'par_traded': Decimal('50000.000000000'),
#   'trade_type': 'D',
#   'is_non_transaction_based_compensation': False,
#   'is_lop_or_takedown': False,
#   'brokers_broker': None,
#   'is_alternative_trading_system': False,
#   'is_weighted_average_price': False,
#   'settlement_date': datetime.date(2023, 8, 7),
#   'calc_date': datetime.date(2045, 5, 1),
#   'calc_day_cat': 2,
#   'maturity_date': datetime.date(2045, 5, 1),
#   'next_call_date': datetime.date(2030, 11, 1),
#   'par_call_date': datetime.date(2030, 11, 1),
#   'refund_date': None,
#   'transaction_type': 'I',
#   'sequence_number': 12470.0},
#  {'msrb_valid_from_date': Timestamp('2023-08-03 11:02:30'),
#   'msrb_valid_to_date': Timestamp('2100-01-01 00:00:00'),
#   'rtrs_control_number': 2023080303184900,
#   'trade_datetime': Timestamp('2023-08-03 11:02:15'),
#   'publish_datetime': Timestamp('2023-08-03 11:02:30'),
#   'yield': 4.048,
#   'dollar_price': 99.301,
#   'par_traded': Decimal('50000.000000000'),
#   'trade_type': 'S',
#   'is_non_transaction_based_compensation': False,
#   'is_lop_or_takedown': False,
#   'brokers_broker': None,
#   'is_alternative_trading_system': False,
#   'is_weighted_average_price': False,
#   'settlement_date': datetime.date(2023, 8, 7),
#   'calc_date': datetime.date(2045, 5, 1),
#   'calc_day_cat': 2,
#   'maturity_date': datetime.date(2045, 5, 1),
#   'next_call_date': datetime.date(2030, 11, 1),
#   'par_call_date': datetime.date(2030, 11, 1),
#   'refund_date': None,
#   'transaction_type': 'I',
#   'sequence_number': 12469.0},
#  {'msrb_valid_from_date': Timestamp('2023-08-03 10:42:04'),
#   'msrb_valid_to_date': Timestamp('2100-01-01 00:00:00'),
#   'rtrs_control_number': 2023080302608600,
#   'trade_datetime': Timestamp('2023-08-03 10:40:58'),
#   'publish_datetime': Timestamp('2023-08-03 10:42:04'),
#   'yield': 4.187,
#   'dollar_price': 97.338,
#   'par_traded': Decimal('30000.000000000'),
#   'trade_type': 'D',
#   'is_non_transaction_based_compensation': False,
#   'is_lop_or_takedown': False,
#   'brokers_broker': None,
#   'is_alternative_trading_system': True,
#   'is_weighted_average_price': False,
#   'settlement_date': datetime.date(2023, 8, 7),
#   'calc_date': datetime.date(2045, 5, 1),
#   'calc_day_cat': 2,
#   'maturity_date': datetime.date(2045, 5, 1),
#   'next_call_date': datetime.date(2030, 11, 1),
#   'par_call_date': datetime.date(2030, 11, 1),
#   'refund_date': None,
#   'transaction_type': 'I',
#   'sequence_number': 10043.0},
#  {'msrb_valid_from_date': Timestamp('2023-08-03 10:41:14'),
#   'msrb_valid_to_date': Timestamp('2100-01-01 00:00:00'),
#   'rtrs_control_number': 2023080302589600,
#   'trade_datetime': Timestamp('2023-08-03 10:40:57'),
#   'publish_datetime': Timestamp('2023-08-03 10:41:14'),
#   'yield': 4.046,
#   'dollar_price': 99.338,
#   'par_traded': Decimal('30000.000000000'),
#   'trade_type': 'S',
#   'is_non_transaction_based_compensation': False,
#   'is_lop_or_takedown': False,
#   'brokers_broker': None,
#   'is_alternative_trading_system': False,
#   'is_weighted_average_price': False,
#   'settlement_date': datetime.date(2023, 8, 7),
#   'calc_date': datetime.date(2045, 5, 1),
#   'calc_day_cat': 2,
#   'maturity_date': datetime.date(2045, 5, 1),
#   'next_call_date': datetime.date(2030, 11, 1),
#   'par_call_date': datetime.date(2030, 11, 1),
#   'refund_date': None,
#   'transaction_type': 'I',
#   'sequence_number': 9966.0},
#  {'msrb_valid_from_date': Timestamp('2023-08-03 10:08:16'),
#   'msrb_valid_to_date': Timestamp('2100-01-01 00:00:00'),
#   'rtrs_control_number': 2023080301767700,
#   'trade_datetime': Timestamp('2023-08-03 10:07:05'),
#   'publish_datetime': Timestamp('2023-08-03 10:08:16'),
#   'yield': 4.211,
#   'dollar_price': 97.006,
#   'par_traded': Decimal('75000.000000000'),
#   'trade_type': 'D',
#   'is_non_transaction_based_compensation': False,
#   'is_lop_or_takedown': False,
#   'brokers_broker': None,
#   'is_alternative_trading_system': True,
#   'is_weighted_average_price': False,
#   'settlement_date': datetime.date(2023, 8, 7),
#   'calc_date': datetime.date(2045, 5, 1),
#   'calc_day_cat': 2,
#   'maturity_date': datetime.date(2045, 5, 1),
#   'next_call_date': datetime.date(2030, 11, 1),
#   'par_call_date': datetime.date(2030, 11, 1),
#   'refund_date': None,
#   'transaction_type': 'I',
#   'sequence_number': 6701.0},
#  {'msrb_valid_from_date': Timestamp('2023-08-03 10:07:15'),
#   'msrb_valid_to_date': Timestamp('2100-01-01 00:00:00'),
#   'rtrs_control_number': 2023080301742500,
#   'trade_datetime': Timestamp('2023-08-03 10:07:04'),
#   'publish_datetime': Timestamp('2023-08-03 10:07:15'),
#   'yield': 4.069,
#   'dollar_price': 99.006,
#   'par_traded': Decimal('75000.000000000'),
#   'trade_type': 'S',
#   'is_non_transaction_based_compensation': False,
#   'is_lop_or_takedown': False,
#   'brokers_broker': None,
#   'is_alternative_trading_system': False,
#   'is_weighted_average_price': False,
#   'settlement_date': datetime.date(2023, 8, 7),
#   'calc_date': datetime.date(2045, 5, 1),
#   'calc_day_cat': 2,
#   'maturity_date': datetime.date(2045, 5, 1),
#   'next_call_date': datetime.date(2030, 11, 1),
#   'par_call_date': datetime.date(2030, 11, 1),
#   'refund_date': None,
#   'transaction_type': 'I',
#   'sequence_number': 6606.0},
#  {'msrb_valid_from_date': Timestamp('2023-08-02 15:09:42'),
#   'msrb_valid_to_date': Timestamp('2100-01-01 00:00:00'),
#   'rtrs_control_number': 2023080210936300,
#   'trade_datetime': Timestamp('2023-08-02 15:07:23'),
#   'publish_datetime': Timestamp('2023-08-02 15:09:42'),
#   'yield': 4.192,
#   'dollar_price': 97.276,
#   'par_traded': Decimal('15000.000000000'),
#   'trade_type': 'D',
#   'is_non_transaction_based_compensation': False,
#   'is_lop_or_takedown': False,
#   'brokers_broker': None,
#   'is_alternative_trading_system': True,
#   'is_weighted_average_price': False,
#   'settlement_date': datetime.date(2023, 8, 4),
#   'calc_date': datetime.date(2045, 5, 1),
#   'calc_day_cat': 2,
#   'maturity_date': datetime.date(2045, 5, 1),
#   'next_call_date': datetime.date(2030, 11, 1),
#   'par_call_date': datetime.date(2030, 11, 1),
#   'refund_date': None,
#   'transaction_type': 'I',
#   'sequence_number': 47040.0},
#  {'msrb_valid_from_date': Timestamp('2023-08-02 15:07:31'),
#   'msrb_valid_to_date': Timestamp('2100-01-01 00:00:00'),
#   'rtrs_control_number': 2023080210864700,
#   'trade_datetime': Timestamp('2023-08-02 15:07:22'),
#   'publish_datetime': Timestamp('2023-08-02 15:07:31'),
#   'yield': 4.05,
#   'dollar_price': 99.276,
#   'par_traded': Decimal('15000.000000000'),
#   'trade_type': 'S',
#   'is_non_transaction_based_compensation': False,
#   'is_lop_or_takedown': False,
#   'brokers_broker': None,
#   'is_alternative_trading_system': False,
#   'is_weighted_average_price': False,
#   'settlement_date': datetime.date(2023, 8, 4),
#   'calc_date': datetime.date(2045, 5, 1),
#   'calc_day_cat': 2,
#   'maturity_date': datetime.date(2045, 5, 1),
#   'next_call_date': datetime.date(2030, 11, 1),
#   'par_call_date': datetime.date(2030, 11, 1),
#   'refund_date': None,
#   'transaction_type': 'I',
#   'sequence_number': 46746.0}]

# %%
reference_data_redis_host = os.environ.get('REDISHOST', '10.2.196.133')
reference_data_redis_port = int(os.environ.get('REDISPORT', 6379))
reference_data_redis_client = redis.Redis(host=reference_data_redis_host, port=reference_data_redis_port, db=0)

# %%
reference_data = reference_data_redis_client.get(cusip_of_interest)[0]    # index 0 indicates the most recent snapshot of the reference data
reference_data = pd.DataFrame(pickle.loads(reference_data))

# %%
reference_data
# Out:
#                                                                              809
# coupon                                                                       4.0
# cusip                                                                  64971XQM3
# ref_valid_from_date                                    2023-08-24 20:00:04+00:00
# ref_valid_to_date                                      2100-01-01 00:00:00+00:00
# incorporated_state_code                                                       NY
# ...                                                                          ...
# use_of_proceeds                                                               20
# use_of_proceeds_supplementary                                               None
# series_id                                                                1168588
# security_description           NEW YORK N Y CITY TRANSITIONAL FIN AUTH REV FU...
# recent                         [{'msrb_valid_from_date': 2023-09-07 12:38:52,...
#
# [159 rows x 1 columns]

# %%
reference_data.loc['recent'].values
# Out:
# array([array([{'msrb_valid_from_date': datetime.datetime(2023, 9, 7, 12, 38, 52), 'msrb_valid_to_date': datetime.datetime(2100, 1, 1, 0, 0), 'rtrs_control_number': 2023090705654800, 'trade_datetime': datetime.datetime(2023, 9, 7, 12, 38, 39), 'publish_datetime': datetime.datetime(2023, 9, 7, 12, 38, 52), 'yield': 4.351, 'dollar_price': 95.11, 'par_traded': Decimal('50000.000000000'), 'trade_type': 'P', 'is_non_transaction_based_compensation': False, 'is_lop_or_takedown': False, 'brokers_broker': None, 'is_alternative_trading_system': False, 'is_weighted_average_price': False, 'settlement_date': datetime.date(2023, 9, 11), 'calc_date': datetime.date(2045, 5, 1), 'calc_day_cat': 2, 'maturity_date': datetime.date(2045, 5, 1), 'next_call_date': datetime.date(2030, 11, 1), 'par_call_date': datetime.date(2030, 11, 1), 'refund_date': None, 'sequence_number': 25381, 'transaction_type': 'I'},
#        {'msrb_valid_from_date': datetime.datetime(2023, 8, 28, 15, 47, 35), 'msrb_valid_to_date': datetime.datetime(2100, 1, 1, 0, 0), 'rtrs_control_number': 2023082809802500, 'trade_datetime': datetime.datetime(2023, 8, 28, 15, 47, 25), 'publish_datetime': datetime.datetime(2023, 8, 28, 15, 47, 35), 'yield': 4.297, 'dollar_price': 95.83, 'par_traded': Decimal('15000.000000000'), 'trade_type': 'D', 'is_non_transaction_based_compensation': False, 'is_lop_or_takedown': False, 'brokers_broker': None, 'is_alternative_trading_system': True, 'is_weighted_average_price': False, 'settlement_date': datetime.date(2023, 8, 30), 'calc_date': datetime.date(2045, 5, 1), 'calc_day_cat': 2, 'maturity_date': datetime.date(2045, 5, 1), 'next_call_date': datetime.date(2030, 11, 1), 'par_call_date': datetime.date(2030, 11, 1), 'refund_date': None, 'sequence_number': 43754, 'transaction_type': 'I'},
#        {'msrb_valid_from_date': datetime.datetime(2023, 8, 28, 15, 47, 35), 'msrb_valid_to_date': datetime.datetime(2100, 1, 1, 0, 0), 'rtrs_control_number': 2023082809802000, 'trade_datetime': datetime.datetime(2023, 8, 28, 15, 47, 25), 'publish_datetime': datetime.datetime(2023, 8, 28, 15, 47, 35), 'yield': 4.153, 'dollar_price': 97.83, 'par_traded': Decimal('15000.000000000'), 'trade_type': 'S', 'is_non_transaction_based_compensation': False, 'is_lop_or_takedown': False, 'brokers_broker': None, 'is_alternative_trading_system': False, 'is_weighted_average_price': False, 'settlement_date': datetime.date(2023, 8, 30), 'calc_date': datetime.date(2045, 5, 1), 'calc_day_cat': 2, 'maturity_date': datetime.date(2045, 5, 1), 'next_call_date': datetime.date(2030, 11, 1), 'par_call_date': datetime.date(2030, 11, 1), 'refund_date': None, 'sequence_number': 43750, 'transaction_type': 'I'},
#        {'msrb_valid_from_date': datetime.datetime(2023, 8, 28, 12, 33, 10), 'msrb_valid_to_date': datetime.datetime(2100, 1, 1, 0, 0), 'rtrs_control_number': 2023082804845500, 'trade_datetime': datetime.datetime(2023, 8, 28, 12, 32, 57), 'publish_datetime': datetime.datetime(2023, 8, 28, 12, 33, 10), 'yield': 4.454, 'dollar_price': 93.73, 'par_traded': Decimal('15000.000000000'), 'trade_type': 'P', 'is_non_transaction_based_compensation': True, 'is_lop_or_takedown': False, 'brokers_broker': None, 'is_alternative_trading_system': False, 'is_weighted_average_price': False, 'settlement_date': datetime.date(2023, 8, 30), 'calc_date': datetime.date(2045, 5, 1), 'calc_day_cat': 2, 'maturity_date': datetime.date(2045, 5, 1), 'next_call_date': datetime.date(2030, 11, 1), 'par_call_date': datetime.date(2030, 11, 1), 'refund_date': None, 'sequence_number': 21818, 'transaction_type': 'I'},
#        {'msrb_valid_from_date': datetime.datetime(2023, 8, 28, 12, 33, 10), 'msrb_valid_to_date': datetime.datetime(2100, 1, 1, 0, 0), 'rtrs_control_number': 2023082804845600, 'trade_datetime': datetime.datetime(2023, 8, 28, 12, 32, 57), 'publish_datetime': datetime.datetime(2023, 8, 28, 12, 33, 10), 'yield': 4.454, 'dollar_price': 93.73, 'par_traded': Decimal('15000.000000000'), 'trade_type': 'D', 'is_non_transaction_based_compensation': False, 'is_lop_or_takedown': False, 'brokers_broker': None, 'is_alternative_trading_system': False, 'is_weighted_average_price': False, 'settlement_date': datetime.date(2023, 8, 30), 'calc_date': datetime.date(2045, 5, 1), 'calc_day_cat': 2, 'maturity_date': datetime.date(2045, 5, 1), 'next_call_date': datetime.date(2030, 11, 1), 'par_call_date': datetime.date(2030, 11, 1), 'refund_date': None, 'sequence_number': 21819, 'transaction_type': 'I'},
#        {'msrb_valid_from_date': datetime.datetime(2023, 8, 25, 10, 51, 40), 'msrb_valid_to_date': datetime.datetime(2100, 1, 1, 0, 0), 'rtrs_control_number': 2023082502332300, 'trade_datetime': datetime.datetime(2023, 8, 25, 10, 51, 28), 'publish_datetime': datetime.datetime(2023, 8, 25, 10, 51, 40), 'yield': 4.155, 'dollar_price': 97.793, 'par_traded': Decimal('25000.000000000'), 'trade_type': 'S', 'is_non_transaction_based_compensation': False, 'is_lop_or_takedown': False, 'brokers_broker': None, 'is_alternative_trading_system': False, 'is_weighted_average_price': False, 'settlement_date': datetime.date(2023, 8, 29), 'calc_date': datetime.date(2045, 5, 1), 'calc_day_cat': 2, 'maturity_date': datetime.date(2045, 5, 1), 'next_call_date': datetime.date(2030, 11, 1), 'par_call_date': datetime.date(2030, 11, 1), 'refund_date': None, 'sequence_number': 9504, 'transaction_type': 'I'},
#        {'msrb_valid_from_date': datetime.datetime(2023, 8, 22, 15, 57, 8), 'msrb_valid_to_date': datetime.datetime(2100, 1, 1, 0, 0), 'rtrs_control_number': 2023082211667900, 'trade_datetime': datetime.datetime(2023, 8, 22, 15, 56, 55), 'publish_datetime': datetime.datetime(2023, 8, 22, 15, 57, 8), 'yield': 4.155, 'dollar_price': 97.793, 'par_traded': Decimal('15000.000000000'), 'trade_type': 'S', 'is_non_transaction_based_compensation': False, 'is_lop_or_takedown': False, 'brokers_broker': None, 'is_alternative_trading_system': False, 'is_weighted_average_price': False, 'settlement_date': datetime.date(2023, 8, 24), 'calc_date': datetime.date(2045, 5, 1), 'calc_day_cat': 2, 'maturity_date': datetime.date(2045, 5, 1), 'next_call_date': datetime.date(2030, 11, 1), 'par_call_date': datetime.date(2030, 11, 1), 'refund_date': None, 'sequence_number': 51438, 'transaction_type': 'I'},
#        {'msrb_valid_from_date': datetime.datetime(2023, 8, 22, 15, 52, 58), 'msrb_valid_to_date': datetime.datetime(2100, 1, 1, 0, 0), 'rtrs_control_number': 2023082211581700, 'trade_datetime': datetime.datetime(2023, 8, 22, 15, 52, 44), 'publish_datetime': datetime.datetime(2023, 8, 22, 15, 52, 58), 'yield': 4.155, 'dollar_price': 97.793, 'par_traded': Decimal('30000.000000000'), 'trade_type': 'S', 'is_non_transaction_based_compensation': False, 'is_lop_or_takedown': False, 'brokers_broker': None, 'is_alternative_trading_system': False, 'is_weighted_average_price': False, 'settlement_date': datetime.date(2023, 8, 24), 'calc_date': datetime.date(2045, 5, 1), 'calc_day_cat': 2, 'maturity_date': datetime.date(2045, 5, 1), 'next_call_date': datetime.date(2030, 11, 1), 'par_call_date': datetime.date(2030, 11, 1), 'refund_date': None, 'sequence_number': 51085, 'transaction_type': 'I'},
#        {'msrb_valid_from_date': datetime.datetime(2023, 8, 21, 12, 16, 39), 'msrb_valid_to_date': datetime.datetime(2100, 1, 1, 0, 0), 'rtrs_control_number': 2023082104730000, 'trade_datetime': datetime.datetime(2023, 8, 21, 12, 15, 26), 'publish_datetime': datetime.datetime(2023, 8, 21, 12, 16, 39), 'yield': 4.306, 'dollar_price': 95.708, 'par_traded': Decimal('70000.000000000'), 'trade_type': 'D', 'is_non_transaction_based_compensation': False, 'is_lop_or_takedown': False, 'brokers_broker': None, 'is_alternative_trading_system': True, 'is_weighted_average_price': False, 'settlement_date': datetime.date(2023, 8, 23), 'calc_date': datetime.date(2045, 5, 1), 'calc_day_cat': 2, 'maturity_date': datetime.date(2045, 5, 1), 'next_call_date': datetime.date(2030, 11, 1), 'par_call_date': datetime.date(2030, 11, 1), 'refund_date': None, 'sequence_number': 20579, 'transaction_type': 'I'},
#        {'msrb_valid_from_date': datetime.datetime(2023, 8, 21, 12, 16, 20), 'msrb_valid_to_date': datetime.datetime(2100, 1, 1, 0, 0), 'rtrs_control_number': 2023082104717500, 'trade_datetime': datetime.datetime(2023, 8, 21, 12, 15, 21), 'publish_datetime': datetime.datetime(2023, 8, 21, 12, 16, 20), 'yield': 4.3, 'dollar_price': 95.793, 'par_traded': Decimal('70000.000000000'), 'trade_type': 'D', 'is_non_transaction_based_compensation': False, 'is_lop_or_takedown': False, 'brokers_broker': None, 'is_alternative_trading_system': True, 'is_weighted_average_price': False, 'settlement_date': datetime.date(2023, 8, 23), 'calc_date': datetime.date(2045, 5, 1), 'calc_day_cat': 2, 'maturity_date': datetime.date(2045, 5, 1), 'next_call_date': datetime.date(2030, 11, 1), 'par_call_date': datetime.date(2030, 11, 1), 'refund_date': None, 'sequence_number': 20520, 'transaction_type': 'I'},
#        {'msrb_valid_from_date': datetime.datetime(2023, 8, 9, 13, 1, 22), 'msrb_valid_to_date': datetime.datetime(2100, 1, 1, 0, 0), 'rtrs_control_number': 2023080906192100, 'trade_datetime': datetime.datetime(2023, 8, 9, 12, 58, 24), 'publish_datetime': datetime.datetime(2023, 8, 9, 13, 1, 22), 'yield': 4.195, 'dollar_price': 97.233, 'par_traded': Decimal('15000.000000000'), 'trade_type': 'D', 'is_non_transaction_based_compensation': False, 'is_lop_or_takedown': False, 'brokers_broker': None, 'is_alternative_trading_system': False, 'is_weighted_average_price': False, 'settlement_date': datetime.date(2023, 8, 11), 'calc_date': datetime.date(2045, 5, 1), 'calc_day_cat': 2, 'maturity_date': datetime.date(2045, 5, 1), 'next_call_date': datetime.date(2030, 11, 1), 'par_call_date': datetime.date(2030, 11, 1), 'refund_date': None, 'sequence_number': 28819, 'transaction_type': 'I'},
#        {'msrb_valid_from_date': datetime.datetime(2023, 8, 9, 12, 58, 35), 'msrb_valid_to_date': datetime.datetime(2100, 1, 1, 0, 0), 'rtrs_control_number': 2023080906191900, 'trade_datetime': datetime.datetime(2023, 8, 9, 12, 58, 24), 'publish_datetime': datetime.datetime(2023, 8, 9, 12, 58, 35), 'yield': 4.195, 'dollar_price': 97.233, 'par_traded': Decimal('15000.000000000'), 'trade_type': 'P', 'is_non_transaction_based_compensation': True, 'is_lop_or_takedown': False, 'brokers_broker': None, 'is_alternative_trading_system': False, 'is_weighted_average_price': False, 'settlement_date': datetime.date(2023, 8, 11), 'calc_date': datetime.date(2045, 5, 1), 'calc_day_cat': 2, 'maturity_date': datetime.date(2045, 5, 1), 'next_call_date': datetime.date(2030, 11, 1), 'par_call_date': datetime.date(2030, 11, 1), 'refund_date': None, 'sequence_number': 28395, 'transaction_type': 'I'},
#        {'msrb_valid_from_date': datetime.datetime(2023, 8, 9, 10, 28, 34), 'msrb_valid_to_date': datetime.datetime(2100, 1, 1, 0, 0), 'rtrs_control_number': 2023080901748300, 'trade_datetime': datetime.datetime(2023, 8, 9, 10, 28, 28), 'publish_datetime': datetime.datetime(2023, 8, 9, 10, 28, 34), 'yield': 4.125, 'dollar_price': 98.209, 'par_traded': Decimal('50000.000000000'), 'trade_type': 'S', 'is_non_transaction_based_compensation': False, 'is_lop_or_takedown': False, 'brokers_broker': None, 'is_alternative_trading_system': False, 'is_weighted_average_price': False, 'settlement_date': datetime.date(2023, 8, 11), 'calc_date': datetime.date(2045, 5, 1), 'calc_day_cat': 2, 'maturity_date': datetime.date(2045, 5, 1), 'next_call_date': datetime.date(2030, 11, 1), 'par_call_date': datetime.date(2030, 11, 1), 'refund_date': None, 'sequence_number': 7620, 'transaction_type': 'I'},
#        {'msrb_valid_from_date': datetime.datetime(2023, 8, 9, 9, 46, 18), 'msrb_valid_to_date': datetime.datetime(2100, 1, 1, 0, 0), 'rtrs_control_number': 2023080900976600, 'trade_datetime': datetime.datetime(2023, 8, 9, 9, 45, 42), 'publish_datetime': datetime.datetime(2023, 8, 9, 9, 46, 18), 'yield': 4.218, 'dollar_price': 96.913, 'par_traded': Decimal('25000.000000000'), 'trade_type': 'D', 'is_non_transaction_based_compensation': False, 'is_lop_or_takedown': False, 'brokers_broker': None, 'is_alternative_trading_system': True, 'is_weighted_average_price': False, 'settlement_date': datetime.date(2023, 8, 11), 'calc_date': datetime.date(2045, 5, 1), 'calc_day_cat': 2, 'maturity_date': datetime.date(2045, 5, 1), 'next_call_date': datetime.date(2030, 11, 1), 'par_call_date': datetime.date(2030, 11, 1), 'refund_date': None, 'sequence_number': 4456, 'transaction_type': 'I'},
#        {'msrb_valid_from_date': datetime.datetime(2023, 8, 9, 9, 46, 18), 'msrb_valid_to_date': datetime.datetime(2100, 1, 1, 0, 0), 'rtrs_control_number': 2023080900983500, 'trade_datetime': datetime.datetime(2023, 8, 9, 9, 45, 42), 'publish_datetime': datetime.datetime(2023, 8, 9, 9, 46, 18), 'yield': 4.167, 'dollar_price': 97.628, 'par_traded': Decimal('25000.000000000'), 'trade_type': 'S', 'is_non_transaction_based_compensation': False, 'is_lop_or_takedown': False, 'brokers_broker': None, 'is_alternative_trading_system': False, 'is_weighted_average_price': False, 'settlement_date': datetime.date(2023, 8, 11), 'calc_date': datetime.date(2045, 5, 1), 'calc_day_cat': 2, 'maturity_date': datetime.date(2045, 5, 1), 'next_call_date': datetime.date(2030, 11, 1), 'par_call_date': datetime.date(2030, 11, 1), 'refund_date': None, 'sequence_number': 4466, 'transaction_type': 'I'},
#        {'msrb_valid_from_date': datetime.datetime(2023, 8, 9, 9, 46, 18), 'msrb_valid_to_date': datetime.datetime(2100, 1, 1, 0, 0), 'rtrs_control_number': 2023080900983200, 'trade_datetime': datetime.datetime(2023, 8, 9, 9, 45, 42), 'publish_datetime': datetime.datetime(2023, 8, 9, 9, 46, 18), 'yield': 4.195, 'dollar_price': 97.228, 'par_traded': Decimal('25000.000000000'), 'trade_type': 'D', 'is_non_transaction_based_compensation': False, 'is_lop_or_takedown': False, 'brokers_broker': None, 'is_alternative_trading_system': False, 'is_weighted_average_price': False, 'settlement_date': datetime.date(2023, 8, 11), 'calc_date': datetime.date(2045, 5, 1), 'calc_day_cat': 2, 'maturity_date': datetime.date(2045, 5, 1), 'next_call_date': datetime.date(2030, 11, 1), 'par_call_date': datetime.date(2030, 11, 1), 'refund_date': None, 'sequence_number': 4468, 'transaction_type': 'I'},
#        {'msrb_valid_from_date': datetime.datetime(2023, 8, 9, 9, 46, 18), 'msrb_valid_to_date': datetime.datetime(2100, 1, 1, 0, 0), 'rtrs_control_number': 2023080900981000, 'trade_datetime': datetime.datetime(2023, 8, 9, 9, 45, 42), 'publish_datetime': datetime.datetime(2023, 8, 9, 9, 46, 18), 'yield': 4.2, 'dollar_price': 97.163, 'par_traded': Decimal('25000.000000000'), 'trade_type': 'D', 'is_non_transaction_based_compensation': False, 'is_lop_or_takedown': False, 'brokers_broker': None, 'is_alternative_trading_system': True, 'is_weighted_average_price': False, 'settlement_date': datetime.date(2023, 8, 11), 'calc_date': datetime.date(2045, 5, 1), 'calc_day_cat': 2, 'maturity_date': datetime.date(2045, 5, 1), 'next_call_date': datetime.date(2030, 11, 1), 'par_call_date': datetime.date(2030, 11, 1), 'refund_date': None, 'sequence_number': 4472, 'transaction_type': 'I'},
#        {'msrb_valid_from_date': datetime.datetime(2023, 8, 9, 9, 44, 21), 'msrb_valid_to_date': datetime.datetime(2100, 1, 1, 0, 0), 'rtrs_control_number': 2023080900949700, 'trade_datetime': datetime.datetime(2023, 8, 9, 9, 44, 1), 'publish_datetime': datetime.datetime(2023, 8, 9, 9, 44, 21), 'yield': 4.277, 'dollar_price': 96.102, 'par_traded': Decimal('50000.000000000'), 'trade_type': 'P', 'is_non_transaction_based_compensation': False, 'is_lop_or_takedown': False, 'brokers_broker': None, 'is_alternative_trading_system': False, 'is_weighted_average_price': False, 'settlement_date': datetime.date(2023, 8, 10), 'calc_date': datetime.date(2045, 5, 1), 'calc_day_cat': 2, 'maturity_date': datetime.date(2045, 5, 1), 'next_call_date': datetime.date(2030, 11, 1), 'par_call_date': datetime.date(2030, 11, 1), 'refund_date': None, 'sequence_number': 4329, 'transaction_type': 'I'},
#        {'msrb_valid_from_date': datetime.datetime(2023, 8, 7, 11, 3, 28), 'msrb_valid_to_date': datetime.datetime(2100, 1, 1, 0, 0), 'rtrs_control_number': 2023080702642400, 'trade_datetime': datetime.datetime(2023, 8, 7, 11, 0, 20), 'publish_datetime': datetime.datetime(2023, 8, 7, 11, 3, 28), 'yield': 4.11, 'dollar_price': 98.424, 'par_traded': Decimal('25000.000000000'), 'trade_type': 'S', 'is_non_transaction_based_compensation': False, 'is_lop_or_takedown': False, 'brokers_broker': None, 'is_alternative_trading_system': False, 'is_weighted_average_price': False, 'settlement_date': datetime.date(2023, 8, 9), 'calc_date': datetime.date(2045, 5, 1), 'calc_day_cat': 2, 'maturity_date': datetime.date(2045, 5, 1), 'next_call_date': datetime.date(2030, 11, 1), 'par_call_date': datetime.date(2030, 11, 1), 'refund_date': None, 'sequence_number': 10433, 'transaction_type': 'I'},
#        {'msrb_valid_from_date': datetime.datetime(2023, 8, 4, 10, 37, 13), 'msrb_valid_to_date': datetime.datetime(2100, 1, 1, 0, 0), 'rtrs_control_number': 2023080402337200, 'trade_datetime': datetime.datetime(2023, 8, 4, 10, 36, 33), 'publish_datetime': datetime.datetime(2023, 8, 4, 10, 37, 13), 'yield': 4.299, 'dollar_price': 95.797, 'par_traded': Decimal('50000.000000000'), 'trade_type': 'D', 'is_non_transaction_based_compensation': False, 'is_lop_or_takedown': False, 'brokers_broker': None, 'is_alternative_trading_system': True, 'is_weighted_average_price': False, 'settlement_date': datetime.date(2023, 8, 8), 'calc_date': datetime.date(2045, 5, 1), 'calc_day_cat': 2, 'maturity_date': datetime.date(2045, 5, 1), 'next_call_date': datetime.date(2030, 11, 1), 'par_call_date': datetime.date(2030, 11, 1), 'refund_date': None, 'sequence_number': 9129, 'transaction_type': 'I'},
#        {'msrb_valid_from_date': datetime.datetime(2023, 8, 4, 10, 37, 13), 'msrb_valid_to_date': datetime.datetime(2100, 1, 1, 0, 0), 'rtrs_control_number': 2023080402347400, 'trade_datetime': datetime.datetime(2023, 8, 4, 10, 36, 32), 'publish_datetime': datetime.datetime(2023, 8, 4, 10, 37, 13), 'yield': 4.29, 'dollar_price': 95.922, 'par_traded': Decimal('50000.000000000'), 'trade_type': 'D', 'is_non_transaction_based_compensation': False, 'is_lop_or_takedown': False, 'brokers_broker': None, 'is_alternative_trading_system': True, 'is_weighted_average_price': False, 'settlement_date': datetime.date(2023, 8, 8), 'calc_date': datetime.date(2045, 5, 1), 'calc_day_cat': 2, 'maturity_date': datetime.date(2045, 5, 1), 'next_call_date': datetime.date(2030, 11, 1), 'par_call_date': datetime.date(2030, 11, 1), 'refund_date': None, 'sequence_number': 9131, 'transaction_type': 'I'},
#        {'msrb_valid_from_date': datetime.datetime(2023, 8, 3, 12, 36, 20), 'msrb_valid_to_date': datetime.datetime(2100, 1, 1, 0, 0), 'rtrs_control_number': 2023080306281400, 'trade_datetime': datetime.datetime(2023, 8, 3, 12, 36, 10), 'publish_datetime': datetime.datetime(2023, 8, 3, 12, 36, 20), 'yield': 4.125, 'dollar_price': 98.212, 'par_traded': Decimal('385000.000000000'), 'trade_type': 'S', 'is_non_transaction_based_compensation': False, 'is_lop_or_takedown': False, 'brokers_broker': None, 'is_alternative_trading_system': False, 'is_weighted_average_price': False, 'settlement_date': datetime.date(2023, 8, 7), 'calc_date': datetime.date(2045, 5, 1), 'calc_day_cat': 2, 'maturity_date': datetime.date(2045, 5, 1), 'next_call_date': datetime.date(2030, 11, 1), 'par_call_date': datetime.date(2030, 11, 1), 'refund_date': None, 'sequence_number': 25801, 'transaction_type': 'I'},
#        {'msrb_valid_from_date': datetime.datetime(2023, 8, 3, 12, 36, 21), 'msrb_valid_to_date': datetime.datetime(2100, 1, 1, 0, 0), 'rtrs_control_number': 2023080306268900, 'trade_datetime': datetime.datetime(2023, 8, 3, 12, 35, 21), 'publish_datetime': datetime.datetime(2023, 8, 3, 12, 36, 21), 'yield': 4.2, 'dollar_price': 97.162, 'par_traded': Decimal('385000.000000000'), 'trade_type': 'D', 'is_non_transaction_based_compensation': False, 'is_lop_or_takedown': False, 'brokers_broker': 'S', 'is_alternative_trading_system': False, 'is_weighted_average_price': False, 'settlement_date': datetime.date(2023, 8, 7), 'calc_date': datetime.date(2045, 5, 1), 'calc_day_cat': 2, 'maturity_date': datetime.date(2045, 5, 1), 'next_call_date': datetime.date(2030, 11, 1), 'par_call_date': datetime.date(2030, 11, 1), 'refund_date': None, 'sequence_number': 25817, 'transaction_type': 'I'},
#        {'msrb_valid_from_date': datetime.datetime(2023, 8, 3, 12, 28, 34), 'msrb_valid_to_date': datetime.datetime(2100, 1, 1, 0, 0), 'rtrs_control_number': 2023080305980700, 'trade_datetime': datetime.datetime(2023, 8, 3, 12, 27, 35), 'publish_datetime': datetime.datetime(2023, 8, 3, 12, 28, 34), 'yield': 4.204, 'dollar_price': 97.102, 'par_traded': Decimal('385000.000000000'), 'trade_type': 'D', 'is_non_transaction_based_compensation': False, 'is_lop_or_takedown': False, 'brokers_broker': 'P', 'is_alternative_trading_system': False, 'is_weighted_average_price': False, 'settlement_date': datetime.date(2023, 8, 7), 'calc_date': datetime.date(2045, 5, 1), 'calc_day_cat': 2, 'maturity_date': datetime.date(2045, 5, 1), 'next_call_date': datetime.date(2030, 11, 1), 'par_call_date': datetime.date(2030, 11, 1), 'refund_date': None, 'sequence_number': 24610, 'transaction_type': 'I'},
#        {'msrb_valid_from_date': datetime.datetime(2023, 8, 3, 11, 2, 30), 'msrb_valid_to_date': datetime.datetime(2100, 1, 1, 0, 0), 'rtrs_control_number': 2023080303185000, 'trade_datetime': datetime.datetime(2023, 8, 3, 11, 2, 15), 'publish_datetime': datetime.datetime(2023, 8, 3, 11, 2, 30), 'yield': 4.19, 'dollar_price': 97.301, 'par_traded': Decimal('50000.000000000'), 'trade_type': 'D', 'is_non_transaction_based_compensation': False, 'is_lop_or_takedown': False, 'brokers_broker': None, 'is_alternative_trading_system': False, 'is_weighted_average_price': False, 'settlement_date': datetime.date(2023, 8, 7), 'calc_date': datetime.date(2045, 5, 1), 'calc_day_cat': 2, 'maturity_date': datetime.date(2045, 5, 1), 'next_call_date': datetime.date(2030, 11, 1), 'par_call_date': datetime.date(2030, 11, 1), 'refund_date': None, 'sequence_number': 12470, 'transaction_type': 'I'},
#        {'msrb_valid_from_date': datetime.datetime(2023, 8, 3, 11, 2, 30), 'msrb_valid_to_date': datetime.datetime(2100, 1, 1, 0, 0), 'rtrs_control_number': 2023080303184900, 'trade_datetime': datetime.datetime(2023, 8, 3, 11, 2, 15), 'publish_datetime': datetime.datetime(2023, 8, 3, 11, 2, 30), 'yield': 4.048, 'dollar_price': 99.301, 'par_traded': Decimal('50000.000000000'), 'trade_type': 'S', 'is_non_transaction_based_compensation': False, 'is_lop_or_takedown': False, 'brokers_broker': None, 'is_alternative_trading_system': False, 'is_weighted_average_price': False, 'settlement_date': datetime.date(2023, 8, 7), 'calc_date': datetime.date(2045, 5, 1), 'calc_day_cat': 2, 'maturity_date': datetime.date(2045, 5, 1), 'next_call_date': datetime.date(2030, 11, 1), 'par_call_date': datetime.date(2030, 11, 1), 'refund_date': None, 'sequence_number': 12469, 'transaction_type': 'I'},
#        {'msrb_valid_from_date': datetime.datetime(2023, 8, 3, 10, 42, 4), 'msrb_valid_to_date': datetime.datetime(2100, 1, 1, 0, 0), 'rtrs_control_number': 2023080302608600, 'trade_datetime': datetime.datetime(2023, 8, 3, 10, 40, 58), 'publish_datetime': datetime.datetime(2023, 8, 3, 10, 42, 4), 'yield': 4.187, 'dollar_price': 97.338, 'par_traded': Decimal('30000.000000000'), 'trade_type': 'D', 'is_non_transaction_based_compensation': False, 'is_lop_or_takedown': False, 'brokers_broker': None, 'is_alternative_trading_system': True, 'is_weighted_average_price': False, 'settlement_date': datetime.date(2023, 8, 7), 'calc_date': datetime.date(2045, 5, 1), 'calc_day_cat': 2, 'maturity_date': datetime.date(2045, 5, 1), 'next_call_date': datetime.date(2030, 11, 1), 'par_call_date': datetime.date(2030, 11, 1), 'refund_date': None, 'sequence_number': 10043, 'transaction_type': 'I'},
#        {'msrb_valid_from_date': datetime.datetime(2023, 8, 3, 10, 41, 14), 'msrb_valid_to_date': datetime.datetime(2100, 1, 1, 0, 0), 'rtrs_control_number': 2023080302589600, 'trade_datetime': datetime.datetime(2023, 8, 3, 10, 40, 57), 'publish_datetime': datetime.datetime(2023, 8, 3, 10, 41, 14), 'yield': 4.046, 'dollar_price': 99.338, 'par_traded': Decimal('30000.000000000'), 'trade_type': 'S', 'is_non_transaction_based_compensation': False, 'is_lop_or_takedown': False, 'brokers_broker': None, 'is_alternative_trading_system': False, 'is_weighted_average_price': False, 'settlement_date': datetime.date(2023, 8, 7), 'calc_date': datetime.date(2045, 5, 1), 'calc_day_cat': 2, 'maturity_date': datetime.date(2045, 5, 1), 'next_call_date': datetime.date(2030, 11, 1), 'par_call_date': datetime.date(2030, 11, 1), 'refund_date': None, 'sequence_number': 9966, 'transaction_type': 'I'},
#        {'msrb_valid_from_date': datetime.datetime(2023, 8, 3, 10, 8, 16), 'msrb_valid_to_date': datetime.datetime(2100, 1, 1, 0, 0), 'rtrs_control_number': 2023080301767700, 'trade_datetime': datetime.datetime(2023, 8, 3, 10, 7, 5), 'publish_datetime': datetime.datetime(2023, 8, 3, 10, 8, 16), 'yield': 4.211, 'dollar_price': 97.006, 'par_traded': Decimal('75000.000000000'), 'trade_type': 'D', 'is_non_transaction_based_compensation': False, 'is_lop_or_takedown': False, 'brokers_broker': None, 'is_alternative_trading_system': True, 'is_weighted_average_price': False, 'settlement_date': datetime.date(2023, 8, 7), 'calc_date': datetime.date(2045, 5, 1), 'calc_day_cat': 2, 'maturity_date': datetime.date(2045, 5, 1), 'next_call_date': datetime.date(2030, 11, 1), 'par_call_date': datetime.date(2030, 11, 1), 'refund_date': None, 'sequence_number': 6701, 'transaction_type': 'I'},
#        {'msrb_valid_from_date': datetime.datetime(2023, 8, 3, 10, 7, 15), 'msrb_valid_to_date': datetime.datetime(2100, 1, 1, 0, 0), 'rtrs_control_number': 2023080301742500, 'trade_datetime': datetime.datetime(2023, 8, 3, 10, 7, 4), 'publish_datetime': datetime.datetime(2023, 8, 3, 10, 7, 15), 'yield': 4.069, 'dollar_price': 99.006, 'par_traded': Decimal('75000.000000000'), 'trade_type': 'S', 'is_non_transaction_based_compensation': False, 'is_lop_or_takedown': False, 'brokers_broker': None, 'is_alternative_trading_system': False, 'is_weighted_average_price': False, 'settlement_date': datetime.date(2023, 8, 7), 'calc_date': datetime.date(2045, 5, 1), 'calc_day_cat': 2, 'maturity_date': datetime.date(2045, 5, 1), 'next_call_date': datetime.date(2030, 11, 1), 'par_call_date': datetime.date(2030, 11, 1), 'refund_date': None, 'sequence_number': 6606, 'transaction_type': 'I'},
#        {'msrb_valid_from_date': datetime.datetime(2023, 8, 2, 15, 9, 42), 'msrb_valid_to_date': datetime.datetime(2100, 1, 1, 0, 0), 'rtrs_control_number': 2023080210936300, 'trade_datetime': datetime.datetime(2023, 8, 2, 15, 7, 23), 'publish_datetime': datetime.datetime(2023, 8, 2, 15, 9, 42), 'yield': 4.192, 'dollar_price': 97.276, 'par_traded': Decimal('15000.000000000'), 'trade_type': 'D', 'is_non_transaction_based_compensation': False, 'is_lop_or_takedown': False, 'brokers_broker': None, 'is_alternative_trading_system': True, 'is_weighted_average_price': False, 'settlement_date': datetime.date(2023, 8, 4), 'calc_date': datetime.date(2045, 5, 1), 'calc_day_cat': 2, 'maturity_date': datetime.date(2045, 5, 1), 'next_call_date': datetime.date(2030, 11, 1), 'par_call_date': datetime.date(2030, 11, 1), 'refund_date': None, 'sequence_number': 47040, 'transaction_type': 'I'},
#        {'msrb_valid_from_date': datetime.datetime(2023, 8, 2, 15, 7, 31), 'msrb_valid_to_date': datetime.datetime(2100, 1, 1, 0, 0), 'rtrs_control_number': 2023080210864700, 'trade_datetime': datetime.datetime(2023, 8, 2, 15, 7, 22), 'publish_datetime': datetime.datetime(2023, 8, 2, 15, 7, 31), 'yield': 4.05, 'dollar_price': 99.276, 'par_traded': Decimal('15000.000000000'), 'trade_type': 'S', 'is_non_transaction_based_compensation': False, 'is_lop_or_takedown': False, 'brokers_broker': None, 'is_alternative_trading_system': False, 'is_weighted_average_price': False, 'settlement_date': datetime.date(2023, 8, 4), 'calc_date': datetime.date(2045, 5, 1), 'calc_day_cat': 2, 'maturity_date': datetime.date(2045, 5, 1), 'next_call_date': datetime.date(2030, 11, 1), 'par_call_date': datetime.date(2030, 11, 1), 'refund_date': None, 'sequence_number': 46746, 'transaction_type': 'I'}],
#       dtype=object)], dtype=object)

# %% [markdown]
# Determine which CUSIPs have 21 columns in their trade history.

# %%
cusips = trade_history_redis_client.keys()

# %%
def get_cusips_with_21_columns_in_trade_history(cusips):
    cusips_with_21_columns_in_trade_history = []
    for cusip in tqdm(cusips):
        cusip = cusip.decode()
        trade_history_for_cusip = trade_history_redis_client.get(cusip)    # use .decode() to convert bytes object into string
        trade_history_for_cusip = pd.DataFrame(pickle.loads(trade_history_for_cusip))
        num_columns_trade_history_for_cusip = len(trade_history_for_cusip.columns)
        if num_columns_trade_history_for_cusip == 21:
            cusips_with_21_columns_in_trade_history.append(cusip)
        elif num_columns_trade_history_for_cusip != 23:
            print(f'{cusip} has a trade history with {num_columns_trade_history_for_cusip} columns\n{trade_history_for_cusip}')
    return cusips_with_21_columns_in_trade_history

# %%
cusips_with_21_columns_in_trade_history = get_cusips_with_21_columns_in_trade_history(cusips)
# Out:
# 100%|██████████| 1006903/1006903 [38:59<00:00, 430.43it/s]

# %%
cusips_with_21_columns_in_trade_history
# Out:
# ['896560VM8',
#  '84553RBL8',
#  '13068KDX2',
#  '05248NMG2',
#  '13067SHM6',
#  '60534RDX4',
#  '956874DC2',
#  '77355PJ20',
#  '44237LWN2',
#  '417846AA0',
#  '41423BGM4',
#  '04779DAJ1',
#  '462467SY8',
#  '57589TDK8',
#  '97709P5D2',
#  '41423CBF2',
#  '739776FS6',
#  '3434874C5',
#  '82102REZ4',
#  '739776FP2',
#  '821686XP2',
#  '60630ABP3',
#  '54458AEB3',
#  '6400826S7',
#  '46246JLY9',
#  '882724E94',
#  '91473HBF5',
#  '739776FR8',
#  '58401AAV2',
#  '62621EQA9',
#  '46615YGG4',
#  '262741EE7',
#  '739776FN7',
#  '13068CDQ5',
#  '687714HF5',
#  '562062DM8',
#  '087470AX8',
#  '16532LNP7',
#  '68179RVK5',
#  '13068BFU6',
#  '739776FM9',
#  '675498KU2',
#  '662902EE1',
#  '91514SEM4',
#  '641847CT3',
#  '6678257V9',
#  '46615YFB6',
#  '64469RG95',
#  '64711NHH1',
#  '46616TRB3',
#  '27102TLZ7',
#  '44239UKJ2',
#  '283822ST2',
#  '73357AER0',
#  '91513UR87',
#  '91412XQF8',
#  '44239LSY1',
#  '529063TZ2',
#  '44239LQN7',
#  '77160EGQ0',
#  '012440PA5',
#  '98647SDN8',
#  '79626UAB7',
#  '420064DQ7',
#  '91513UY97',
#  '41418YRD9',
#  '692154HH3',
#  '13079UEN8',
#  '54459QD28',
#  '09658BYB1',
#  '739776FQ0',
#  '04778ABM0',
#  '081077J83',
#  '33765VDB0',
#  '610661FX3',
#  '91514CAS0',
#  '54468VCW1',
#  '44243AHJ4',
#  '88213M5X3',
#  '71779XAQ0',
#  '19624BAB7',
#  '048573MJ5',
#  '283668CE9',
#  '649674GS1',
#  '44243AJG8',
#  '44237LUX2',
#  '79741VDN6',
#  '66332PBF0',
#  '98647QNK7',
#  '05248NMT4',
#  '358730DV8',
#  '44241BNG3',
#  '74539XLV2',
#  '739776FU1',
#  '44239UKA1',
#  '739776FT4',
#  '74442PNP6',
#  '98647QNA9',
#  '68179RUF7',
#  '9818482U7',
#  '03444PAC6']

# %%
len(cusips_with_21_columns_in_trade_history)
# Out:
# 101
