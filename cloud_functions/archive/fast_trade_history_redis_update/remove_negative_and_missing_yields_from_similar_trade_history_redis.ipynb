# %% [markdown]
# Last updated by Developer on 2024-06-14.
#
# When populating the similar trade history redis on 2024-02-26, I forgot to remove trades with negative yields before uploading them to the redis. This notebook identifies the trades which may have been added to the similar trades redis, and removes them.

# %%
import pandas as pd
import pickle

from main import FEATURES_FOR_EACH_TRADE_IN_HISTORY, \
                 MAX_NUM_TRADES_IN_SIMILAR_TRADE_HISTORY, \
                 similar_trade_history_redis_client, \
                 get_reference_data_from_reference_data_redis, \
                 typecast_reference_data, \
                 left_join_on_cusip, \
                 download_pickle_file, \
                 add_features_for_definition_of_similar, \
                 create_trade_history_numpy_array, \
                 remove_negative_and_missing_yields, \
                 upload_trade_history_to_redis, \
                 upload_to_redis_from_upload_function

# %% [markdown]
# Get all the trades for 2024-02-26.

# %%
all_trades = download_pickle_file('msrb_intraday_real_time_trade_files', '2024-02-26/all_trade_messages.pkl')
all_trades.head(10)
# Out:
# File 2024-02-26/all_trade_messages.pkl found in msrb_intraday_real_time_trade_files/2024-02-26/all_trade_messages.pkl
# Pickle file 2024-02-26/all_trade_messages.pkl downloaded from msrb_intraday_real_time_trade_files/2024-02-26/all_trade_messages.pkl
#                 message_type  sequence_number rtrs_control_number trade_type  \
# sequence_number
# 0                          O                0                None       None
# 1                          T                1    2024021600016600          S
# 2                          T                2    2024021600049300          S
# 3                          T                3    2024021600053100          S
# 4                          T                4    2024021600105400          S
# 5                          T                5    2024021600108000          P
# 6                          T                6    2024021600166100          S
# 7                          T                7    2024021600214400          S
# 8                          T                8    2024021600242900          P
# 9                          T                9    2024021600369100          S
#
#                 transaction_type      cusip  \
# sequence_number
# 0                           None       None
# 1                              R  64971XY28
# 2                              R  70917RPY5
# 3                              R  64970HAW4
# 4                              R  64972GZB3
# 5                              R  64972GZB3
# 6                              R  60528AAS3
# 7                              R  523470HD7
# 8                              R  13063BFR8
# 9                              R  709224M30
#
#                                               security_description  \
# sequence_number
# 0                                                             None
# 1                NEW YORK N Y CITY TRANSITIONAL FIN AUTH REV AD...
# 2                PENNSYLVANIA ST HIGHER EDL FACS AUTH REV VAR-U...
# 3                NEW YORK N Y CITY HSG DEV CORP MULTIFAMILY REN...
# 4                NEW YORK N Y CITY MUN WTR FIN AUTH WTR & SWR S...
# 5                NEW YORK N Y CITY MUN WTR FIN AUTH WTR & SWR S...
# 6                MISSISSIPPI BUSINESS FIN CORP MISS GULF OPPORT...
# 7                                  LEE CNTY FLA ARPT REV AMT-SER B
# 8                                   CALIFORNIA ST TAXABLE-VAR PURP
# 9                 PENNSYLVANIA ST TPK COMMN TPK REV VAR-SECOND SER
#
#                  dated_date coupon maturity_date  ...  \
# sequence_number                                   ...
# 0                      None   None          None  ...
# 1                2022-08-02   3.05    2052-08-01  ...
# 2                2008-04-16   3.61    2038-01-01  ...
# 3                2002-08-22   3.67    2032-08-15  ...
# 4                2021-03-31    3.1    2045-06-15  ...
# 5                2021-03-31    3.1    2045-06-15  ...
# 6                2007-12-19   2.91    2030-12-01  ...
# 7                2021-10-26    4.0    2038-10-01  ...
# 8                2010-04-01  7.625    2040-03-01  ...
# 9                2019-06-04   3.61    2038-12-01  ...
#
#                  is_weighted_average_price is_lop_or_takedown publish_date  \
# sequence_number
# 0                                    False              False         None
# 1                                    False              False   2024-02-26
# 2                                    False              False   2024-02-26
# 3                                    False              False   2024-02-26
# 4                                    False              False   2024-02-26
# 5                                    False              False   2024-02-26
# 6                                    False              False   2024-02-26
# 7                                    False              False   2024-02-26
# 8                                    False              False   2024-02-26
# 9                                    False              False   2024-02-26
#
#                 publish_time version unable_to_verify_dollar_price  \
# sequence_number
# 0                       None    None                         False
# 1                   06:01:01     1.3                         False
# 2                   06:01:01     1.3                         False
# 3                   06:01:01     1.3                         False
# 4                   06:01:01     1.3                         False
# 5                   06:01:01     1.3                         False
# 6                   06:01:01     1.3                         False
# 7                   06:01:01     1.3                         False
# 8                   06:01:01     1.3                         False
# 9                   06:01:01     1.3                         False
#
#                 is_alternative_trading_system  \
# sequence_number
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
# 5                                       False
# 6                                       False
# 7                                       False
# 8                                       False
# 9                                       False
#
#                 is_non_transaction_based_compensation  \
# sequence_number
# 0                                               False
# 1                                                True
# 2                                                True
# 3                                                True
# 4                                                True
# 5                                                True
# 6                                                True
# 7                                               False
# 8                                               False
# 9                                                True
#
#                 is_trade_with_a_par_amount_over_5MM  upload_date
# sequence_number
# 0                                             False   2024-02-26
# 1                                             False   2024-02-26
# 2                                             False   2024-02-26
# 3                                             False   2024-02-26
# 4                                             False   2024-02-26
# 5                                             False   2024-02-26
# 6                                             False   2024-02-26
# 7                                             False   2024-02-26
# 8                                             False   2024-02-26
# 9                                             False   2024-02-26
#
# [10 rows x 29 columns]

# %% [markdown]
# Isolate the trades with negative yields.

# %%
all_trades_with_negative_yields = all_trades[~pd.isna(all_trades['yield'])]
all_trades_with_negative_yields = all_trades_with_negative_yields[all_trades_with_negative_yields['yield'] < 0]
# Out:
# len(all_trades_with_negative_yields): 59

# %% [markdown]
# Add similar trade history redis featuers to get bucket identifiers for trades with negative yields.

# %%
cusip_list_from_msrb_data = all_trades_with_negative_yields['cusip'].unique().tolist()    # .unique() prevents same CUSIP being queried in Redis when there are multiple trades with the same CUSIP
reference_data, cusips_not_found = get_reference_data_from_reference_data_redis(cusip_list_from_msrb_data)
reference_data = typecast_reference_data(reference_data)
all_trades_with_negative_yields = left_join_on_cusip(all_trades_with_negative_yields, reference_data)
# Out:
# BEGIN get_reference_data_from_reference_data_redis
# END get_reference_data_from_reference_data_redis. Execution time: 0:00:00.140410
# BEGIN typecast_reference_data
# END typecast_reference_data. Execution time: 0:00:00.000991
# BEGIN left_join_on_cusip
# END left_join_on_cusip. Execution time: 0:00:00.083512

# %%
all_trades_with_negative_yields = all_trades_with_negative_yields.dropna(subset=['issue_key', 'maturity_date', 'trade_date', 'coupon'])
all_trades_with_negative_yields = add_features_for_definition_of_similar(all_trades_with_negative_yields)
print('len(all_trades_with_negative_yields):', len(all_trades_with_negative_yields))
# Out:
# len(all_trades_with_negative_yields): 59

# %% [markdown]
# The following function is taken from `fast_trade_history_redis_update/main.py` with minor modifications.

# %%
def get_key_trade_history_pair(key, redis_client, max_num_trades, key_transform_func=None, verbose=False, keep_cusip_in_trade_history=False):
    '''`key_transform_func` is helpful in turning a tuple into a primitive type (e.g. string) that can be 
    used as a key for Redis. Redis does not allow tuples to be used as keys.'''
    if key_transform_func is not None: key = key_transform_func(key)
    if verbose: print(f'Calling get_key_trade_history_pair(...) with key={key}')
    features_for_each_trade_in_history = list(FEATURES_FOR_EACH_TRADE_IN_HISTORY.keys())
    if keep_cusip_in_trade_history: features_for_each_trade_in_history.append('cusip')
    if not redis_client.exists(key): print(f'{key} should exist in similar trade history redis')
    old_trade_history = redis_client.get(key)
    try:
        old_trade_history = pd.DataFrame(pickle.loads(old_trade_history), columns=features_for_each_trade_in_history)
    except Exception as e:
        print('key:', key)
        print('old_trade_history:\n', pd.DataFrame(pickle.loads(old_trade_history)))
        raise e
    before_removing_negative_yields = len(old_trade_history)
    old_trade_history = remove_negative_and_missing_yields(old_trade_history)
    after_removing_negative_yields = len(old_trade_history)
    if before_removing_negative_yields == after_removing_negative_yields:
        print('No trades were removed, so no updates need to be made, thus returning `None`')
        return None, None
    return key, create_trade_history_numpy_array(old_trade_history, max_num_trades)

# %%
features_to_string = lambda features: '_'.join([str(feature) for feature in features])    # `features` should be a tuple or list; NOTE: this lambda function is identical to `similar_group_to_similar_key(...)` in `app_engine/demo/server/modules/finance.py`
get_features_similar_trade_history_pair_caller = lambda features: get_key_trade_history_pair(features, similar_trade_history_redis_client, MAX_NUM_TRADES_IN_SIMILAR_TRADE_HISTORY, features_to_string, verbose=True, keep_cusip_in_trade_history=True)
features_trade_history_pairs = [get_features_similar_trade_history_pair_caller(features) for features, df_for_features in all_trades_with_negative_yields.groupby(['issue_key', 'years_to_maturity_date_by_5', 'coupon_by_1'])]
features_trade_history_pairs = [(feature, trade_history) for feature, trade_history in features_trade_history_pairs if feature is not None]
# Out:
# Calling get_key_trade_history_pair(...) with key=571357_1_5
# Removed 3 trades for having negative or missing yields, leaving 7 trades
# Calling get_key_trade_history_pair(...) with key=573112_3_6
# Removed 1 trades for having negative or missing yields, leaving 3 trades
# Calling get_key_trade_history_pair(...) with key=619626_2_6
# Removed 1 trades for having negative or missing yields, leaving 28 trades
# Calling get_key_trade_history_pair(...) with key=621809_1_5
# Removed 4 trades for having negative or missing yields, leaving 7 trades
# Calling get_key_trade_history_pair(...) with key=625701_3_5
# Removed 1 trades for having negative or missing yields, leaving 39 trades
# Calling get_key_trade_history_pair(...) with key=746450_0_5
# Removed 1 trades for having negative or missing yields, leaving 63 trades
# Calling get_key_trade_history_pair(...) with key=752411_0_5
# Removed 2 trades for having negative or missing yields, leaving 62 trades
# Calling get_key_trade_history_pair(...) with key=779986_0_5
# Removed 1 trades for having negative or missing yields, leaving 2 trades
# Calling get_key_trade_history_pair(...) with key=865275_1_5
# Removed 3 trades for having negative or missing yields, leaving 0 trades
# Calling get_key_trade_history_pair(...) with key=875741_2_4
# Removed 1 trades for having negative or missing yields, leaving 28 trades
# Calling get_key_trade_history_pair(...) with key=875741_3_5
# Removed 1 trades for having negative or missing yields, leaving 63 trades
# Calling get_key_trade_history_pair(...) with key=883873_0_4
# Removed 2 trades for having negative or missing yields, leaving 5 trades
# Calling get_key_trade_history_pair(...) with key=921626_1_6
# Removed 2 trades for having negative or missing yields, leaving 14 trades
# Calling get_key_trade_history_pair(...) with key=940251_0_4
# Removed 1 trades for having negative or missing yields, leaving 5 trades
# Calling get_key_trade_history_pair(...) with key=944202_0_5
# Removed 1 trades for having negative or missing yields, leaving 63 trades
# Calling get_key_trade_history_pair(...) with key=948654_3_5
# Removed 1 trades for having negative or missing yields, leaving 29 trades
# Calling get_key_trade_history_pair(...) with key=957855_0_5
# Removed 1 trades for having negative or missing yields, leaving 63 trades
# Calling get_key_trade_history_pair(...) with key=966508_1_5
# Removed 1 trades for having negative or missing yields, leaving 41 trades
# Calling get_key_trade_history_pair(...) with key=966782_0_5
# Removed 2 trades for having negative or missing yields, leaving 62 trades
# Calling get_key_trade_history_pair(...) with key=967573_3_-1
# Removed 2 trades for having negative or missing yields, leaving 62 trades
# Calling get_key_trade_history_pair(...) with key=967705_1_5
# Removed 1 trades for having negative or missing yields, leaving 20 trades
# Calling get_key_trade_history_pair(...) with key=970721_0_5
# Removed 2 trades for having negative or missing yields, leaving 37 trades
# Calling get_key_trade_history_pair(...) with key=976974_0_5
# Removed 1 trades for having negative or missing yields, leaving 11 trades
# Calling get_key_trade_history_pair(...) with key=977378_3_5
# Removed 2 trades for having negative or missing yields, leaving 60 trades
# Calling get_key_trade_history_pair(...) with key=977864_3_4
# Removed 3 trades for having negative or missing yields, leaving 29 trades
# Calling get_key_trade_history_pair(...) with key=981430_1_5
# Removed 1 trades for having negative or missing yields, leaving 63 trades
# Calling get_key_trade_history_pair(...) with key=984914_0_-1
# Removed 3 trades for having negative or missing yields, leaving 61 trades
# Calling get_key_trade_history_pair(...) with key=987762_1_5
# Removed 2 trades for having negative or missing yields, leaving 62 trades
# Calling get_key_trade_history_pair(...) with key=987945_2_5
# Removed 1 trades for having negative or missing yields, leaving 32 trades
# Calling get_key_trade_history_pair(...) with key=990524_0_5
# Removed 3 trades for having negative or missing yields, leaving 61 trades
# Calling get_key_trade_history_pair(...) with key=1019839_1_4
# No trades were removed, so no updates need to be made, thus returning `None`
# Calling get_key_trade_history_pair(...) with key=1034734_4_5
# Removed 3 trades for having negative or missing yields, leaving 31 trades
# Calling get_key_trade_history_pair(...) with key=1070147_1_5
# Removed 2 trades for having negative or missing yields, leaving 62 trades
# Calling get_key_trade_history_pair(...) with key=1209157_1_5
# Removed 1 trades for having negative or missing yields, leaving 63 trades

# %%
similar_trade_history_redis_client.delete('865275_1_5')    # since this key no longer has any trades, remove it from the redis
# Out:
# 1

# %% [markdown]
# Upload new trade history pairs to the similar trade history redis.

# %%
upload_similar_trade_history_to_similar_trade_history_redis = lambda features, trade_history: upload_trade_history_to_redis(features, trade_history, similar_trade_history_redis_client)
upload_to_redis_from_upload_function(features_trade_history_pairs, upload_similar_trade_history_to_similar_trade_history_redis)
# Out:
# [('571357_1_5',
#   array([[Timestamp('2024-02-26 15:19:15'),
#           Timestamp('2100-01-01 00:00:00'), 2024022609411100,
#           Timestamp('2024-02-26 15:19:04'),
#           Timestamp('2024-02-26 15:19:15'), 0.38, 100.381, 10000.0, 'P',
#           False, False, None, False, False, datetime.date(2024, 2, 28),
#           datetime.date(2024, 3, 28), 0, datetime.date(2033, 2, 15),
#           datetime.date(2024, 3, 28), datetime.date(2024, 3, 28), NaT, 'I',
#           41729, '795677AG8'],
#          [Timestamp('2024-02-13 13:41:15'),
#           Timestamp('2100-01-01 00:00:00'), 2024021306627300,
#           Timestamp('2024-02-13 13:39:07'),
#           Timestamp('2024-02-13 13:41:15'), 5.17, 99.677, 10000.0, 'P',
#           False, False, None, False, False, datetime.date(2024, 2, 13),
#           datetime.date(2033, 2, 15), 2, datetime.date(2033, 2, 15),
#           datetime.date(2024, 3, 15), datetime.date(2024, 3, 15), NaT, 'I',
#           29266, '795677AG8'],
#          [Timestamp('2024-02-09 08:48:18'),
#           Timestamp('2100-01-01 00:00:00'), 2024020801861500,
#           Timestamp('2024-02-08 10:12:47'),
#           Timestamp('2024-02-09 08:48:18'), 3.698, 100.112, 30000.0, 'D',
#           False, False, None, False, False, datetime.date(2024, 2, 9),
#           datetime.date(2024, 3, 11), 0, datetime.date(2033, 2, 15),
#           datetime.date(2024, 3, 11), datetime.date(2024, 3, 11), NaT, 'I',
#           1420, '795677AG8'],
#          [Timestamp('2024-02-08 10:18:46'),
#           Timestamp('2100-01-01 00:00:00'), 2024020801865400,
#           Timestamp('2024-02-08 10:12:47'),
#           Timestamp('2024-02-08 10:18:46'), 3.698, 100.112, 30000.0, 'P',
#           True, False, None, False, False, datetime.date(2024, 2, 9),
#           datetime.date(2024, 3, 10), 0, datetime.date(2033, 2, 15),
#           datetime.date(2024, 3, 10), datetime.date(2024, 3, 10), NaT, 'I',
#           7781, '795677AG8'],
#          [Timestamp('2024-02-01 10:39:35'),
#           Timestamp('2100-01-01 00:00:00'), 2024020102806300.0,
#           Timestamp('2024-02-01 10:39:02'),
#           Timestamp('2024-02-01 10:39:35'), 0.837, 100.32, 25000.0, 'D',
#           False, False, None, True, False, datetime.date(2024, 2, 5),
#           datetime.date(2024, 3, 3), 0, datetime.date(2033, 2, 15),
#           datetime.date(2024, 3, 3), datetime.date(2024, 3, 3), NaT, 'I',
#           11637, '795677AG8'],
#          [Timestamp('2024-02-01 10:39:19'),
#           Timestamp('2100-01-01 00:00:00'), 2024020102806100.0,
#           Timestamp('2024-02-01 10:39:02'),
#           Timestamp('2024-02-01 10:39:19'), 1.489, 100.27, 25000.0, 'D',
#           False, False, None, True, False, datetime.date(2024, 2, 5),
#           datetime.date(2024, 3, 3), 0, datetime.date(2033, 2, 15),
#           datetime.date(2024, 3, 3), datetime.date(2024, 3, 3), NaT, 'I',
#           11589, '795677AG8'],
#          [Timestamp('2024-02-01 10:39:19'),
#           Timestamp('2100-01-01 00:00:00'), 2024020102806000.0,
#           Timestamp('2024-02-01 10:39:02'),
#           Timestamp('2024-02-01 10:39:19'), 1.489, 100.27, 25000.0, 'P',
#           True, False, None, False, False, datetime.date(2024, 2, 5),
#           datetime.date(2024, 3, 3), 0, datetime.date(2033, 2, 15),
#           datetime.date(2024, 3, 3), datetime.date(2024, 3, 3), NaT, 'I',
#           11585, '795677AG8']], dtype=object)),
#  ('573112_3_6',
#   array([[Timestamp('2024-01-25 12:52:39'),
#           Timestamp('2100-01-01 00:00:00'), 2024012506292100,
#           Timestamp('2024-01-25 12:40:42'),
#           Timestamp('2024-01-25 12:52:39'), 6.79, 99.6, 10000.0, 'P', True,
#           False, None, False, False, datetime.date(2024, 1, 29),
#           datetime.date(2040, 5, 15), 2, datetime.date(2040, 5, 15),
#           datetime.date(2024, 2, 25), datetime.date(2024, 2, 25), NaT, 'I',
#           28395, '254842AK3'],
#          [Timestamp('2024-01-25 12:52:39'),
#           Timestamp('2100-01-01 00:00:00'), 2024012506291700,
#           Timestamp('2024-01-25 12:40:42'),
#           Timestamp('2024-01-25 12:52:39'), 6.79, 99.6, 10000.0, 'D',
#           False, False, None, False, False, datetime.date(2024, 1, 29),
#           datetime.date(2040, 5, 15), 2, datetime.date(2040, 5, 15),
#           datetime.date(2024, 2, 25), datetime.date(2024, 2, 25), NaT, 'I',
#           28394, '254842AK3'],
#          [Timestamp('2024-01-25 11:27:44'),
#           Timestamp('2100-01-01 00:00:00'), 2024012503631900,
#           Timestamp('2024-01-25 11:26:08'),
#           Timestamp('2024-01-25 11:27:44'), 0.331, 100.445, 285000.0, 'P',
#           False, False, None, False, False, datetime.date(2024, 1, 29),
#           datetime.date(2024, 2, 25), 0, datetime.date(2040, 5, 15),
#           datetime.date(2024, 2, 25), datetime.date(2024, 2, 25), NaT, 'I',
#           15778, '254842AK3']], dtype=object)),
#  ('619626_2_6',
#   array([[Timestamp('2024-02-26 15:51:24'),
#           Timestamp('2100-01-01 00:00:00'), 2024022610207900,
#           Timestamp('2024-02-26 15:51:00'),
#           Timestamp('2024-02-26 15:51:24'), 3.424, 100.2, 15000.0, 'D',
#           False, False, None, False, False, datetime.date(2024, 2, 28),
#           datetime.date(2024, 3, 28), 0, datetime.date(2037, 5, 1),
#           datetime.date(2024, 3, 28), datetime.date(2024, 3, 28), NaT, 'I',
#           44872, '130923BG9'],
#          [Timestamp('2024-02-26 12:43:39'),
#           Timestamp('2100-01-01 00:00:00'), 2024022605267200,
#           Timestamp('2024-02-26 12:43:26'),
#           Timestamp('2024-02-26 12:43:39'), 5.853, 100.0, 15000.0, 'D',
#           False, False, None, False, False, datetime.date(2024, 2, 28),
#           datetime.date(2024, 3, 28), 0, datetime.date(2037, 5, 1),
#           datetime.date(2024, 3, 28), datetime.date(2024, 3, 28), NaT, 'I',
#           23122, '130923BG9'],
#          [Timestamp('2024-02-26 12:43:36'),
#           Timestamp('2100-01-01 00:00:00'), 2024022605266800,
#           Timestamp('2024-02-26 12:43:26'),
#           Timestamp('2024-02-26 12:43:36'), 5.853, 100.0, 15000.0, 'P',
#           True, False, None, False, False, datetime.date(2024, 2, 28),
#           datetime.date(2024, 3, 28), 0, datetime.date(2037, 5, 1),
#           datetime.date(2024, 3, 28), datetime.date(2024, 3, 28), NaT, 'I',
#           23099, '130923BG9'],
#          [Timestamp('2024-01-08 14:04:43'),
#           Timestamp('2100-01-01 00:00:00'), 2024010807679500,
#           Timestamp('2024-01-08 14:03:58'),
#           Timestamp('2024-01-08 14:04:43'), 6.048, 99.555, 10000.0, 'D',
#           False, False, None, True, False, datetime.date(2024, 1, 10),
#           datetime.date(2037, 5, 1), 2, datetime.date(2037, 5, 1),
#           datetime.date(2024, 2, 8), datetime.date(2024, 2, 8), NaT, 'I',
#           34728, '130923BG9'],
#          [Timestamp('2024-01-08 14:04:08'),
#           Timestamp('2100-01-01 00:00:00'), 2024010807679400,
#           Timestamp('2024-01-08 14:03:58'),
#           Timestamp('2024-01-08 14:04:08'), 6.068, 99.374, 10000.0, 'P',
#           False, False, None, False, False, datetime.date(2024, 1, 10),
#           datetime.date(2037, 5, 1), 2, datetime.date(2037, 5, 1),
#           datetime.date(2024, 2, 8), datetime.date(2024, 2, 8), NaT, 'I',
#           34663, '130923BG9'],
#          [Timestamp('2024-01-03 13:37:18'),
#           Timestamp('2100-01-01 00:00:00'), 2024010308347100,
#           Timestamp('2024-01-03 13:36:36'),
#           Timestamp('2024-01-03 13:37:18'), 6.093, 99.15, 10000.0, 'S',
#           False, False, None, False, False, datetime.date(2024, 1, 4),
#           datetime.date(2037, 5, 1), 2, datetime.date(2037, 5, 1),
#           datetime.date(2024, 2, 3), datetime.date(2024, 2, 3), NaT, 'I',
#           36601, '130923BG9'],
#          [Timestamp('2023-12-21 16:28:55'),
#           Timestamp('2100-01-01 00:00:00'), 2023122113088400,
#           Timestamp('2023-12-21 16:28:32'),
#           Timestamp('2023-12-21 16:28:55'), 2.188, 100.25, 10000.0, 'D',
#           False, False, None, False, False, datetime.date(2023, 12, 26),
#           datetime.date(2024, 1, 21), 0, datetime.date(2037, 5, 1),
#           datetime.date(2024, 1, 21), datetime.date(2024, 1, 21), NaT, 'I',
#           57459, '130923BG9'],
#          [Timestamp('2023-12-21 16:28:55'),
#           Timestamp('2100-01-01 00:00:00'), 2023122113088300,
#           Timestamp('2023-12-21 16:28:32'),
#           Timestamp('2023-12-21 16:28:55'), 2.188, 100.25, 10000.0, 'S',
#           True, False, None, False, False, datetime.date(2023, 12, 26),
#           datetime.date(2024, 1, 21), 0, datetime.date(2037, 5, 1),
#           datetime.date(2024, 1, 21), datetime.date(2024, 1, 21), NaT, 'I',
#           57458, '130923BG9'],
#          [Timestamp('2023-12-05 14:21:54'),
#           Timestamp('2100-01-01 00:00:00'), 2023120511694300,
#           Timestamp('2023-12-05 14:21:32'),
#           Timestamp('2023-12-05 14:21:54'), 6.097, 99.11, 10000.0, 'P',
#           False, False, None, False, False, datetime.date(2023, 12, 7),
#           datetime.date(2037, 5, 1), 2, datetime.date(2037, 5, 1),
#           datetime.date(2024, 1, 5), datetime.date(2024, 1, 5), NaT, 'I',
#           52864, '130923BG9'],
#          [Timestamp('2023-12-04 15:53:14'),
#           Timestamp('2100-01-01 00:00:00'), 2023120414910700,
#           Timestamp('2023-12-04 15:51:00'),
#           Timestamp('2023-12-04 15:53:14'), 6.079, 99.28, 10000.0, 'S',
#           False, False, None, False, False, datetime.date(2023, 12, 6),
#           datetime.date(2037, 5, 1), 2, datetime.date(2037, 5, 1),
#           datetime.date(2024, 1, 4), datetime.date(2024, 1, 4), NaT, 'I',
#           73786, '130923BG9'],
#          [Timestamp('2023-11-17 15:06:42'),
#           Timestamp('2100-01-01 00:00:00'), 2023111713998000,
#           Timestamp('2023-11-17 15:06:13'),
#           Timestamp('2023-11-17 15:06:42'), 6.054, 99.5, 10000.0, 'D',
#           False, False, None, False, False, datetime.date(2023, 11, 21),
#           datetime.date(2037, 5, 1), 2, datetime.date(2037, 5, 1),
#           datetime.date(2023, 12, 18), datetime.date(2023, 12, 18), NaT,
#           'I', 63537, '130923BG9'],
#          [Timestamp('2023-11-17 15:06:42'),
#           Timestamp('2100-01-01 00:00:00'), 2023111713997900,
#           Timestamp('2023-11-17 15:06:13'),
#           Timestamp('2023-11-17 15:06:42'), 6.068, 99.375, 10000.0, 'P',
#           False, False, None, False, False, datetime.date(2023, 11, 21),
#           datetime.date(2037, 5, 1), 2, datetime.date(2037, 5, 1),
#           datetime.date(2023, 12, 18), datetime.date(2023, 12, 18), NaT,
#           'I', 63536, '130923BG9'],
#          [Timestamp('2023-11-08 13:48:56'),
#           Timestamp('2100-01-01 00:00:00'), 2023110810420200,
#           Timestamp('2023-11-08 13:44:03'),
#           Timestamp('2023-11-08 13:48:56'), 6.079, 99.28, 10000.0, 'D',
#           False, False, None, True, False, datetime.date(2023, 11, 10),
#           datetime.date(2037, 5, 1), 2, datetime.date(2037, 5, 1),
#           datetime.date(2023, 12, 9), datetime.date(2023, 12, 9), NaT, 'I',
#           47563, '130923BG9'],
#          [Timestamp('2023-11-08 13:44:13'),
#           Timestamp('2100-01-01 00:00:00'), 2023110810420300,
#           Timestamp('2023-11-08 13:44:03'),
#           Timestamp('2023-11-08 13:44:13'), 6.079, 99.28, 10000.0, 'P',
#           True, False, None, False, False, datetime.date(2023, 11, 10),
#           datetime.date(2037, 5, 1), 2, datetime.date(2037, 5, 1),
#           datetime.date(2023, 12, 9), datetime.date(2023, 12, 9), NaT, 'I',
#           46790, '130923BG9'],
#          [Timestamp('2023-10-05 15:25:42'),
#           Timestamp('2100-01-01 00:00:00'), 2023100513444000,
#           Timestamp('2023-10-05 15:25:14'),
#           Timestamp('2023-10-05 15:25:42'), 6.004, 99.959, 10000.0, 'D',
#           False, False, None, True, False, datetime.date(2023, 10, 10),
#           datetime.date(2037, 5, 1), 2, datetime.date(2037, 5, 1),
#           datetime.date(2023, 11, 5), datetime.date(2023, 11, 5), NaT, 'I',
#           60889, '130923BG9'],
#          [Timestamp('2023-10-05 15:25:24'),
#           Timestamp('2100-01-01 00:00:00'), 2023100513443900,
#           Timestamp('2023-10-05 15:25:14'),
#           Timestamp('2023-10-05 15:25:24'), 6.141, 98.709, 10000.0, 'P',
#           False, False, None, False, False, datetime.date(2023, 10, 10),
#           datetime.date(2037, 5, 1), 2, datetime.date(2037, 5, 1),
#           datetime.date(2023, 11, 5), datetime.date(2023, 11, 5), NaT, 'I',
#           60852, '130923BG9'],
#          [Timestamp('2023-09-14 15:42:32'),
#           Timestamp('2100-01-01 00:00:00'), 2023091411438800,
#           Timestamp('2023-09-14 15:42:21'),
#           Timestamp('2023-09-14 15:42:32'), 3.171, 100.198, 50000.0, 'P',
#           True, False, None, False, False, datetime.date(2023, 9, 18),
#           datetime.date(2023, 10, 15), 0, datetime.date(2037, 5, 1),
#           datetime.date(2023, 10, 15), datetime.date(2023, 10, 15), NaT,
#           'I', 52492, '130923BG9'],
#          [Timestamp('2023-09-14 15:17:05'),
#           Timestamp('2100-01-01 00:00:00'), 2023091410774600,
#           Timestamp('2023-09-14 15:15:52'),
#           Timestamp('2023-09-14 15:17:05'), 1.822, 100.298, 50000.0, 'D',
#           False, False, None, True, False, datetime.date(2023, 9, 18),
#           datetime.date(2023, 10, 15), 0, datetime.date(2037, 5, 1),
#           datetime.date(2023, 10, 15), datetime.date(2023, 10, 15), NaT,
#           'I', 49545, '130923BG9'],
#          [Timestamp('2023-05-19 17:48:29'),
#           Timestamp('2100-01-01 00:00:00'), 2023051911420800,
#           Timestamp('2023-05-19 17:28:20'),
#           Timestamp('2023-05-19 17:48:29'), 3.583, 100.161,
#           Decimal('80000.000000000'), 'D', False, False, None, True, False,
#           datetime.date(2023, 5, 23), datetime.date(2023, 6, 19), 0,
#           datetime.date(2037, 5, 1), datetime.date(2023, 6, 19),
#           datetime.date(2023, 6, 19), NaT, 'I', 45025.0, '130923BG9'],
#          [Timestamp('2023-05-19 16:57:20'),
#           Timestamp('2100-01-01 00:00:00'), 2023051910867200,
#           Timestamp('2023-05-19 16:55:55'),
#           Timestamp('2023-05-19 16:57:20'), 5.694, 100.011,
#           Decimal('80000.000000000'), 'P', False, False, None, False,
#           False, datetime.date(2023, 5, 23), datetime.date(2023, 6, 19), 0,
#           datetime.date(2037, 5, 1), datetime.date(2023, 6, 19),
#           datetime.date(2023, 6, 19), NaT, 'I', 44590.0, '130923BG9'],
#          [Timestamp('2023-05-19 16:39:06'),
#           Timestamp('2100-01-01 00:00:00'), 2023051910569700,
#           Timestamp('2023-05-19 16:37:58'),
#           Timestamp('2023-05-19 16:39:06'), 0.079, 100.411,
#           Decimal('80000.000000000'), 'D', False, False, None, True, False,
#           datetime.date(2023, 5, 23), datetime.date(2023, 6, 19), 0,
#           datetime.date(2037, 5, 1), datetime.date(2023, 6, 19),
#           datetime.date(2023, 6, 19), NaT, 'I', 44010.0, '130923BG9'],
#          [Timestamp('2023-04-17 13:12:20'),
#           Timestamp('2100-01-01 00:00:00'), 2023041705106400,
#           Timestamp('2023-04-17 13:12:11'),
#           Timestamp('2023-04-17 13:12:20'), 6.002, 99.976,
#           Decimal('25000.000000000'), 'S', False, False, None, False,
#           False, datetime.date(2023, 4, 19), datetime.date(2037, 5, 1), 2,
#           datetime.date(2037, 5, 1), datetime.date(2023, 5, 18),
#           datetime.date(2023, 5, 18), NaT, 'I', 21974.0, '130923BG9'],
#          [Timestamp('2023-04-17 12:27:08'),
#           Timestamp('2100-01-01 00:00:00'), 2023041704122400,
#           Timestamp('2023-04-17 12:26:51'),
#           Timestamp('2023-04-17 12:27:08'), 6.053, 99.5,
#           Decimal('25000.000000000'), 'P', True, False, None, False, False,
#           datetime.date(2023, 4, 19), datetime.date(2037, 5, 1), 2,
#           datetime.date(2037, 5, 1), datetime.date(2023, 5, 18),
#           datetime.date(2023, 5, 18), NaT, 'I', 17571.0, '130923BG9'],
#          [Timestamp('2022-09-29 14:43:24'),
#           Timestamp('2100-01-01 00:00:00'), 2022092910937800,
#           Timestamp('2022-09-29 14:42:21'),
#           Timestamp('2022-09-29 14:43:24'), 4.496, 100.1,
#           Decimal('20000.000000000'), 'S', False, False, None, False,
#           False, datetime.date(2022, 10, 3), datetime.date(2022, 10, 30),
#           0, datetime.date(2037, 5, 1), datetime.date(2022, 10, 30),
#           datetime.date(2022, 10, 30), NaT, 'I', 48518.0, '130923BG9'],
#          [Timestamp('2022-09-23 15:56:09'),
#           Timestamp('2100-01-01 00:00:00'), 2022092310650300,
#           Timestamp('2022-09-23 15:55:43'),
#           Timestamp('2022-09-23 15:56:09'), 4.496, 100.1,
#           Decimal('10000.000000000'), 'D', False, False, None, True, False,
#           datetime.date(2022, 9, 27), datetime.date(2022, 10, 24), 0,
#           datetime.date(2037, 5, 1), datetime.date(2022, 10, 24),
#           datetime.date(2022, 10, 24), NaT, 'I', 44724.0, '130923BG9'],
#          [Timestamp('2022-09-23 15:56:01'),
#           Timestamp('2100-01-01 00:00:00'), 2022092310650500,
#           Timestamp('2022-09-23 15:55:43'),
#           Timestamp('2022-09-23 15:56:01'), 6.004, 99.95,
#           Decimal('10000.000000000'), 'P', False, False, None, False,
#           False, datetime.date(2022, 9, 27), datetime.date(2037, 5, 1), 2,
#           datetime.date(2037, 5, 1), datetime.date(2022, 10, 24),
#           datetime.date(2022, 10, 24), NaT, 'I', 44710.0, '130923BG9'],
#          [Timestamp('2022-09-22 15:13:29'),
#           Timestamp('2100-01-01 00:00:00'), 2022092210512300,
#           Timestamp('2022-09-22 15:12:52'),
#           Timestamp('2022-09-22 15:13:29'), 6.01, 99.9,
#           Decimal('10000.000000000'), 'D', False, False, None, True, False,
#           datetime.date(2022, 9, 26), datetime.date(2037, 5, 1), 2,
#           datetime.date(2037, 5, 1), datetime.date(2022, 10, 23),
#           datetime.date(2022, 10, 23), NaT, 'I', 45730.0, '130923BG9'],
#          [Timestamp('2022-09-22 15:13:12'),
#           Timestamp('2100-01-01 00:00:00'), 2022092210510700,
#           Timestamp('2022-09-22 15:12:52'),
#           Timestamp('2022-09-22 15:13:12'), 6.141, 98.65,
#           Decimal('10000.000000000'), 'P', False, False, None, False,
#           False, datetime.date(2022, 9, 26), datetime.date(2037, 5, 1), 2,
#           datetime.date(2037, 5, 1), datetime.date(2022, 10, 23),
#           datetime.date(2022, 10, 23), NaT, 'I', 45689.0, '130923BG9']],
#         dtype=object)),
#  ('621809_1_5',
#   array([[Timestamp('2023-12-08 12:30:58'),
#           Timestamp('2100-01-01 00:00:00'), 2023120806295400,
#           Timestamp('2023-12-08 12:30:53'),
#           Timestamp('2023-12-08 12:30:58'), 0.116, 100.339, 50000.0, 'P',
#           False, False, None, False, False, datetime.date(2023, 12, 12),
#           datetime.date(2024, 1, 8), 0, datetime.date(2032, 2, 15),
#           datetime.date(2024, 1, 8), datetime.date(2024, 1, 8), NaT, 'I',
#           28119, '848627HD0'],
#          [Timestamp('2023-10-20 13:46:08'),
#           Timestamp('2100-01-01 00:00:00'), 2023102010707500,
#           Timestamp('2023-10-20 13:45:30'),
#           Timestamp('2023-10-20 13:46:08'), 5.064, 99.566, 15000.0, 'P',
#           True, False, None, False, False, datetime.date(2023, 10, 24),
#           datetime.date(2032, 2, 15), 2, datetime.date(2032, 2, 15),
#           datetime.date(2023, 11, 20), datetime.date(2023, 11, 20), NaT,
#           'I', 50164, '848627HD0'],
#          [Timestamp('2023-10-20 12:53:22'),
#           Timestamp('2100-01-01 00:00:00'), 2023102008565300,
#           Timestamp('2023-10-20 12:50:54'),
#           Timestamp('2023-10-20 12:53:22'), 5.064, 99.566, 15000.0, 'D',
#           False, False, None, True, False, datetime.date(2023, 10, 24),
#           datetime.date(2032, 2, 15), 2, datetime.date(2032, 2, 15),
#           datetime.date(2023, 11, 20), datetime.date(2023, 11, 20), NaT,
#           'I', 40160, '848627HD0'],
#          [Timestamp('2022-11-08 15:12:50'),
#           Timestamp('2100-01-01 00:00:00'), 2022110813591300,
#           Timestamp('2022-11-08 15:11:44'),
#           Timestamp('2022-11-08 15:12:50'), 2.764, 100.169,
#           Decimal('25000.000000000'), 'P', False, False, None, False,
#           False, datetime.date(2022, 11, 10), datetime.date(2022, 12, 9),
#           0, datetime.date(2032, 2, 15), datetime.date(2022, 12, 9),
#           datetime.date(2022, 12, 9), NaT, 'I', 60129.0, '848627HD0'],
#          [Timestamp('2022-11-08 15:11:52'),
#           Timestamp('2100-01-01 00:00:00'), 2022110813561800,
#           Timestamp('2022-11-08 15:11:39'),
#           Timestamp('2022-11-08 15:11:52'), 0.25, 100.369,
#           Decimal('25000.000000000'), 'D', False, False, None, True, False,
#           datetime.date(2022, 11, 10), datetime.date(2022, 12, 9), 0,
#           datetime.date(2032, 2, 15), datetime.date(2022, 12, 9),
#           datetime.date(2022, 12, 9), NaT, 'I', 60020.0, '848627HD0'],
#          [Timestamp('2022-09-12 09:05:34'),
#           Timestamp('2100-01-01 00:00:00'), 2022091200443200,
#           Timestamp('2022-09-12 09:04:14'),
#           Timestamp('2022-09-12 09:05:34'), 2.953, 100.154,
#           Decimal('15000.000000000'), 'S', False, False, None, False,
#           False, datetime.date(2022, 9, 14), datetime.date(2022, 10, 13),
#           0, datetime.date(2032, 2, 15), datetime.date(2022, 10, 13),
#           datetime.date(2022, 10, 13), NaT, 'I', 1562.0, '848627HD0'],
#          [Timestamp('2022-09-09 12:50:30'),
#           Timestamp('2100-01-01 00:00:00'), 2022090905501200,
#           Timestamp('2022-09-09 12:49:43'),
#           Timestamp('2022-09-09 12:50:30'), 5.084, 99.375,
#           Decimal('15000.000000000'), 'P', False, False, None, False,
#           False, datetime.date(2022, 9, 13), datetime.date(2032, 2, 15), 2,
#           datetime.date(2032, 2, 15), datetime.date(2022, 10, 10),
#           datetime.date(2022, 10, 10), NaT, 'I', 24435.0, '848627HD0']],
#         dtype=object)),
#  ('625701_3_5',
#   array([[Timestamp('2024-02-26 13:14:18'),
#           Timestamp('2100-01-01 00:00:00'), 2024022606256200,
#           Timestamp('2024-02-26 13:13:46'),
#           Timestamp('2024-02-26 13:14:18'), 4.826, 100.055, 20000.0, 'D',
#           False, False, 'P', False, False, datetime.date(2024, 2, 28),
#           datetime.date(2024, 3, 28), 0, datetime.date(2043, 5, 15),
#           datetime.date(2024, 3, 28), datetime.date(2024, 3, 28), NaT, 'I',
#           27483, '16876QBG3'],
#          [Timestamp('2024-02-26 13:14:18'),
#           Timestamp('2100-01-01 00:00:00'), 2024022606255900,
#           Timestamp('2024-02-26 13:13:46'),
#           Timestamp('2024-02-26 13:14:18'), 4.826, 100.055, 20000.0, 'D',
#           False, False, None, False, False, datetime.date(2024, 2, 28),
#           datetime.date(2024, 3, 28), 0, datetime.date(2043, 5, 15),
#           datetime.date(2024, 3, 28), datetime.date(2024, 3, 28), NaT, 'I',
#           27482, '16876QBG3'],
#          [Timestamp('2024-02-26 13:14:18'),
#           Timestamp('2100-01-01 00:00:00'), 2024022606255700,
#           Timestamp('2024-02-26 13:13:46'),
#           Timestamp('2024-02-26 13:14:18'), 5.628, 99.955, 20000.0, 'P',
#           False, False, None, False, False, datetime.date(2024, 2, 28),
#           datetime.date(2043, 5, 15), 2, datetime.date(2043, 5, 15),
#           datetime.date(2024, 3, 28), datetime.date(2024, 3, 28), NaT, 'I',
#           27481, '16876QBG3'],
#          [Timestamp('2024-02-23 11:48:57'),
#           Timestamp('2100-01-01 00:00:00'), 2024022304399800,
#           Timestamp('2024-02-22 11:46:00'),
#           Timestamp('2024-02-23 11:48:57'), 5.548, 99.5, 15000.0, 'S',
#           True, False, None, False, False, datetime.date(2024, 2, 23),
#           datetime.date(2039, 5, 15), 2, datetime.date(2039, 5, 15),
#           datetime.date(2024, 3, 25), datetime.date(2024, 3, 25), NaT, 'I',
#           19087, '16876QBF5'],
#          [Timestamp('2024-02-23 11:48:23'),
#           Timestamp('2100-01-01 00:00:00'), 2024022304383600,
#           Timestamp('2024-02-22 11:46:00'),
#           Timestamp('2024-02-23 11:48:23'), 5.548, 99.5, 15000.0, 'P',
#           True, False, None, False, False, datetime.date(2024, 2, 23),
#           datetime.date(2039, 5, 15), 2, datetime.date(2039, 5, 15),
#           datetime.date(2024, 3, 25), datetime.date(2024, 3, 25), NaT, 'I',
#           19016, '16876QBF5'],
#          [Timestamp('2024-02-13 14:17:56'),
#           Timestamp('2100-01-01 00:00:00'), 2024021307487500,
#           Timestamp('2024-02-13 14:17:21'),
#           Timestamp('2024-02-13 14:17:56'), 5.377, 100.0, 15000.0, 'P',
#           False, False, None, False, False, datetime.date(2024, 2, 14),
#           datetime.date(2024, 3, 15), 0, datetime.date(2039, 5, 15),
#           datetime.date(2024, 3, 15), datetime.date(2024, 3, 15), NaT, 'I',
#           33070, '16876QBF5'],
#          [Timestamp('2024-02-13 14:12:36'),
#           Timestamp('2100-01-01 00:00:00'), 2024021307378400,
#           Timestamp('2024-02-13 14:12:05'),
#           Timestamp('2024-02-13 14:12:36'), 5.377, 100.0, 25000.0, 'P',
#           False, False, None, False, False, datetime.date(2024, 2, 14),
#           datetime.date(2024, 3, 15), 0, datetime.date(2039, 5, 15),
#           datetime.date(2024, 3, 15), datetime.date(2024, 3, 15), NaT, 'I',
#           32562, '16876QBF5'],
#          [Timestamp('2024-02-09 09:47:55'),
#           Timestamp('2100-01-01 00:00:00'), 2024020901033200,
#           Timestamp('2024-02-09 09:47:42'),
#           Timestamp('2024-02-09 09:47:55'), 2.112, 100.25, 10000.0, 'S',
#           False, False, None, False, False, datetime.date(2024, 2, 13),
#           datetime.date(2024, 3, 11), 0, datetime.date(2039, 5, 15),
#           datetime.date(2024, 3, 11), datetime.date(2024, 3, 11), NaT, 'I',
#           4216, '16876QBF5'],
#          [Timestamp('2024-02-08 11:10:52'),
#           Timestamp('2100-01-01 00:00:00'), 2024020803359100,
#           Timestamp('2024-02-08 11:09:46'),
#           Timestamp('2024-02-08 11:10:52'), 5.548, 99.5, 10000.0, 'P',
#           True, False, None, False, False, datetime.date(2024, 2, 12),
#           datetime.date(2039, 5, 15), 2, datetime.date(2039, 5, 15),
#           datetime.date(2024, 3, 10), datetime.date(2024, 3, 10), NaT, 'I',
#           14727, '16876QBF5'],
#          [Timestamp('2024-02-08 11:10:20'),
#           Timestamp('2100-01-01 00:00:00'), 2024020803352200,
#           Timestamp('2024-02-08 11:09:08'),
#           Timestamp('2024-02-08 11:10:20'), 5.548, 99.5, 10000.0, 'D',
#           False, False, None, False, False, datetime.date(2024, 2, 12),
#           datetime.date(2039, 5, 15), 2, datetime.date(2039, 5, 15),
#           datetime.date(2024, 3, 10), datetime.date(2024, 3, 10), NaT, 'I',
#           14695, '16876QBF5'],
#          [Timestamp('2024-02-02 13:36:09'),
#           Timestamp('2100-01-01 00:00:00'), 2024020206945100.0,
#           Timestamp('2024-02-02 13:35:37'),
#           Timestamp('2024-02-02 13:36:09'), 5.573, 99.25, 35000.0, 'D',
#           False, False, None, False, False, datetime.date(2024, 2, 6),
#           datetime.date(2039, 5, 15), 2, datetime.date(2039, 5, 15),
#           datetime.date(2024, 3, 4), datetime.date(2024, 3, 4), NaT, 'I',
#           30148, '16876QBF5'],
#          [Timestamp('2024-02-02 13:35:55'),
#           Timestamp('2100-01-01 00:00:00'), 2024020206937200.0,
#           Timestamp('2024-02-02 13:35:37'),
#           Timestamp('2024-02-02 13:35:55'), 5.573, 99.25, 35000.0, 'P',
#           True, False, None, False, False, datetime.date(2024, 2, 6),
#           datetime.date(2039, 5, 15), 2, datetime.date(2039, 5, 15),
#           datetime.date(2024, 3, 4), datetime.date(2024, 3, 4), NaT, 'I',
#           30099, '16876QBF5'],
#          [Timestamp('2024-01-31 11:34:31'),
#           Timestamp('2100-01-01 00:00:00'), 2024013104022000,
#           Timestamp('2024-01-31 11:34:20'),
#           Timestamp('2024-01-31 11:34:31'), 5.573, 99.25, 30000.0, 'P',
#           False, False, None, False, False, datetime.date(2024, 2, 2),
#           datetime.date(2039, 5, 15), 2, datetime.date(2039, 5, 15),
#           datetime.date(2024, 3, 2), datetime.date(2024, 3, 2), NaT, 'I',
#           17534, '16876QBF5'],
#          [Timestamp('2024-01-26 12:30:00'),
#           Timestamp('2100-01-01 00:00:00'), 2024012605370400,
#           Timestamp('2024-01-26 12:29:30'),
#           Timestamp('2024-01-26 12:30:00'), 1.972, 100.25, 35000.0, 'P',
#           False, False, None, False, False, datetime.date(2024, 1, 30),
#           datetime.date(2024, 2, 26), 0, datetime.date(2043, 5, 15),
#           datetime.date(2024, 2, 26), datetime.date(2024, 2, 26), NaT, 'I',
#           23850, '16876QBG3'],
#          [Timestamp('2024-01-26 12:29:28'),
#           Timestamp('2100-01-01 00:00:00'), 2024012605357700,
#           Timestamp('2024-01-26 12:29:00'),
#           Timestamp('2024-01-26 12:29:28'), 1.852, 100.25, 25000.0, 'P',
#           False, False, None, False, False, datetime.date(2024, 1, 30),
#           datetime.date(2024, 2, 26), 0, datetime.date(2039, 5, 15),
#           datetime.date(2024, 2, 26), datetime.date(2024, 2, 26), NaT, 'I',
#           23790, '16876QBF5'],
#          [Timestamp('2024-01-23 12:26:10'),
#           Timestamp('2100-01-01 00:00:00'), 2024012305275400,
#           Timestamp('2024-01-23 12:26:01'),
#           Timestamp('2024-01-23 12:26:10'), 5.638, 99.835, 15000.0, 'S',
#           False, False, None, False, False, datetime.date(2024, 1, 24),
#           datetime.date(2043, 5, 15), 2, datetime.date(2043, 5, 15),
#           datetime.date(2024, 2, 23), datetime.date(2024, 2, 23), NaT, 'I',
#           22881, '16876QBG3'],
#          [Timestamp('2024-01-23 12:21:48'),
#           Timestamp('2100-01-01 00:00:00'), 2024012305157000,
#           Timestamp('2024-01-23 12:21:35'),
#           Timestamp('2024-01-23 12:21:48'), 5.65, 99.7, 15000.0, 'P', True,
#           False, None, False, False, datetime.date(2024, 1, 24),
#           datetime.date(2043, 5, 15), 2, datetime.date(2043, 5, 15),
#           datetime.date(2024, 2, 23), datetime.date(2024, 2, 23), NaT, 'I',
#           22403, '16876QBG3'],
#          [Timestamp('2024-01-08 10:34:30'),
#           Timestamp('2100-01-01 00:00:00'), 2024010802041600,
#           Timestamp('2024-01-08 10:34:17'),
#           Timestamp('2024-01-08 10:34:30'), 2.112, 100.25, 25000.0, 'D',
#           False, False, None, True, False, datetime.date(2024, 1, 10),
#           datetime.date(2024, 2, 8), 0, datetime.date(2039, 5, 15),
#           datetime.date(2024, 2, 8), datetime.date(2024, 2, 8), NaT, 'I',
#           8782, '16876QBF5'],
#          [Timestamp('2024-01-08 10:34:25'),
#           Timestamp('2100-01-01 00:00:00'), 2024010802041500,
#           Timestamp('2024-01-08 10:34:17'),
#           Timestamp('2024-01-08 10:34:25'), 3.415, 100.15, 25000.0, 'P',
#           False, False, None, False, False, datetime.date(2024, 1, 10),
#           datetime.date(2024, 2, 8), 0, datetime.date(2039, 5, 15),
#           datetime.date(2024, 2, 8), datetime.date(2024, 2, 8), NaT, 'I',
#           8780, '16876QBF5'],
#          [Timestamp('2024-01-05 11:36:08'),
#           Timestamp('2100-01-01 00:00:00'), 2024010503487400,
#           Timestamp('2024-01-05 11:32:10'),
#           Timestamp('2024-01-05 11:36:08'), 5.373, 100.0, 20000.0, 'D',
#           False, False, None, True, False, datetime.date(2024, 1, 9),
#           datetime.date(2024, 2, 5), 0, datetime.date(2039, 5, 15),
#           datetime.date(2024, 2, 5), datetime.date(2024, 2, 5), NaT, 'I',
#           15292, '16876QBF5'],
#          [Timestamp('2024-01-05 11:36:08'),
#           Timestamp('2100-01-01 00:00:00'), 2024010503576700,
#           Timestamp('2024-01-05 11:32:10'),
#           Timestamp('2024-01-05 11:36:08'), 4.935, 100.031, 20000.0, 'S',
#           False, False, None, False, False, datetime.date(2024, 1, 9),
#           datetime.date(2024, 2, 5), 0, datetime.date(2039, 5, 15),
#           datetime.date(2024, 2, 5), datetime.date(2024, 2, 5), NaT, 'I',
#           15291, '16876QBF5'],
#          [Timestamp('2024-01-05 11:33:12'),
#           Timestamp('2100-01-01 00:00:00'), 2024010503487300,
#           Timestamp('2024-01-05 11:32:10'),
#           Timestamp('2024-01-05 11:33:12'), 5.509, 99.9, 20000.0, 'P',
#           False, False, None, False, False, datetime.date(2024, 1, 9),
#           datetime.date(2039, 5, 15), 2, datetime.date(2039, 5, 15),
#           datetime.date(2024, 2, 5), datetime.date(2024, 2, 5), NaT, 'I',
#           14850, '16876QBF5'],
#          [Timestamp('2024-01-04 15:11:37'),
#           Timestamp('2100-01-01 00:00:00'), 2024010410532400,
#           Timestamp('2024-01-04 15:11:18'),
#           Timestamp('2024-01-04 15:11:37'), 5.373, 100.0, 85000.0, 'P',
#           False, False, None, False, False, datetime.date(2024, 1, 8),
#           datetime.date(2024, 2, 4), 0, datetime.date(2039, 5, 15),
#           datetime.date(2024, 2, 4), datetime.date(2024, 2, 4), NaT, 'I',
#           47316, '16876QBF5'],
#          [Timestamp('2024-01-04 12:41:46'),
#           Timestamp('2100-01-01 00:00:00'), 2024010406483700,
#           Timestamp('2024-01-04 12:41:22'),
#           Timestamp('2024-01-04 12:41:46'), 1.972, 100.25, 55000.0, 'P',
#           False, False, None, False, False, datetime.date(2024, 1, 8),
#           datetime.date(2024, 2, 4), 0, datetime.date(2043, 5, 15),
#           datetime.date(2024, 2, 4), datetime.date(2024, 2, 4), NaT, 'I',
#           28485, '16876QBG3'],
#          [Timestamp('2024-01-04 12:41:46'),
#           Timestamp('2100-01-01 00:00:00'), 2024010406483600,
#           Timestamp('2024-01-04 12:41:10'),
#           Timestamp('2024-01-04 12:41:46'), 1.972, 100.25, 50000.0, 'P',
#           False, False, None, False, False, datetime.date(2024, 1, 8),
#           datetime.date(2024, 2, 4), 0, datetime.date(2043, 5, 15),
#           datetime.date(2024, 2, 4), datetime.date(2024, 2, 4), NaT, 'I',
#           28484, '16876QBG3'],
#          [Timestamp('2024-01-04 12:41:13'),
#           Timestamp('2100-01-01 00:00:00'), 2024010406445600,
#           Timestamp('2024-01-04 12:40:37'),
#           Timestamp('2024-01-04 12:41:13'), 5.373, 100.0, 20000.0, 'P',
#           False, False, None, False, False, datetime.date(2024, 1, 8),
#           datetime.date(2024, 2, 4), 0, datetime.date(2039, 5, 15),
#           datetime.date(2024, 2, 4), datetime.date(2024, 2, 4), NaT, 'I',
#           28193, '16876QBF5'],
#          [Timestamp('2024-01-04 12:40:42'),
#           Timestamp('2100-01-01 00:00:00'), 2024010406419300,
#           Timestamp('2024-01-04 12:40:22'),
#           Timestamp('2024-01-04 12:40:42'), 5.373, 100.0, 20000.0, 'P',
#           False, False, None, False, False, datetime.date(2024, 1, 8),
#           datetime.date(2024, 2, 4), 0, datetime.date(2039, 5, 15),
#           datetime.date(2024, 2, 4), datetime.date(2024, 2, 4), NaT, 'I',
#           28019, '16876QBF5'],
#          [Timestamp('2024-01-02 12:31:34'),
#           Timestamp('2100-01-01 00:00:00'), 2024010205288900,
#           Timestamp('2024-01-02 12:27:37'),
#           Timestamp('2024-01-02 12:31:34'), 5.671, 98.25, 20000.0, 'P',
#           False, False, None, False, False, datetime.date(2024, 1, 4),
#           datetime.date(2039, 5, 15), 2, datetime.date(2039, 5, 15),
#           datetime.date(2024, 2, 2), datetime.date(2024, 2, 2), NaT, 'I',
#           23479, '16876QBF5'],
#          [Timestamp('2024-01-02 12:30:00'),
#           Timestamp('2100-01-01 00:00:00'), 2024010205243600,
#           Timestamp('2024-01-02 12:27:37'),
#           Timestamp('2024-01-02 12:30:00'), 2.112, 100.25, 20000.0, 'D',
#           False, False, None, True, False, datetime.date(2024, 1, 4),
#           datetime.date(2024, 2, 2), 0, datetime.date(2039, 5, 15),
#           datetime.date(2024, 2, 2), datetime.date(2024, 2, 2), NaT, 'I',
#           23298, '16876QBF5'],
#          [Timestamp('2024-01-02 12:27:55'),
#           Timestamp('2100-01-01 00:00:00'), 2024010205175200,
#           Timestamp('2024-01-02 12:23:11'),
#           Timestamp('2024-01-02 12:27:55'), 5.776, 98.25, 20000.0, 'P',
#           False, False, None, False, False, datetime.date(2024, 1, 4),
#           datetime.date(2043, 5, 15), 2, datetime.date(2043, 5, 15),
#           datetime.date(2024, 2, 2), datetime.date(2024, 2, 2), NaT, 'I',
#           23020, '16876QBG3'],
#          [Timestamp('2024-01-02 12:26:17'),
#           Timestamp('2100-01-01 00:00:00'), 2024010205130600,
#           Timestamp('2024-01-02 12:23:11'),
#           Timestamp('2024-01-02 12:26:17'), 2.233, 100.25, 20000.0, 'D',
#           False, False, None, True, False, datetime.date(2024, 1, 4),
#           datetime.date(2024, 2, 2), 0, datetime.date(2043, 5, 15),
#           datetime.date(2024, 2, 2), datetime.date(2024, 2, 2), NaT, 'I',
#           22838, '16876QBG3'],
#          [Timestamp('2023-12-06 14:52:04'),
#           Timestamp('2100-01-01 00:00:00'), 2023120613204500,
#           Timestamp('2023-12-06 14:51:30'),
#           Timestamp('2023-12-06 14:52:04'), 5.721, 98.875, 60000.0, 'P',
#           False, False, None, False, False, datetime.date(2023, 12, 8),
#           datetime.date(2043, 5, 15), 2, datetime.date(2043, 5, 15),
#           datetime.date(2024, 1, 6), datetime.date(2024, 1, 6), NaT, 'I',
#           57495, '16876QBG3'],
#          [Timestamp('2023-12-06 14:25:35'),
#           Timestamp('2100-01-01 00:00:00'), 2023120612192500,
#           Timestamp('2023-12-06 14:24:52'),
#           Timestamp('2023-12-06 14:25:35'), 5.689, 99.25, 80000.0, 'P',
#           False, False, None, False, False, datetime.date(2023, 12, 8),
#           datetime.date(2043, 5, 15), 2, datetime.date(2043, 5, 15),
#           datetime.date(2024, 1, 6), datetime.date(2024, 1, 6), NaT, 'I',
#           52686, '16876QBG3'],
#          [Timestamp('2023-11-30 16:07:16'),
#           Timestamp('2100-01-01 00:00:00'), 2023113015725300,
#           Timestamp('2023-11-30 16:06:06'),
#           Timestamp('2023-11-30 16:07:16'), 5.561, 99.995, 10000.0, 'S',
#           True, False, None, False, False, datetime.date(2023, 12, 4),
#           datetime.date(2023, 12, 31), 0, datetime.date(2043, 5, 15),
#           datetime.date(2023, 12, 31), datetime.date(2023, 12, 31), NaT,
#           'I', 72002, '16876QBG3'],
#          [Timestamp('2023-11-30 16:02:25'),
#           Timestamp('2100-01-01 00:00:00'), 2023113015478200,
#           Timestamp('2023-11-30 15:58:26'),
#           Timestamp('2023-11-30 16:02:25'), 5.561, 99.995, 10000.0, 'D',
#           False, False, None, True, False, datetime.date(2023, 12, 4),
#           datetime.date(2023, 12, 31), 0, datetime.date(2043, 5, 15),
#           datetime.date(2023, 12, 31), datetime.date(2023, 12, 31), NaT,
#           'I', 71495, '16876QBG3'],
#          [Timestamp('2023-11-29 15:34:19'),
#           Timestamp('2100-01-01 00:00:00'), 2023112915526500,
#           Timestamp('2023-11-29 15:34:03'),
#           Timestamp('2023-11-29 15:34:19'), 5.495, 100.0, 190000.0, 'S',
#           False, False, None, False, False, datetime.date(2023, 11, 30),
#           datetime.date(2023, 12, 30), 0, datetime.date(2043, 5, 15),
#           datetime.date(2023, 12, 30), datetime.date(2023, 12, 30), NaT,
#           'I', 71287, '16876QBG3'],
#          [Timestamp('2023-11-29 15:24:21'),
#           Timestamp('2100-01-01 00:00:00'), 2023112915196800,
#           Timestamp('2023-11-29 15:24:08'),
#           Timestamp('2023-11-29 15:24:21'), 5.793, 98.05, 85000.0, 'P',
#           False, False, None, False, False, datetime.date(2023, 11, 30),
#           datetime.date(2043, 5, 15), 2, datetime.date(2043, 5, 15),
#           datetime.date(2023, 12, 30), datetime.date(2023, 12, 30), NaT,
#           'I', 69811, '16876QBG3'],
#          [Timestamp('2023-11-29 13:52:08'),
#           Timestamp('2100-01-01 00:00:00'), 2023112911687600,
#           Timestamp('2023-11-29 13:51:51'),
#           Timestamp('2023-11-29 13:52:08'), 5.886, 97.0, 10000.0, 'D',
#           False, False, None, True, False, datetime.date(2023, 12, 1),
#           datetime.date(2043, 5, 15), 2, datetime.date(2043, 5, 15),
#           datetime.date(2023, 12, 30), datetime.date(2023, 12, 30), NaT,
#           'I', 53827, '16876QBG3'],
#          [Timestamp('2023-11-29 13:52:03'),
#           Timestamp('2100-01-01 00:00:00'), 2023112911687000,
#           Timestamp('2023-11-29 13:51:51'),
#           Timestamp('2023-11-29 13:52:03'), 5.886, 97.0, 10000.0, 'P',
#           True, False, None, False, False, datetime.date(2023, 12, 1),
#           datetime.date(2043, 5, 15), 2, datetime.date(2043, 5, 15),
#           datetime.date(2023, 12, 30), datetime.date(2023, 12, 30), NaT,
#           'I', 53800, '16876QBG3']], dtype=object)),
#  ('746450_0_5',
#   array([[Timestamp('2024-02-26 15:20:16'),
#           Timestamp('2100-01-01 00:00:00'), 2024022609428400, ..., 'I',
#           41810, '927676MY9'],
#          [Timestamp('2024-02-26 15:20:16'),
#           Timestamp('2100-01-01 00:00:00'), 2024022609428500, ..., 'I',
#           41811, '927676MY9'],
#          [Timestamp('2024-02-26 15:18:28'),
#           Timestamp('2100-01-01 00:00:00'), 2024022609395900, ..., 'I',
#           41662, '927676MZ6'],
#          ...,
#          [Timestamp('2023-12-12 10:36:32'),
#           Timestamp('2100-01-01 00:00:00'), 2023121202654300, ..., 'I',
#           11129, '927676MW3'],
#          [Timestamp('2023-12-07 13:57:16'),
#           Timestamp('2100-01-01 00:00:00'), 2023120710177700, ..., 'I',
#           45383, '927676MV5'],
#          [Timestamp('2023-12-07 13:57:16'),
#           Timestamp('2100-01-01 00:00:00'), 2023120710177300, ..., 'I',
#           45381, '927676MV5']], dtype=object)),
#  ('752411_0_5',
#   array([[Timestamp('2024-02-26 12:37:01'),
#           Timestamp('2100-01-01 00:00:00'), 2024022605028000, ..., 'I',
#           22090, '914811NS9'],
#          [Timestamp('2024-02-26 12:37:01'),
#           Timestamp('2100-01-01 00:00:00'), 2024022605027900, ..., 'I',
#           22089, '914811NS9'],
#          [Timestamp('2024-02-21 16:01:54'),
#           Timestamp('2100-01-01 00:00:00'), 2024022107279200, ..., 'I',
#           53117, '914811PP3'],
#          ...,
#          [Timestamp('2023-11-24 12:36:33'),
#           Timestamp('2100-01-01 00:00:00'), 2023112403910900, ..., 'I',
#           17538, '914811NR1'],
#          [Timestamp('2023-11-24 12:36:33'),
#           Timestamp('2100-01-01 00:00:00'), 2023112403926000, ..., 'I',
#           17537, '914811NR1'],
#          [Timestamp('2023-11-21 14:47:15'),
#           Timestamp('2100-01-01 00:00:00'), 2023112112465200, ..., 'I',
#           57221, '914811PX6']], dtype=object)),
#  ('779986_0_5',
#   array([[Timestamp('2024-02-07 10:47:41'),
#           Timestamp('2100-01-01 00:00:00'), 2024020702399200,
#           Timestamp('2024-02-07 10:44:53'),
#           Timestamp('2024-02-07 10:47:41'), 4.518, 100.049, 80000.0, 'P',
#           False, False, None, False, False, datetime.date(2024, 2, 9),
#           datetime.date(2024, 3, 8), 0, datetime.date(2027, 12, 1),
#           datetime.date(2024, 3, 8), datetime.date(2024, 3, 8), NaT, 'I',
#           10920, '674140KV9'],
#          [Timestamp('2024-02-07 10:47:35'),
#           Timestamp('2100-01-01 00:00:00'), 2024020702398600,
#           Timestamp('2024-02-07 10:44:53'),
#           Timestamp('2024-02-07 10:47:35'), 3.383, 100.139, 80000.0, 'D',
#           False, False, None, True, False, datetime.date(2024, 2, 9),
#           datetime.date(2024, 3, 8), 0, datetime.date(2027, 12, 1),
#           datetime.date(2024, 3, 8), datetime.date(2024, 3, 8), NaT, 'I',
#           10918, '674140KV9']], dtype=object)),
#  ('865275_1_5', array([], shape=(0, 24), dtype=object)),
#  ('875741_2_4',
#   array([[Timestamp('2024-02-22 11:16:33'),
#           Timestamp('2100-01-01 00:00:00'), 2024022203523200,
#           Timestamp('2024-02-22 11:15:44'),
#           Timestamp('2024-02-22 11:16:33'), 0.488, 100.33, 70000.0, 'D',
#           False, False, None, True, False, datetime.date(2024, 2, 26),
#           datetime.date(2024, 3, 24), 0, datetime.date(2035, 7, 1),
#           datetime.date(2024, 3, 24), datetime.date(2024, 3, 24), NaT, 'I',
#           16078, '59334KFU7'],
#          [Timestamp('2024-02-22 11:16:33'),
#           Timestamp('2100-01-01 00:00:00'), 2024022203502300,
#           Timestamp('2024-02-22 11:15:44'),
#           Timestamp('2024-02-22 11:16:33'), 2.118, 100.205, 70000.0, 'D',
#           False, False, None, True, False, datetime.date(2024, 2, 26),
#           datetime.date(2024, 3, 24), 0, datetime.date(2035, 7, 1),
#           datetime.date(2024, 3, 24), datetime.date(2024, 3, 24), NaT, 'I',
#           16076, '59334KFU7'],
#          [Timestamp('2024-02-22 11:15:58'),
#           Timestamp('2100-01-01 00:00:00'), 2024022203502700,
#           Timestamp('2024-02-22 11:15:44'),
#           Timestamp('2024-02-22 11:15:58'), 2.967, 100.14, 70000.0, 'D',
#           False, False, None, False, False, datetime.date(2024, 2, 26),
#           datetime.date(2024, 3, 24), 0, datetime.date(2035, 7, 1),
#           datetime.date(2024, 3, 24), datetime.date(2024, 3, 24), NaT, 'I',
#           15956, '59334KFU7'],
#          [Timestamp('2024-02-22 11:15:58'),
#           Timestamp('2100-01-01 00:00:00'), 2024022203502600,
#           Timestamp('2024-02-22 11:15:44'),
#           Timestamp('2024-02-22 11:15:58'), 4.912, 99.889, 70000.0, 'P',
#           False, False, None, False, False, datetime.date(2024, 2, 26),
#           datetime.date(2035, 7, 1), 2, datetime.date(2035, 7, 1),
#           datetime.date(2024, 3, 24), datetime.date(2024, 3, 24), NaT, 'I',
#           15954, '59334KFU7'],
#          [Timestamp('2023-12-19 13:22:35'),
#           Timestamp('2100-01-01 00:00:00'), 2023121909301500,
#           Timestamp('2023-12-19 13:22:26'),
#           Timestamp('2023-12-19 13:22:35'), 4.499, 100.023, 195000.0, 'S',
#           False, False, None, False, False, datetime.date(2023, 12, 21),
#           datetime.date(2024, 1, 19), 0, datetime.date(2035, 7, 1),
#           datetime.date(2024, 1, 19), datetime.date(2024, 1, 19), NaT, 'I',
#           41846, '59334KFU7'],
#          [Timestamp('2023-12-19 13:17:10'),
#           Timestamp('2100-01-01 00:00:00'), 2023121909115900,
#           Timestamp('2023-12-19 13:16:21'),
#           Timestamp('2023-12-19 13:17:10'), 4.909, 99.923, 195000.0, 'D',
#           False, False, 'P', False, False, datetime.date(2023, 12, 21),
#           datetime.date(2035, 7, 1), 2, datetime.date(2035, 7, 1),
#           datetime.date(2024, 1, 19), datetime.date(2024, 1, 19), NaT, 'I',
#           41143, '59334KFU7'],
#          [Timestamp('2023-12-19 13:16:19'),
#           Timestamp('2100-01-01 00:00:00'), 2023121909116600,
#           Timestamp('2023-12-19 13:15:13'),
#           Timestamp('2023-12-19 13:16:19'), 4.923, 99.798, 10000.0, 'P',
#           False, False, None, False, False, datetime.date(2023, 12, 21),
#           datetime.date(2035, 7, 1), 2, datetime.date(2035, 7, 1),
#           datetime.date(2024, 1, 19), datetime.date(2024, 1, 19), NaT, 'I',
#           41014, '59334KFU7'],
#          [Timestamp('2023-12-19 13:16:19'),
#           Timestamp('2100-01-01 00:00:00'), 2023121909116500,
#           Timestamp('2023-12-19 13:15:13'),
#           Timestamp('2023-12-19 13:16:19'), 4.923, 99.798, 20000.0, 'P',
#           False, False, None, False, False, datetime.date(2023, 12, 21),
#           datetime.date(2035, 7, 1), 2, datetime.date(2035, 7, 1),
#           datetime.date(2024, 1, 19), datetime.date(2024, 1, 19), NaT, 'I',
#           41013, '59334KFU7'],
#          [Timestamp('2023-12-19 13:16:19'),
#           Timestamp('2100-01-01 00:00:00'), 2023121909116400,
#           Timestamp('2023-12-19 13:15:12'),
#           Timestamp('2023-12-19 13:16:19'), 4.923, 99.798, 25000.0, 'P',
#           False, False, None, False, False, datetime.date(2023, 12, 21),
#           datetime.date(2035, 7, 1), 2, datetime.date(2035, 7, 1),
#           datetime.date(2024, 1, 19), datetime.date(2024, 1, 19), NaT, 'I',
#           41012, '59334KFU7'],
#          [Timestamp('2023-12-19 13:16:19'),
#           Timestamp('2100-01-01 00:00:00'), 2023121909116300,
#           Timestamp('2023-12-19 13:15:12'),
#           Timestamp('2023-12-19 13:16:19'), 4.923, 99.798, 15000.0, 'P',
#           False, False, None, False, False, datetime.date(2023, 12, 21),
#           datetime.date(2035, 7, 1), 2, datetime.date(2035, 7, 1),
#           datetime.date(2024, 1, 19), datetime.date(2024, 1, 19), NaT, 'I',
#           41011, '59334KFU7'],
#          [Timestamp('2023-12-19 13:16:19'),
#           Timestamp('2100-01-01 00:00:00'), 2023121909116200,
#           Timestamp('2023-12-19 13:15:12'),
#           Timestamp('2023-12-19 13:16:19'), 4.923, 99.798, 40000.0, 'P',
#           False, False, None, False, False, datetime.date(2023, 12, 21),
#           datetime.date(2035, 7, 1), 2, datetime.date(2035, 7, 1),
#           datetime.date(2024, 1, 19), datetime.date(2024, 1, 19), NaT, 'I',
#           41010, '59334KFU7'],
# ...
#           datetime.date(2024, 3, 7), datetime.date(2024, 3, 7), NaT, 'I',
#           48645, '593237FR6'],
#          [Timestamp('2024-02-05 16:04:29'),
#           Timestamp('2100-01-01 00:00:00'), 2024020510881200.0,
#           Timestamp('2024-02-05 16:04:00'),
#           Timestamp('2024-02-05 16:04:29'), 5.016, 99.8, 25000.0, 'D',
#           False, False, None, False, False, datetime.date(2024, 2, 7),
#           datetime.date(2044, 2, 1), 2, datetime.date(2044, 2, 1),
#           datetime.date(2024, 3, 7), datetime.date(2024, 3, 7), NaT, 'I',
#           48653, '593237FR6'],
#          [Timestamp('2024-02-05 14:41:31'),
#           Timestamp('2100-01-01 00:00:00'), 2024020508800300.0,
#           Timestamp('2024-02-05 14:41:17'),
#           Timestamp('2024-02-05 14:41:31'), 5.032, 99.6, 25000.0, 'D',
#           False, False, None, False, False, datetime.date(2024, 2, 7),
#           datetime.date(2044, 2, 1), 2, datetime.date(2044, 2, 1),
#           datetime.date(2024, 3, 7), datetime.date(2024, 3, 7), NaT, 'I',
#           39797, '593237FR6'],
#          [Timestamp('2024-02-05 14:41:31'),
#           Timestamp('2100-01-01 00:00:00'), 2024020508800200.0,
#           Timestamp('2024-02-05 14:41:17'),
#           Timestamp('2024-02-05 14:41:31'), 5.072, 99.103, 25000.0, 'P',
#           False, False, None, False, False, datetime.date(2024, 2, 7),
#           datetime.date(2044, 2, 1), 2, datetime.date(2044, 2, 1),
#           datetime.date(2024, 3, 7), datetime.date(2024, 3, 7), NaT, 'I',
#           39793, '593237FR6'],
#          [Timestamp('2024-02-02 10:05:17'),
#           Timestamp('2100-01-01 00:00:00'), 2024020201223300.0,
#           Timestamp('2024-02-02 10:04:36'),
#           Timestamp('2024-02-02 10:05:17'), 3.875, 100.078, 25000.0, 'D',
#           False, False, None, False, False, datetime.date(2024, 2, 6),
#           datetime.date(2024, 3, 4), 0, datetime.date(2044, 2, 1),
#           datetime.date(2024, 3, 4), datetime.date(2024, 3, 4), NaT, 'I',
#           4861, '593237FR6'],
#          [Timestamp('2024-02-02 10:05:17'),
#           Timestamp('2100-01-01 00:00:00'), 2024020201229300.0,
#           Timestamp('2024-02-02 10:04:36'),
#           Timestamp('2024-02-02 10:05:17'), 3.875, 100.078, 25000.0, 'S',
#           True, False, None, False, False, datetime.date(2024, 2, 6),
#           datetime.date(2024, 3, 4), 0, datetime.date(2044, 2, 1),
#           datetime.date(2024, 3, 4), datetime.date(2024, 3, 4), NaT, 'I',
#           4860, '593237FR6'],
#          [Timestamp('2024-02-01 15:00:35'),
#           Timestamp('2100-01-01 00:00:00'), 2024020110549300.0,
#           Timestamp('2024-02-01 15:00:27'),
#           Timestamp('2024-02-01 15:00:35'), 5.021, 99.74, 25000.0, 'D',
#           False, False, None, False, False, datetime.date(2024, 2, 5),
#           datetime.date(2044, 2, 1), 2, datetime.date(2044, 2, 1),
#           datetime.date(2024, 3, 3), datetime.date(2024, 3, 3), NaT, 'I',
#           45370, '593237FR6'],
#          [Timestamp('2024-02-01 15:00:35'),
#           Timestamp('2100-01-01 00:00:00'), 2024020110549200.0,
#           Timestamp('2024-02-01 15:00:27'),
#           Timestamp('2024-02-01 15:00:35'), 5.053, 99.34, 25000.0, 'P',
#           False, False, None, False, False, datetime.date(2024, 2, 5),
#           datetime.date(2044, 2, 1), 2, datetime.date(2044, 2, 1),
#           datetime.date(2024, 3, 3), datetime.date(2024, 3, 3), NaT, 'I',
#           45366, '593237FR6'],
#          [Timestamp('2024-02-01 15:00:39'),
#           Timestamp('2100-01-01 00:00:00'), 2024020110550800.0,
#           Timestamp('2024-02-01 15:00:00'),
#           Timestamp('2024-02-01 15:00:39'), 5.021, 99.74, 25000.0, 'D',
#           False, False, None, True, False, datetime.date(2024, 2, 5),
#           datetime.date(2044, 2, 1), 2, datetime.date(2044, 2, 1),
#           datetime.date(2024, 3, 3), datetime.date(2024, 3, 3), NaT, 'I',
#           45388, '593237FR6'],
#          [Timestamp('2024-01-22 16:11:55'),
#           Timestamp('2100-01-01 00:00:00'), 2024012210728500,
#           Timestamp('2024-01-22 16:11:00'),
#           Timestamp('2024-01-22 16:11:55'), 0.976, 100.3, 25000.0, 'D',
#           False, False, None, False, False, datetime.date(2024, 1, 24),
#           datetime.date(2024, 2, 22), 0, datetime.date(2044, 2, 1),
#           datetime.date(2024, 2, 22), datetime.date(2024, 2, 22), NaT, 'I',
#           47939, '593237FR6'],
#          [Timestamp('2024-01-22 10:32:55'),
#           Timestamp('2100-01-01 00:00:00'), 2024012201924900,
#           Timestamp('2024-01-22 10:32:27'),
#           Timestamp('2024-01-22 10:32:55'), 2.74, 100.177, 25000.0, 'D',
#           False, False, None, True, False, datetime.date(2024, 1, 22),
#           datetime.date(2024, 2, 22), 0, datetime.date(2044, 2, 1),
#           datetime.date(2024, 2, 22), datetime.date(2024, 2, 22), NaT, 'I',
#           7982, '593237FR6'],
#          [Timestamp('2024-01-22 10:32:54'),
#           Timestamp('2100-01-01 00:00:00'), 2024012201923300,
#           Timestamp('2024-01-22 10:32:27'),
#           Timestamp('2024-01-22 10:32:54'), 2.74, 100.177, 25000.0, 'D',
#           False, False, None, False, False, datetime.date(2024, 1, 22),
#           datetime.date(2024, 2, 22), 0, datetime.date(2044, 2, 1),
#           datetime.date(2024, 2, 22), datetime.date(2024, 2, 22), NaT, 'I',
#           7977, '593237FR6'],
#          [Timestamp('2024-01-22 10:32:54'),
#           Timestamp('2100-01-01 00:00:00'), 2024012201923200,
#           Timestamp('2024-01-22 10:32:27'),
#           Timestamp('2024-01-22 10:32:54'), 2.74, 100.177, 25000.0, 'P',
#           True, False, None, False, False, datetime.date(2024, 1, 22),
#           datetime.date(2024, 2, 22), 0, datetime.date(2044, 2, 1),
#           datetime.date(2024, 2, 22), datetime.date(2024, 2, 22), NaT, 'I',
#           7976, '593237FR6'],
#          [Timestamp('2024-01-08 08:46:34'),
#           Timestamp('2100-01-01 00:00:00'), 2024010800287500,
#           Timestamp('2024-01-08 08:46:22'),
#           Timestamp('2024-01-08 08:46:34'), 2.933, 100.15, 25000.0, 'S',
#           False, False, None, False, False, datetime.date(2024, 1, 10),
#           datetime.date(2024, 2, 8), 0, datetime.date(2044, 2, 1),
#           datetime.date(2024, 2, 8), datetime.date(2024, 2, 8), NaT, 'I',
#           1284, '593237FR6'],
#          [Timestamp('2024-01-05 12:34:58'),
#           Timestamp('2100-01-01 00:00:00'), 2024010505349500,
#           Timestamp('2024-01-05 12:32:39'),
#           Timestamp('2024-01-05 12:34:58'), 5.05, 99.37, 25000.0, 'P',
#           False, False, None, False, False, datetime.date(2024, 1, 9),
#           datetime.date(2044, 2, 1), 2, datetime.date(2044, 2, 1),
#           datetime.date(2024, 2, 5), datetime.date(2024, 2, 5), NaT, 'I',
#           23490, '593237FR6'],
#          [Timestamp('2023-12-15 08:48:11'),
#           Timestamp('2100-01-01 00:00:00'), 2023121500592000,
#           Timestamp('2023-12-15 08:45:54'),
#           Timestamp('2023-12-15 08:48:11'), 3.251, 100.196, 45000.0, 'D',
#           False, False, None, True, False, datetime.date(2023, 12, 19),
#           datetime.date(2024, 2, 1), 0, datetime.date(2044, 2, 1),
#           datetime.date(2024, 2, 1), datetime.date(2024, 2, 1), NaT, 'I',
#           2712, '593237FR6'],
#          [Timestamp('2023-12-15 08:46:45'),
#           Timestamp('2100-01-01 00:00:00'), 2023121500541300,
#           Timestamp('2023-12-15 08:45:54'),
#           Timestamp('2023-12-15 08:46:45'), 3.251, 100.196, 45000.0, 'D',
#           False, False, None, False, False, datetime.date(2023, 12, 19),
#           datetime.date(2024, 2, 1), 0, datetime.date(2044, 2, 1),
#           datetime.date(2024, 2, 1), datetime.date(2024, 2, 1), NaT, 'I',
#           2505, '593237FR6'],
#          [Timestamp('2023-12-15 08:46:45'),
#           Timestamp('2100-01-01 00:00:00'), 2023121500541100,
#           Timestamp('2023-12-15 08:45:54'),
#           Timestamp('2023-12-15 08:46:45'), 2.41, 100.296, 45000.0, 'S',
#           False, False, None, False, False, datetime.date(2023, 12, 19),
#           datetime.date(2024, 2, 1), 0, datetime.date(2044, 2, 1),
#           datetime.date(2024, 2, 1), datetime.date(2024, 2, 1), NaT, 'I',
#           2504, '593237FR6'],
#          [Timestamp('2023-12-07 16:00:37'),
#           Timestamp('2100-01-01 00:00:00'), 2023120714660200,
#           Timestamp('2023-12-07 15:58:35'),
#           Timestamp('2023-12-07 16:00:37'), 5.163, 97.97, 45000.0, 'P',
#           False, False, None, False, False, datetime.date(2023, 12, 8),
#           datetime.date(2044, 2, 1), 2, datetime.date(2044, 2, 1),
#           datetime.date(2024, 2, 1), datetime.date(2024, 2, 1), NaT, 'I',
#           66318, '593237FR6'],
#          [Timestamp('2023-12-04 16:59:23'),
#           Timestamp('2100-01-01 00:00:00'), 2023120416675000,
#           Timestamp('2023-12-04 16:59:04'),
#           Timestamp('2023-12-04 16:59:23'), 5.079, 99.001, 55000.0, 'P',
#           False, False, None, False, False, datetime.date(2023, 12, 6),
#           datetime.date(2044, 2, 1), 2, datetime.date(2044, 2, 1),
#           datetime.date(2024, 2, 1), datetime.date(2024, 2, 1), NaT, 'I',
#           79846, '593237FR6'],
#          [Timestamp('2023-12-04 16:59:23'),
#           Timestamp('2100-01-01 00:00:00'), 2023120416674900,
#           Timestamp('2023-12-04 16:59:04'),
#           Timestamp('2023-12-04 16:59:23'), 4.584, 100.051, 55000.0, 'S',
#           False, False, None, False, False, datetime.date(2023, 12, 6),
#           datetime.date(2024, 2, 1), 0, datetime.date(2044, 2, 1),
#           datetime.date(2024, 2, 1), datetime.date(2024, 2, 1), NaT, 'I',
#           79845, '593237FR6'],
#          [Timestamp('2023-11-17 11:16:04'),
#           Timestamp('2100-01-01 00:00:00'), 2023111705185700,
#           Timestamp('2023-11-17 11:15:51'),
#           Timestamp('2023-11-17 11:16:04'), 4.925, 100.0, 50000.0, 'S',
#           False, False, None, False, False, datetime.date(2023, 11, 21),
#           datetime.date(2024, 2, 1), 0, datetime.date(2044, 2, 1),
#           datetime.date(2024, 2, 1), datetime.date(2024, 2, 1), NaT, 'I',
#           22859, '593237FR6'],
#          [Timestamp('2023-11-16 15:40:53'),
#           Timestamp('2100-01-01 00:00:00'), 2023111617035900,
#           Timestamp('2023-11-16 15:40:34'),
#           Timestamp('2023-11-16 15:40:53'), 5.095, 98.8, 50000.0, 'P',
#           False, False, None, False, False, datetime.date(2023, 11, 20),
#           datetime.date(2044, 2, 1), 2, datetime.date(2044, 2, 1),
#           datetime.date(2024, 2, 1), datetime.date(2024, 2, 1), NaT, 'I',
#           78080, '593237FR6'],
#          [Timestamp('2023-11-16 10:28:20'),
#           Timestamp('2100-01-01 00:00:00'), 2023111603484700,
#           Timestamp('2023-11-16 10:26:41'),
#           Timestamp('2023-11-16 10:28:20'), 4.925, 100.0, 10000.0, 'D',
#           False, False, None, True, False, datetime.date(2023, 11, 20),
#           datetime.date(2024, 2, 1), 0, datetime.date(2044, 2, 1),
#           datetime.date(2024, 2, 1), datetime.date(2024, 2, 1), NaT, 'I',
#           14493, '593237FR6'],
#          [Timestamp('2023-11-16 10:26:39'),
#           Timestamp('2100-01-01 00:00:00'), 2023111603436300,
#           Timestamp('2023-11-16 10:26:32'),
#           Timestamp('2023-11-16 10:26:39'), 4.422, 100.1, 10000.0, 'S',
#           False, False, None, False, False, datetime.date(2023, 11, 20),
#           datetime.date(2024, 2, 1), 0, datetime.date(2044, 2, 1),
#           datetime.date(2024, 2, 1), datetime.date(2024, 2, 1), NaT, 'I',
#           14277, '593237FR6'],
#          [Timestamp('2023-11-16 09:21:22'),
#           Timestamp('2100-01-01 00:00:00'), 2023111601559700,
#           Timestamp('2023-11-16 09:21:13'),
#           Timestamp('2023-11-16 09:21:22'), 4.547, 100.075, 20000.0, 'S',
#           False, False, None, False, False, datetime.date(2023, 11, 20),
#           datetime.date(2024, 2, 1), 0, datetime.date(2044, 2, 1),
#           datetime.date(2024, 2, 1), datetime.date(2024, 2, 1), NaT, 'I',
#           6399, '593237FR6'],
#          [Timestamp('2023-11-16 09:21:17'),
#           Timestamp('2100-01-01 00:00:00'), 2023111601555200,
#           Timestamp('2023-11-16 09:19:34'),
#           Timestamp('2023-11-16 09:21:17'), 4.925, 100.0, 15000.0, 'D',
#           False, False, None, True, False, datetime.date(2023, 11, 20),
#           datetime.date(2024, 2, 1), 0, datetime.date(2044, 2, 1),
#           datetime.date(2024, 2, 1), datetime.date(2024, 2, 1), NaT, 'I',
#           6379, '593237FR6'],
#          [Timestamp('2023-11-15 15:58:46'),
#           Timestamp('2100-01-01 00:00:00'), 2023111517250600,
#           Timestamp('2023-11-15 15:58:32'),
#           Timestamp('2023-11-15 15:58:46'), 4.927, 100.0, 20000.0, 'S',
#           True, False, None, False, False, datetime.date(2023, 11, 17),
#           datetime.date(2024, 2, 1), 0, datetime.date(2044, 2, 1),
#           datetime.date(2024, 2, 1), datetime.date(2024, 2, 1), NaT, 'I',
#           78308, '593237FR6'],
#          [Timestamp('2023-11-15 16:00:55'),
#           Timestamp('2100-01-01 00:00:00'), 2023111517328000,
#           Timestamp('2023-11-15 15:56:35'),
#           Timestamp('2023-11-15 16:00:55'), 4.927, 100.0, 20000.0, 'D',
#           False, False, None, True, False, datetime.date(2023, 11, 17),
#           datetime.date(2024, 2, 1), 0, datetime.date(2044, 2, 1),
#           datetime.date(2024, 2, 1), datetime.date(2024, 2, 1), NaT, 'I',
#           78659, '593237FR6'],
#          [Timestamp('2023-11-15 15:45:20'),
#           Timestamp('2100-01-01 00:00:00'), 2023111516597300,
#           Timestamp('2023-11-15 15:43:35'),
#           Timestamp('2023-11-15 15:45:20'), 5.071, 99.099, 50000.0, 'D',
#           False, False, None, True, False, datetime.date(2023, 11, 17),
#           datetime.date(2044, 2, 1), 2, datetime.date(2044, 2, 1),
#           datetime.date(2024, 2, 1), datetime.date(2024, 2, 1), NaT, 'I',
#           75483, '593237FR6'],
#          [Timestamp('2023-11-15 15:43:49'),
#           Timestamp('2100-01-01 00:00:00'), 2023111516597400,
#           Timestamp('2023-11-15 15:43:35'),
#           Timestamp('2023-11-15 15:43:49'), 5.071, 99.099, 50000.0, 'P',
#           True, False, None, False, False, datetime.date(2023, 11, 17),
#           datetime.date(2044, 2, 1), 2, datetime.date(2044, 2, 1),
#           datetime.date(2024, 2, 1), datetime.date(2024, 2, 1), NaT, 'I',
#           75256, '593237FR6']], dtype=object)),
#  ('1070147_1_5',
#   array([[Timestamp('2024-02-15 14:22:12'),
#           Timestamp('2100-01-01 00:00:00'), 2024021509301300, ..., 'I',
#           40947, '047849FH2'],
#          [Timestamp('2024-02-15 14:00:07'),
#           Timestamp('2100-01-01 00:00:00'), 2024021508652900, ..., 'I',
#           37756, '047849FH2'],
#          [Timestamp('2024-01-30 15:53:11'),
#           Timestamp('2100-01-01 00:00:00'), 2024013010923300, ..., 'I',
#           49215, '047849GG3'],
#          ...,
#          [Timestamp('2023-06-20 12:01:16'),
#           Timestamp('2100-01-01 00:00:00'), 2023062004064300, ..., 'I',
#           17540.0, '047849GH1'],
#          [Timestamp('2023-06-20 12:01:15'),
#           Timestamp('2100-01-01 00:00:00'), 2023062004063300, ..., 'I',
#           17537.0, '047849GH1'],
#          [Timestamp('2023-06-16 13:43:48'),
#           Timestamp('2100-01-01 00:00:00'), 2023061606719900, ..., 'I',
#           29780.0, '047849FH2']], dtype=object)),
#  ('1209157_1_5',
#   array([[Timestamp('2024-02-26 12:46:10'),
#           Timestamp('2100-01-01 00:00:00'), 2024022605387700, ..., 'I',
#           23698, '452227SF9'],
#          [Timestamp('2024-02-22 12:42:32'),
#           Timestamp('2100-01-01 00:00:00'), 2024022206250800, ..., 'I',
#           28620, '452227TR2'],
#          [Timestamp('2024-02-22 12:42:32'),
#           Timestamp('2100-01-01 00:00:00'), 2024022206250600, ..., 'I',
#           28619, '452227TR2'],
#          ...,
#          [Timestamp('2024-01-09 14:58:40'),
#           Timestamp('2100-01-01 00:00:00'), 2024010909300200, ..., 'I',
#           41703, '452227TT8'],
#          [Timestamp('2024-01-03 11:56:45'),
#           Timestamp('2100-01-01 00:00:00'), 2024010305195100, ..., 'I',
#           22451, '452227SD4'],
#          [Timestamp('2024-01-03 10:23:00'),
#           Timestamp('2100-01-01 00:00:00'), 2024010302468100, ..., 'I',
#           10664, '452227SE2']], dtype=object))]
