# %%
import json 
import requests
import os
import subprocess
import numpy as np

# %%
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "../../eng-reactor-287421-03c9ca947790.json"

# %%
token = '{}'.format(subprocess.Popen(args="gcloud auth print-identity-token", stdout=subprocess.PIPE, shell=True).communicate()[0])[2:-3]

# %%
token = 'eyJhbGciOiJSUzI1NiIsImtpZCI6IjgxOWQxZTYxNDI5ZGQzZDNjYWVmMTI5YzBhYzJiYWU4YzZkNDZmYmMiLCJ0eXAiOiJKV1QifQ..Mjz5UdZIKQ1g5kcSZ7hzPQ39jk44dpUsN0ijXCMLdaxGZyOo-HpGbb2hRVYxoY99Kr7Irr_lZUJOzZTwZnE8nDtWzkYsVrsep5wPubcWOwAwIXwKvTP5B3l0LBAbaC7NDwWG7ZNf62HKYdSyQndGjFSv48f8C9CDQEgkRaWPs4INszxxaQsAc07JlT3whu9Q0b5QVht4UvCXhFPJABfRRKHmc4Wkv1gAwfmcMkPM8LaaVZhLEk_44hUUorNGg2E_yJKP3fHeDOi0mdE4wcd2QTYowkoWh4WTAOSL73Qz4lKJ4FimUA6I1aRa7sxwY5kM91pCQx4AMskcL68xWE3o1w'

# %%
# %%time

response = requests.get('https://us-east4-eng-reactor-287421.cloudfunctions.net/daily_yield_curve',
                       params = {"maturity":5, "target_date":"2021-08-31"})

response.json()
# Out:
# Wall time: 3.42 s
# {'error': '', 'result': 43.1953054913291, 'status': 'Success'}

# %%
# %%time

response = requests.get('https://us-east4-eng-reactor-287421.cloudfunctions.net/current_yield_curve',
                       params = {"maturity":5}, headers={"Authorization":"Bearer {}".format(token)})

response.json()
# Out:
# Wall time: 31.2 s
# {'error': '',
#  'result': 43.41013824121851,
#  'status': 'Success',
#  'timestamp': 'Thu, 02 Sep 2021 15:56:00 GMT'}

# %%
# %%time

t = np.repeat(5.5, 6000)
maturities = json.dumps(t.tolist())
print(len(t))
response = requests.get('https://us-east4-eng-reactor-287421.cloudfunctions.net/current_yield_curve_batch',
                       params = {"maturity":maturities}, headers={"Authorization":"Bearer {}".format(token)})
response.json()
# Out:
# 6000

# %%
# %%time

t = np.repeat(5.5, 1000)
maturities = json.dumps(t.tolist())
print(len(t))
response = requests.get('https://us-east4-eng-reactor-287421.cloudfunctions.net/current_yield_curve_batch',
                       params = {"maturity":maturities}, headers={"Authorization":"Bearer {}".format(token)})
response.json()
# Out:
# 500
# Wall time: 31.8 s
# {'error': '',
# ...
