# %%
input_data = {'username': 'gil@ficc.ai', 'password': 'aDwYwwL6', "cusipList": [
        "586145T38",
        "586145U69",
        "590621KZ0",
        "5917455E0",
        "592041CL9",
        "592250CK8",
        "59259Y4G1",
        "59261ACX3",
        "592643AY6",
        "592643BL3"
    ],
    "quantityList": [50, 50, 50, 50, 50, 50, 50, 50, 50, 50],
    "tradeTypeList": ["P", "P", "P", "P", "P", "P", "P", "P", "P", "P"]
}

# %%
import requests

# fill out the EMAIL and PASSWORD variables below
EMAIL = 'YOUR EMAIL'
PASSWORD = 'YOUR PASSWORD'

# do NOT change this function
def ficc_prices(cusips_quantities_tradetypes):
    base_url = 'https://api.ficc.ai/api/batchpricing'
    cusip_list = [row['CUSIP'] for row in cusips_quantities_tradetypes]
    quantity_list = [row['Quantity'] for row in cusips_quantities_tradetypes]
    trade_type_list = [row['Trade Type'] for row in
    cusips_quantities_tradetypes]
    response = requests.post(base_url, data=input_data)
    # {'username': EMAIL,
    # 'password': PASSWORD,
    # 'cusipList': cusip_list,
    # 'quantityList': quantity_list,
    # 'tradeTypeList': trade_type_list})

    return response.json()

# example CUSIP, quantity (in thousands), trade type triples; feel free to put your own using the below format

# for trade type, use the following mapping. P: Purchase from Customer, S: Sale to Customer, D: Inter-Dealer
cusips_quantities_tradetypes = [
{'CUSIP': '64971XQM3', 'Quantity': 5, 'Trade Type': 'S'},
{'CUSIP': '64971XQM3', 'Quantity': 500, 'Trade Type': 'D'},
{'CUSIP': '13063DU89', 'Quantity': 100, 'Trade Type': 'P'},
{'CUSIP': '13063DLJ5', 'Quantity': 250, 'Trade Type': 'S'},
{'CUSIP': '54466HJM9', 'Quantity': 500, 'Trade Type': 'P'},
{'CUSIP': '650036CJ3', 'Quantity': 5000, 'Trade Type': 'S'},
]

# calling the function to retrieve pricing information
#print(ficc_prices(cusips_quantities_tradetypes))

# %%
x = ficc_prices(cusips_quantities_tradetypes)
x
# Out:
# '{"cusip":{"0":"586145T38","1":"586145U69","2":"590621KZ0","3":"5917455E0","4":"592041CL9","5":"592250CK8","6":"59259Y4G1","7":"59261ACX3","8":"592643AY6","9":"592643BL3"},"quantity":{"0":50000,"1":50000,"2":50000,"3":50000,"4":50000,"5":50000,"6":50000,"7":50000,"8":50000,"9":50000},"trade_type":{"0":"Bid Side","1":"Bid Side","2":"Bid Side","3":"Bid Side","4":"Bid Side","5":"Bid Side","6":"Bid Side","7":"Bid Side","8":"Bid Side","9":"Bid Side"},"ytw":{"0":4.272,"1":4.366,"2":3.807,"3":4.583,"4":4.145,"5":5.287,"6":4.608,"7":4.712,"8":4.204,"9":4.728},"price":{"0":92.809,"1":94.723,"2":105.489,"3":80.424,"4":102.913,"5":18.311,"6":100.357,"7":90.2,"8":76.854,"9":46.627},"yield_to_worst_date":{"0":"06-01-2036","1":"06-01-2047","2":"12-01-2027","3":"07-01-2045","4":"11-01-2028","5":"12-15-2056","6":"05-15-2025","7":"11-15-2046","8":"10-01-2030","9":"10-01-2040"},"coupon":{"0":3.5,"1":4.0,"2":5.5,"3":3.125,"4":4.875,"5":0.0,"6":5.0,"7":4.0,"8":0.0,"9":0.0},"security_description":{"0":"MEMPHIS TENN GEN IMPT BDS 2018 ","1":"MEMPHIS TENN GEN IMPT BDS 2018 ","2":"MESA CNTY COLO VY SCH DIST NO 051 GRAND JUNCTION GO BDS 2018 ","3":"METROPOLITAN ATLANTA RAPID TRAN AUTH GA SALES TAX REV BDS 2019 A ","4":"MET GOVT NASHVILLE & DAVIDSON CNTY TENN H & E FACS BRD REV REF REV BDS 1998 BAPTIST HOSP INC","5":"METROPOLITAN PIER & EXPOSITION AUTH ILL REV REF BDS 2017 A ","6":"METROPOLITAN TRANSN AUTH N Y REV BDS A-1 ","7":"METROPOLITAN TRANSN AUTH N Y REV REV GREEN BDS A-1 ","8":"METROPOLITAN WASH D C ARPTS AUTH DULLES TOLL RD REV BDS 2009B ","9":"METROPOLITAN WASH D C ARPTS AUTH DULLES TOLL RD REV BDS 2009B "},"maturity_date":{"0":"06-01-2036","1":"06-01-2047","2":"12-01-2035","3":"07-01-2045","4":"11-01-2028","5":"12-15-2056","6":"11-15-2036","7":"11-15-2046","8":"10-01-2030","9":"10-01-2040"}}'
