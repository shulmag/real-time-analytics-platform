# %% [markdown]
# To run this notebook, create the virtual environment with `requirements_jupyter.txt` and a version of Python >= 3.10.

# %%
from api_call import main

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
main()
